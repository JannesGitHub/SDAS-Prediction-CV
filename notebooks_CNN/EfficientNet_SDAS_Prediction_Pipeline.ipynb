# %% [markdown]
# # Training a CNN for Image-Regression to predict the SDAS of a given image

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from opencv-python) (1.26.2)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np        #library for matrices (useful for data preparation)
import os                 #library for package manage
import cv2                #library for loading images
import tensorflow as tf   #library/framework for all kinds of machine learning tasks
import matplotlib.pyplot as plt #libary for visualisation
import random             #for random seeds

import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Input, Lambda
from tensorflow.keras.initializers import Constant, he_normal

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator #for Augmentation of Training Data

from tqdm.keras import TqdmCallback # for loading-bar
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

from tensorflow.keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# !nvidia-smi
# Out:
# Mon May 12 13:45:54 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A30                     On  |   00000000:E2:00.0 Off |                   On |
# | N/A   33C    P0             55W /  165W |                  N/A   |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | MIG devices:                                                                            |
# +------------------+----------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                     Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                       BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                  |        ECC|                       |
# |==================+==================================+===========+=======================|
# |  0    0   0   0  |           22517MiB / 24050MiB    | 56      0 |  4   0    4    1    1 |
# |                  |                 4MiB / 32768MiB  |           |                       |
# +------------------+----------------------------------+-----------+-----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# speicher test

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
gpus
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15973924510675645775
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1130233856
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5219629538526767917
# physical_device_desc: "device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]
# I0000 00:00:1747057555.461173  182890 gpu_device.cc:2019] Created device /device:GPU:0 with 1077 MB memory:  -> device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0

# %% [markdown]
# fix random seed. Always use a fixed random seed to guarantee that when you run the code twice you will get the same outcome. This removes a factor of variation and will help keep you sane.

# %%
# 1. Python-Seed für allgemeine Zufallszahlen
random.seed(42)

# 2. NumPy-Seed für alle Operationen mit NumPy
np.random.seed(42)

# 3. TensorFlow-Seed für TensorFlow-Operationen
tf.random.set_seed(42)

# 4. Optional: OS-Level Seed für bestimmte Bibliotheken
os.environ['PYTHONHASHSEED'] = '42'

# %% [markdown]
# ## Model Architecture

# %%
# Input layer
input_layer = Input(shape=(200, 200, 1))

# Grayscale zu RGB
x = Lambda(lambda x: tf.image.grayscale_to_rgb(x), output_shape=(200, 200, 3))(input_layer)

# Load EfficientNetB0 base (ohne Klassifikationskopf)
efficientnet_base = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=x)

# Base-Model einfrieren (optional)
for layer in efficientnet_base.layers:
    layer.trainable = False

# Regression Head
x = efficientnet_base.output
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
x = BatchNormalization()(x)
output = Dense(1, activation='linear', kernel_initializer=he_normal())(x)

# Modell zusammenbauen
model = Model(inputs=input_layer, outputs=output)

# %%
# Compile model
learning_rate = 0.00001 # learning_rate = 0.00000001 -> Muss sehr viel niedriger gewählt
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError'])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 200, 200,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 200, 200,  │          0 │ input_layer_2[0]… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_4         │ (None, 200, 200,  │          0 │ lambda_2[0][0]    │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_2     │ (None, 200, 200,  │          7 │ rescaling_4[0][0] │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_5         │ (None, 200, 200,  │          0 │ normalization_2[… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 201, 201,  │          0 │ rescaling_5[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 100, 100,  │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 100, 100,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 100, 100,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 100, 100,  │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 100, 100,  │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 100, 100,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 100, 100,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 100, 100,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 100, 100,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 100, 100,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 100, 100,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 100, 100,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 101, 101,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 50, 50,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 50, 50,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 50, 50,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 50, 50,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 50, 50,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 50, 50,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 50, 50,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 50, 50,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 50, 50,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 50, 50,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 50, 50,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 50, 50,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 50, 50,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 50, 50,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 50, 50,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 50, 50,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 50, 50,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 50, 50,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 50, 50,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 50, 50,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 53, 53,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 25, 25,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 25, 25,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 25, 25,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 25, 25,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 25, 25,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 25, 25,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 25, 25,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 25, 25,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 25, 25,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 25, 25,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 25, 25,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 25, 25,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 25, 25,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 25, 25,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 25, 25,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 25, 25,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 25, 25,    │          0 │ block3b_drop[0][… │
# │                     │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 25, 25,    │      9,600 │ block3b_add[0][0] │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 25, 25,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 25, 25,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 27, 27,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 13, 13,    │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 13, 13,    │        960 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 13, 13,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 13, 13,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 240)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 13, 13,    │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 13, 13,    │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 13, 13,    │     38,400 │ block4a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 13, 13,    │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 13, 13,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 13, 13,    │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 13, 13,    │      1,920 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 13, 13,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 13, 13,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 480)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 13, 13,    │     38,400 │ block4b_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 13, 13,    │        320 │ block4b_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 13, 13,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 13, 13,    │          0 │ block4b_drop[0][… │
# │                     │ 80)               │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 13, 13,    │     38,400 │ block4b_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 13, 13,    │      1,920 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 13, 13,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 13, 13,    │      4,320 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 13, 13,    │      1,920 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 13, 13,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 480)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 480) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 13, 13,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 480)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 13, 13,    │     38,400 │ block4c_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 13, 13,    │        320 │ block4c_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 13, 13,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 13, 13,    │          0 │ block4c_drop[0][… │
# │                     │ 80)               │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 13, 13,    │     38,400 │ block4c_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 13, 13,    │      1,920 │ block5a_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 13, 13,    │          0 │ block5a_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv      │ (None, 13, 13,    │     12,000 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 13, 13,    │      1,920 │ block5a_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 13, 13,    │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 480)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 480) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 480) │     10,080 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 13, 13,    │          0 │ block5a_activati… │
# │ (Multiply)          │ 480)              │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 13, 13,    │     53,760 │ block5a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 13, 13,    │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 13, 13,    │     75,264 │ block5a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 13, 13,    │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 13, 13,    │          0 │ block5b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv      │ (None, 13, 13,    │     16,800 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 13, 13,    │      2,688 │ block5b_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 13, 13,    │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 13, 13,    │          0 │ block5b_activati… │
# │ (Multiply)          │ 672)              │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 13, 13,    │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 13, 13,    │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 13, 13,    │          0 │ block5b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 13, 13,    │          0 │ block5b_drop[0][… │
# │                     │ 112)              │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 13, 13,    │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 13, 13,    │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 13, 13,    │          0 │ block5c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv      │ (None, 13, 13,    │     16,800 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 13, 13,    │      2,688 │ block5c_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 13, 13,    │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 13, 13,    │          0 │ block5c_activati… │
# │ (Multiply)          │ 672)              │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 13, 13,    │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 13, 13,    │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 13, 13,    │          0 │ block5c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 13, 13,    │          0 │ block5c_drop[0][… │
# │                     │ 112)              │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 13, 13,    │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 13, 13,    │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 13, 13,    │          0 │ block6a_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv_pad  │ (None, 17, 17,    │          0 │ block6a_expand_a… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv      │ (None, 7, 7, 672) │     16,800 │ block6a_dwconv_p… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 7, 7, 672) │      2,688 │ block6a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 7, 7, 672) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 7, 7, 672) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 7, 7, 192) │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 7, 7, 192) │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 7, 7,      │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 7, 7,      │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 7, 7,      │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv      │ (None, 7, 7,      │     28,800 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 7, 7,      │      4,608 │ block6b_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 7, 7,      │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 7, 7,      │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 7, 7, 192) │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 7, 7, 192) │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 7, 7, 192) │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 7, 7, 192) │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 7, 7,      │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 7, 7,      │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 7, 7,      │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv      │ (None, 7, 7,      │     28,800 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 7, 7,      │      4,608 │ block6c_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 7, 7,      │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 7, 7,      │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 7, 7, 192) │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 7, 7, 192) │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 7, 7, 192) │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 7, 7, 192) │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 7, 7,      │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 7, 7,      │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 7, 7,      │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv      │ (None, 7, 7,      │     28,800 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 7, 7,      │      4,608 │ block6d_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 7, 7,      │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 7, 7,      │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 7, 7, 192) │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 7, 7, 192) │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 7, 7, 192) │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 7, 7, 192) │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 7, 7,      │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 7, 7,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 7, 7,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 7, 7,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 7, 7,      │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 7, 7,      │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 7, 7,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 7, 7, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 7, 7, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 7, 7,      │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 7, 7,      │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 7, 7,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 62720)     │          0 │ top_activation[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │  4,014,144 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,064,036 (30.76 MB)
#  Trainable params: 4,014,337 (15.31 MB)
#  Non-trainable params: 4,049,699 (15.45 MB)

# %% [markdown]
# ## Import Dataset and Preprocessing

# %%
# Path to the folder containing the original images (no subfolders)
data_dir = r'../data/bmw_train'
image_exts = ('.jpeg', '.jpg', '.bmp', '.png')
pixel_per_micrometer = 1/0.728265817023213 # for our training data from bmw
F_value = 1.36/pixel_per_micrometer        # F_value from paper

# List all image filenames
files = [f for f in os.listdir(data_dir) if f.lower().endswith(image_exts)] 

tiles = []
labels = []
tile_size = 200

for idx, file in enumerate(files, 1):
    img_path = os.path.join(data_dir, file)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"⚠️ Could not load {file}, skipping.")
        continue

    # --- Extract label from filename exactly as in the original script ---
    try:
        filename_parts = file.split('_')
        if len(filename_parts) < 2:
            print(f"⚠️ Unexpected filename format: {file}")
            continue
        sdas_value_str = filename_parts[1]   # e.g., '33' from 'AC_33_B2.jpg'
        SDAS = float(sdas_value_str)         # Convert string to float
        s_value = round(SDAS / F_value, 2)  # Apply formula
    except Exception as e:
        print(f"⚠️ Error parsing label from '{file}': {e}")
        continue
        
    norm_label = s_value / 100.0  # Normalize to 0–1 range

    h, w = img.shape

    # Split image into 200×200 tiles
    for y in range(0, h, tile_size):
        for x in range(0, w, tile_size):
            tile = img[y:y+tile_size, x:x+tile_size]
            if tile.shape != (tile_size, tile_size):
                continue  # Skip incomplete tiles at the edges

            # Normalize pixel values and add channel dimension
            tile = tile.astype(np.float16) / 255.0
            tile = tile[..., np.newaxis]  # Shape: (200, 200, 1)

            tiles.append(tile)
            labels.append(norm_label)

            # Apply 90°, 180°, and 270° rotations and store them as additional samples
            # for k in [1, 2, 3]:  # 1 = 90°, 2 = 180°, 3 = 270°
            #     rotated = np.rot90(tile, k)  # Rotate k times 90° counter-clockwise
            #     tiles.append(rotated)
            #     labels.append(norm_label)

    if idx % 50 == 0:
        print(f"⏳ Processed {idx}/{len(files)} images...")

# Convert lists to NumPy arrays
input_data = np.array(tiles, dtype=np.float16)
labels     = np.array(labels, dtype=np.float16)

print(f"✅ Done: {input_data.shape[0]} tiles created, input shape {input_data.shape[1:]}")
# Out:
# ⏳ Processed 50/130 images...
# ⏳ Processed 100/130 images...
# ✅ Done: 12870 tiles created, input shape (200, 200, 1)
# Processing file 16945/30685
# Processing file 16946/30685
# Processing file 16947/30685
# Processing file 16948/30685
# Processing file 16949/30685
# Processing file 16950/30685
# Processing file 16951/30685
# Processing file 16952/30685
# Processing file 16953/30685
# Processing file 16954/30685
# Processing file 16955/30685
# Processing file 16956/30685
# Processing file 16957/30685
# Processing file 16958/30685
# Processing file 16959/30685
# Processing file 16960/30685
# Processing file 16961/30685
# Processing file 16962/30685
# Processing file 16963/30685
# Processing file 16964/30685
# Processing file 16965/30685
# Processing file 16966/30685
# Processing file 16967/30685
# Processing file 16968/30685
# Processing file 16969/30685
# Processing file 16970/30685
# Processing file 16971/30685
# Processing file 16972/30685
# Processing file 16973/30685
# Processing file 16974/30685
# Processing file 16975/30685
# Processing file 16976/30685
# Processing file 16977/30685
# Processing file 16978/30685
# Processing file 16979/30685
# Processing file 16980/30685
# Processing file 16981/30685
# Processing file 16982/30685
# Processing file 16983/30685
# Processing file 16984/30685
# Processing file 16985/30685
# Processing file 16986/30685
# Processing file 16987/30685
# Processing file 16988/30685
# Processing file 16989/30685
# Processing file 16990/30685
# Processing file 16991/30685
# Processing file 16992/30685
# Processing file 16993/30685
# Processing file 16994/30685
# Processing file 16995/30685
# Processing file 16996/30685
# Processing file 16997/30685
# Processing file 16998/30685
# Processing file 16999/30685
# Processing file 17000/30685
# Processing file 17001/30685
# Processing file 17002/30685
# Processing file 17003/30685
# Processing file 17004/30685
# Processing file 17005/30685
# Processing file 17006/30685
# Processing file 17007/30685
# Processing file 17008/30685
# Processing file 17009/30685
# Processing file 17010/30685
# Processing file 17011/30685
# Processing file 17012/30685
# Processing file 17013/30685
# Processing file 17014/30685
# Processing file 17015/30685
# Processing file 17016/30685
# Processing file 17017/30685
# Processing file 17018/30685
# Processing file 17019/30685
# Processing file 17020/30685
# Processing file 17021/30685
# Processing file 17022/30685
# Processing file 17023/30685
# Processing file 17024/30685
# Processing file 17025/30685
# Processing file 17026/30685
# Processing file 17027/30685
# Processing file 17028/30685
# Processing file 17029/30685
# Processing file 17030/30685
# Processing file 17031/30685
# Processing file 17032/30685
# Processing file 17033/30685
# Processing file 17034/30685
# Processing file 17035/30685
# Processing file 17036/30685
# Processing file 17037/30685
# Processing file 17038/30685
# Processing file 17039/30685
# Processing file 17040/30685
# Processing file 17041/30685
# Processing file 17042/30685
# Processing file 17043/30685
# Processing file 17044/30685
# Processing file 17045/30685
# Processing file 17046/30685
# Processing file 17047/30685
# Processing file 17048/30685
# Processing file 17049/30685
# Processing file 17050/30685
# Processing file 17051/30685
# Processing file 17052/30685
# Processing file 17053/30685
# Processing file 17054/30685
# Processing file 17055/30685
# Processing file 17056/30685
# Processing file 17057/30685
# Processing file 17058/30685
# Processing file 17059/30685
# Processing file 17060/30685
# Processing file 17061/30685
# Processing file 17062/30685
# Processing file 17063/30685
# Processing file 17064/30685
# Processing file 17065/30685
# Processing file 17066/30685
# Processing file 17067/30685
# Processing file 17068/30685
# Processing file 17069/30685
# Processing file 17070/30685
# Processing file 17071/30685
# Processing file 17072/30685
# Processing file 17073/30685
# Processing file 17074/30685
# Processing file 17075/30685
# Processing file 17076/30685
# Processing file 17077/30685
# Processing file 17078/30685
# Processing file 17079/30685
# Processing file 17080/30685
# Processing file 17081/30685
# Processing file 17082/30685
# Processing file 17083/30685
# Processing file 17084/30685
# Processing file 17085/30685
# Processing file 17086/30685
# Processing file 17087/30685
# Processing file 17088/30685
# Processing file 17089/30685
# Processing file 17090/30685
# Processing file 17091/30685
# Processing file 17092/30685
# Processing file 17093/30685
# Processing file 17094/30685
# Processing file 17095/30685
# Processing file 17096/30685
# Processing file 17097/30685
# Processing file 17098/30685
# Processing file 17099/30685
# Processing file 17100/30685
# Processing file 17101/30685
# Processing file 17102/30685
# Processing file 17103/30685
# Processing file 17104/30685
# Processing file 17105/30685
# Processing file 17106/30685
# Processing file 17107/30685
# Processing file 17108/30685
# Processing file 17109/30685
# Processing file 17110/30685
# Processing file 17111/30685
# Processing file 17112/30685
# Processing file 17113/30685
# Processing file 17114/30685
# Processing file 17115/30685
# Processing file 17116/30685
# Processing file 17117/30685
# Processing file 17118/30685
# Processing file 17119/30685
# Processing file 17120/30685
# Processing file 17121/30685
# Processing file 17122/30685
# Processing file 17123/30685
# Processing file 17124/30685
# Processing file 17125/30685
# Processing file 17126/30685
# Processing file 17127/30685
# Processing file 17128/30685
# Processing file 17129/30685
# Processing file 17130/30685
# Processing file 17131/30685
# Processing file 17132/30685
# Processing file 17133/30685
# Processing file 17134/30685
# Processing file 17135/30685
# Processing file 17136/30685
# Processing file 17137/30685
# Processing file 17138/30685
# Processing file 17139/30685
# Processing file 17140/30685
# Processing file 17141/30685
# Processing file 17142/30685
# Processing file 17143/30685
# Processing file 17144/30685
# Processing file 17145/30685
# Processing file 17146/30685
# Processing file 17147/30685
# Processing file 17148/30685
# Processing file 17149/30685
# Processing file 17150/30685
# Processing file 17151/30685
# Processing file 17152/30685
# Processing file 17153/30685
# Processing file 17154/30685
# Processing file 17155/30685
# Processing file 17156/30685
# Processing file 17157/30685
# Processing file 17158/30685
# Processing file 17159/30685
# Processing file 17160/30685
# Processing file 17161/30685
# Processing file 17162/30685
# Processing file 17163/30685
# Processing file 17164/30685
# Processing file 17165/30685
# Processing file 17166/30685
# Processing file 17167/30685
# Processing file 17168/30685
# Processing file 17169/30685
# Processing file 17170/30685
# Processing file 17171/30685
# Processing file 17172/30685
# Processing file 17173/30685
# Processing file 17174/30685
# Processing file 17175/30685
# Processing file 17176/30685
# Processing file 17177/30685
# Processing file 17178/30685
# Processing file 17179/30685
# Processing file 17180/30685
# Processing file 17181/30685
# Processing file 17182/30685
# Processing file 17183/30685
# Processing file 17184/30685
# Processing file 17185/30685
# Processing file 17186/30685
# Processing file 17187/30685
# Processing file 17188/30685
# Processing file 17189/30685
# Processing file 17190/30685
# Processing file 17191/30685
# Processing file 17192/30685
# Processing file 17193/30685
# Processing file 17194/30685
# Processing file 17195/30685
# Processing file 17196/30685
# Processing file 17197/30685
# Processing file 17198/30685
# Processing file 17199/30685
# Processing file 17200/30685
# Processing file 17201/30685
# Processing file 17202/30685
# Processing file 17203/30685
# Processing file 17204/30685
# Processing file 17205/30685
# Processing file 17206/30685
# Processing file 17207/30685
# Processing file 17208/30685
# Processing file 17209/30685
# Processing file 17210/30685
# Processing file 17211/30685
# Processing file 17212/30685
# Processing file 17213/30685
# Processing file 17214/30685
# Processing file 17215/30685
# Processing file 17216/30685
# Processing file 17217/30685
# Processing file 17218/30685
# Processing file 17219/30685
# Processing file 17220/30685
# Processing file 17221/30685
# Processing file 17222/30685
# Processing file 17223/30685
# Processing file 17224/30685
# Processing file 17225/30685
# Processing file 17226/30685
# Processing file 17227/30685
# Processing file 17228/30685
# Processing file 17229/30685
# Processing file 17230/30685
# Processing file 17231/30685
# Processing file 17232/30685
# Processing file 17233/30685
# Processing file 17234/30685
# Processing file 17235/30685
# Processing file 17236/30685
# Processing file 17237/30685
# Processing file 17238/30685
# Processing file 17239/30685
# Processing file 17240/30685
# Processing file 17241/30685
# Processing file 17242/30685
# Processing file 17243/30685
# Processing file 17244/30685
# Processing file 17245/30685
# Processing file 17246/30685
# Processing file 17247/30685
# Processing file 17248/30685
# Processing file 17249/30685
# Processing file 17250/30685
# Processing file 17251/30685
# Processing file 17252/30685
# Processing file 17253/30685
# Processing file 17254/30685
# Processing file 17255/30685
# Processing file 17256/30685
# Processing file 17257/30685
# Processing file 17258/30685
# Processing file 17259/30685
# Processing file 17260/30685
# Processing file 17261/30685
# Processing file 17262/30685
# Processing file 17263/30685
# Processing file 17264/30685
# Processing file 17265/30685
# Processing file 17266/30685
# Processing file 17267/30685
# Processing file 17268/30685
# Processing file 17269/30685
# Processing file 17270/30685
# Processing file 17271/30685
# Processing file 17272/30685
# Processing file 17273/30685
# Processing file 17274/30685
# Processing file 17275/30685
# Processing file 17276/30685
# Processing file 17277/30685
# Processing file 17278/30685
# Processing file 17279/30685
# Processing file 17280/30685
# Processing file 17281/30685
# Processing file 17282/30685
# Processing file 17283/30685
# Processing file 17284/30685
# Processing file 17285/30685
# Processing file 17286/30685
# Processing file 17287/30685
# Processing file 17288/30685
# Processing file 17289/30685
# Processing file 17290/30685
# Processing file 17291/30685
# Processing file 17292/30685
# Processing file 17293/30685
# Processing file 17294/30685
# Processing file 17295/30685
# Processing file 17296/30685
# Processing file 17297/30685
# Processing file 17298/30685
# Processing file 17299/30685
# Processing file 17300/30685
# Processing file 17301/30685
# Processing file 17302/30685
# Processing file 17303/30685
# Processing file 17304/30685
# Processing file 17305/30685
# Processing file 17306/30685
# Processing file 17307/30685
# Processing file 17308/30685
# Processing file 17309/30685
# Processing file 17310/30685
# Processing file 17311/30685
# Processing file 17312/30685
# Processing file 17313/30685
# Processing file 17314/30685
# Processing file 17315/30685
# Processing file 17316/30685
# Processing file 17317/30685
# Processing file 17318/30685
# Processing file 17319/30685
# Processing file 17320/30685
# Processing file 17321/30685
# Processing file 17322/30685
# Processing file 17323/30685
# Processing file 17324/30685
# Processing file 17325/30685
# Processing file 17326/30685
# Processing file 17327/30685
# Processing file 17328/30685
# Processing file 17329/30685
# Processing file 17330/30685
# Processing file 17331/30685
# Processing file 17332/30685
# Processing file 17333/30685
# Processing file 17334/30685
# Processing file 17335/30685
# Processing file 17336/30685
# Processing file 17337/30685
# Processing file 17338/30685
# Processing file 17339/30685
# Processing file 17340/30685
# Processing file 17341/30685
# Processing file 17342/30685
# Processing file 17343/30685
# Processing file 17344/30685
# Processing file 17345/30685
# Processing file 17346/30685
# Processing file 17347/30685
# Processing file 17348/30685
# Processing file 17349/30685
# Processing file 17350/30685
# Processing file 17351/30685
# Processing file 17352/30685
# Processing file 17353/30685
# Processing file 17354/30685
# Processing file 17355/30685
# Processing file 17356/30685
# Processing file 17357/30685
# Processing file 17358/30685
# Processing file 17359/30685
# Processing file 17360/30685
# Processing file 17361/30685
# Processing file 17362/30685
# Processing file 17363/30685
# Processing file 17364/30685
# Processing file 17365/30685
# Processing file 17366/30685
# Processing file 17367/30685
# Processing file 17368/30685
# Processing file 17369/30685
# Processing file 17370/30685
# Processing file 17371/30685
# Processing file 17372/30685
# Processing file 17373/30685
# Processing file 17374/30685
# Processing file 17375/30685
# Processing file 17376/30685
# Processing file 17377/30685
# Processing file 17378/30685
# Processing file 17379/30685
# Processing file 17380/30685
# Processing file 17381/30685
# Processing file 17382/30685
# Processing file 17383/30685
# Processing file 17384/30685
# Processing file 17385/30685
# Processing file 17386/30685
# Processing file 17387/30685
# Processing file 17388/30685
# Processing file 17389/30685
# Processing file 17390/30685
# Processing file 17391/30685
# Processing file 17392/30685
# Processing file 17393/30685
# Processing file 17394/30685
# Processing file 17395/30685
# Processing file 17396/30685
# Processing file 17397/30685
# Processing file 17398/30685
# Processing file 17399/30685
# Processing file 17400/30685
# Processing file 17401/30685
# Processing file 17402/30685
# Processing file 17403/30685
# Processing file 17404/30685
# Processing file 17405/30685
# Processing file 17406/30685
# Processing file 17407/30685
# Processing file 17408/30685
# Processing file 17409/30685
# Processing file 17410/30685
# Processing file 17411/30685
# Processing file 17412/30685
# Processing file 17413/30685
# Processing file 17414/30685
# Processing file 17415/30685
# Processing file 17416/30685
# Processing file 17417/30685
# Processing file 17418/30685
# Processing file 17419/30685
# Processing file 17420/30685
# Processing file 17421/30685
# Processing file 17422/30685
# Processing file 17423/30685
# Processing file 17424/30685
# Processing file 17425/30685
# Processing file 17426/30685
# Processing file 17427/30685
# Processing file 17428/30685
# Processing file 17429/30685
# Processing file 17430/30685
# Processing file 17431/30685
# Processing file 17432/30685
# Processing file 17433/30685
# Processing file 17434/30685
# Processing file 17435/30685
# Processing file 17436/30685
# Processing file 17437/30685
# Processing file 17438/30685
# Processing file 17439/30685
# Processing file 17440/30685
# Processing file 17441/30685
# Processing file 17442/30685
# Processing file 17443/30685
# Processing file 17444/30685
# Processing file 17445/30685
# Processing file 17446/30685
# Processing file 17447/30685
# Processing file 17448/30685
# Processing file 17449/30685
# Processing file 17450/30685
# Processing file 17451/30685
# Processing file 17452/30685
# Processing file 17453/30685
# Processing file 17454/30685
# Processing file 17455/30685
# Processing file 17456/30685
# Processing file 17457/30685
# Processing file 17458/30685
# Processing file 17459/30685
# Processing file 17460/30685
# Processing file 17461/30685
# Processing file 17462/30685
# Processing file 17463/30685
# Processing file 17464/30685
# Processing file 17465/30685
# Processing file 17466/30685
# Processing file 17467/30685
# Processing file 17468/30685
# Processing file 17469/30685
# Processing file 17470/30685
# Processing file 17471/30685
# Processing file 17472/30685
# Processing file 17473/30685
# Processing file 17474/30685
# Processing file 17475/30685
# Processing file 17476/30685
# Processing file 17477/30685
# Processing file 17478/30685
# Processing file 17479/30685
# Processing file 17480/30685
# Processing file 17481/30685
# Processing file 17482/30685
# Processing file 17483/30685
# Processing file 17484/30685
# Processing file 17485/30685
# Processing file 17486/30685
# Processing file 17487/30685
# Processing file 17488/30685
# Processing file 17489/30685
# Processing file 17490/30685
# Processing file 17491/30685
# Processing file 17492/30685
# Processing file 17493/30685
# Processing file 17494/30685
# Processing file 17495/30685
# Processing file 17496/30685
# Processing file 17497/30685
# Processing file 17498/30685
# Processing file 17499/30685
# Processing file 17500/30685
# Processing file 17501/30685
# Processing file 17502/30685
# Processing file 17503/30685
# Processing file 17504/30685
# Processing file 17505/30685
# Processing file 17506/30685
# Processing file 17507/30685
# Processing file 17508/30685
# Processing file 17509/30685
# Processing file 17510/30685
# Processing file 17511/30685
# Processing file 17512/30685
# Processing file 17513/30685
# Processing file 17514/30685
# Processing file 17515/30685
# Processing file 17516/30685
# Processing file 17517/30685
# Processing file 17518/30685
# Processing file 17519/30685
# Processing file 17520/30685
# Processing file 17521/30685
# Processing file 17522/30685
# Processing file 17523/30685
# Processing file 17524/30685
# Processing file 17525/30685
# Processing file 17526/30685
# Processing file 17527/30685
# Processing file 17528/30685
# Processing file 17529/30685
# Processing file 17530/30685
# Processing file 17531/30685
# Processing file 17532/30685
# Processing file 17533/30685
# Processing file 17534/30685
# Processing file 17535/30685
# Processing file 17536/30685
# Processing file 17537/30685
# Processing file 17538/30685
# Processing file 17539/30685
# Processing file 17540/30685
# Processing file 17541/30685
# Processing file 17542/30685
# Processing file 17543/30685
# Processing file 17544/30685
# Processing file 17545/30685
# Processing file 17546/30685
# Processing file 17547/30685
# Processing file 17548/30685
# Processing file 17549/30685
# Processing file 17550/30685
# Processing file 17551/30685
# Processing file 17552/30685
# Processing file 17553/30685
# Processing file 17554/30685
# Processing file 17555/30685
# Processing file 17556/30685
# Processing file 17557/30685
# Processing file 17558/30685
# Processing file 17559/30685
# Processing file 17560/30685
# Processing file 17561/30685
# Processing file 17562/30685
# Processing file 17563/30685
# Processing file 17564/30685
# Processing file 17565/30685
# Processing file 17566/30685
# Processing file 17567/30685
# Processing file 17568/30685
# Processing file 17569/30685
# Processing file 17570/30685
# Processing file 17571/30685
# Processing file 17572/30685
# Processing file 17573/30685
# Processing file 17574/30685
# Processing file 17575/30685
# Processing file 17576/30685
# Processing file 17577/30685
# Processing file 17578/30685
# Processing file 17579/30685
# Processing file 17580/30685
# Processing file 17581/30685
# Processing file 17582/30685
# Processing file 17583/30685
# Processing file 17584/30685
# Processing file 17585/30685
# Processing file 17586/30685
# Processing file 17587/30685
# Processing file 17588/30685
# Processing file 17589/30685
# Processing file 17590/30685
# Processing file 17591/30685
# Processing file 17592/30685
# Processing file 17593/30685
# Processing file 17594/30685
# Processing file 17595/30685
# Processing file 17596/30685
# Processing file 17597/30685
# Processing file 17598/30685
# Processing file 17599/30685
# Processing file 17600/30685
# Processing file 17601/30685
# Processing file 17602/30685
# Processing file 17603/30685
# Processing file 17604/30685
# Processing file 17605/30685
# Processing file 17606/30685
# Processing file 17607/30685
# Processing file 17608/30685
# Processing file 17609/30685
# Processing file 17610/30685
# Processing file 17611/30685
# Processing file 17612/30685
# Processing file 17613/30685
# Processing file 17614/30685
# Processing file 17615/30685
# Processing file 17616/30685
# Processing file 17617/30685
# Processing file 17618/30685
# Processing file 17619/30685
# Processing file 17620/30685
# Processing file 17621/30685
# Processing file 17622/30685
# Processing file 17623/30685
# Processing file 17624/30685
# Processing file 17625/30685
# Processing file 17626/30685
# Processing file 17627/30685
# Processing file 17628/30685
# Processing file 17629/30685
# Processing file 17630/30685
# Processing file 17631/30685
# Processing file 17632/30685
# Processing file 17633/30685
# Processing file 17634/30685
# Processing file 17635/30685
# Processing file 17636/30685
# Processing file 17637/30685
# Processing file 17638/30685
# Processing file 17639/30685
# Processing file 17640/30685
# Processing file 17641/30685
# Processing file 17642/30685
# Processing file 17643/30685
# Processing file 17644/30685
# Processing file 17645/30685
# Processing file 17646/30685
# Processing file 17647/30685
# Processing file 17648/30685
# Processing file 17649/30685
# Processing file 17650/30685
# Processing file 17651/30685
# Processing file 17652/30685
# Processing file 17653/30685
# Processing file 17654/30685
# Processing file 17655/30685
# Processing file 17656/30685
# Processing file 17657/30685
# Processing file 17658/30685
# Processing file 17659/30685
# Processing file 17660/30685
# Processing file 17661/30685
# Processing file 17662/30685
# Processing file 17663/30685
# Processing file 17664/30685
# Processing file 17665/30685
# Processing file 17666/30685
# Processing file 17667/30685
# Processing file 17668/30685
# Processing file 17669/30685
# Processing file 17670/30685
# Processing file 17671/30685
# Processing file 17672/30685
# Processing file 17673/30685
# Processing file 17674/30685
# Processing file 17675/30685
# Processing file 17676/30685
# Processing file 17677/30685
# Processing file 17678/30685
# Processing file 17679/30685
# Processing file 17680/30685
# Processing file 17681/30685
# Processing file 17682/30685
# Processing file 17683/30685
# Processing file 17684/30685
# Processing file 17685/30685
# Processing file 17686/30685
# Processing file 17687/30685
# Processing file 17688/30685
# Processing file 17689/30685
# Processing file 17690/30685
# Processing file 17691/30685
# Processing file 17692/30685
# Processing file 17693/30685
# Processing file 17694/30685
# Processing file 17695/30685
# Processing file 17696/30685
# Processing file 17697/30685
# Processing file 17698/30685
# Processing file 17699/30685
# Processing file 17700/30685
# Processing file 17701/30685
# Processing file 17702/30685
# Processing file 17703/30685
# Processing file 17704/30685
# Processing file 17705/30685
# Processing file 17706/30685
# Processing file 17707/30685
# Processing file 17708/30685
# Processing file 17709/30685
# Processing file 17710/30685
# Processing file 17711/30685
# Processing file 17712/30685
# Processing file 17713/30685
# Processing file 17714/30685
# Processing file 17715/30685
# Processing file 17716/30685
# Processing file 17717/30685
# Processing file 17718/30685
# Processing file 17719/30685
# Processing file 17720/30685
# Processing file 17721/30685
# Processing file 17722/30685
# Processing file 17723/30685
# Processing file 17724/30685
# Processing file 17725/30685
# Processing file 17726/30685
# Processing file 17727/30685
# Processing file 17728/30685
# Processing file 17729/30685
# Processing file 17730/30685
# Processing file 17731/30685
# Processing file 17732/30685
# Processing file 17733/30685
# Processing file 17734/30685
# Processing file 17735/30685
# Processing file 17736/30685
# Processing file 17737/30685
# Processing file 17738/30685
# Processing file 17739/30685
# Processing file 17740/30685
# Processing file 17741/30685
# Processing file 17742/30685
# Processing file 17743/30685
# Processing file 17744/30685
# Processing file 17745/30685
# Processing file 17746/30685
# Processing file 17747/30685
# Processing file 17748/30685
# Processing file 17749/30685
# Processing file 17750/30685
# Processing file 17751/30685
# Processing file 17752/30685
# Processing file 17753/30685
# Processing file 17754/30685
# Processing file 17755/30685
# Processing file 17756/30685
# Processing file 17757/30685
# Processing file 17758/30685
# Processing file 17759/30685
# Processing file 17760/30685
# Processing file 17761/30685
# Processing file 17762/30685
# Processing file 17763/30685
# Processing file 17764/30685
# Processing file 17765/30685
# Processing file 17766/30685
# Processing file 17767/30685
# Processing file 17768/30685
# Processing file 17769/30685
# Processing file 17770/30685
# Processing file 17771/30685
# Processing file 17772/30685
# Processing file 17773/30685
# Processing file 17774/30685
# Processing file 17775/30685
# Processing file 17776/30685
# Processing file 17777/30685
# Processing file 17778/30685
# Processing file 17779/30685
# Processing file 17780/30685
# Processing file 17781/30685
# Processing file 17782/30685
# Processing file 17783/30685
# Processing file 17784/30685
# Processing file 17785/30685
# Processing file 17786/30685
# Processing file 17787/30685
# Processing file 17788/30685
# Processing file 17789/30685
# Processing file 17790/30685
# Processing file 17791/30685
# Processing file 17792/30685
# Processing file 17793/30685
# Processing file 17794/30685
# Processing file 17795/30685
# Processing file 17796/30685
# Processing file 17797/30685
# Processing file 17798/30685
# Processing file 17799/30685
# Processing file 17800/30685
# Processing file 17801/30685
# Processing file 17802/30685
# Processing file 17803/30685
# Processing file 17804/30685
# Processing file 17805/30685
# Processing file 17806/30685
# Processing file 17807/30685
# Processing file 17808/30685
# Processing file 17809/30685
# Processing file 17810/30685
# Processing file 17811/30685
# Processing file 17812/30685
# Processing file 17813/30685
# Processing file 17814/30685
# Processing file 17815/30685
# Processing file 17816/30685
# Processing file 17817/30685
# Processing file 17818/30685
# Processing file 17819/30685
# Processing file 17820/30685
# Processing file 17821/30685
# Processing file 17822/30685
# Processing file 17823/30685
# Processing file 17824/30685
# Processing file 17825/30685
# Processing file 17826/30685
# Processing file 17827/30685
# Processing file 17828/30685
# Processing file 17829/30685
# Processing file 17830/30685
# Processing file 17831/30685
# Processing file 17832/30685
# Processing file 17833/30685
# Processing file 17834/30685
# Processing file 17835/30685
# Processing file 17836/30685
# Processing file 17837/30685
# Processing file 17838/30685
# Processing file 17839/30685
# Processing file 17840/30685
# Processing file 17841/30685
# Processing file 17842/30685
# Processing file 17843/30685
# Processing file 17844/30685
# Processing file 17845/30685
# Processing file 17846/30685
# Processing file 17847/30685
# Processing file 17848/30685
# Processing file 17849/30685
# Processing file 17850/30685
# Processing file 17851/30685
# Processing file 17852/30685
# Processing file 17853/30685
# Processing file 17854/30685
# Processing file 17855/30685
# Processing file 17856/30685
# Processing file 17857/30685
# Processing file 17858/30685
# Processing file 17859/30685
# Processing file 17860/30685
# Processing file 17861/30685
# Processing file 17862/30685
# Processing file 17863/30685
# Processing file 17864/30685
# Processing file 17865/30685
# Processing file 17866/30685
# Processing file 17867/30685
# Processing file 17868/30685
# Processing file 17869/30685
# Processing file 17870/30685
# Processing file 17871/30685
# Processing file 17872/30685
# Processing file 17873/30685
# Processing file 17874/30685
# Processing file 17875/30685
# Processing file 17876/30685
# Processing file 17877/30685
# Processing file 17878/30685
# Processing file 17879/30685
# Processing file 17880/30685
# Processing file 17881/30685
# Processing file 17882/30685
# Processing file 17883/30685
# Processing file 17884/30685
# Processing file 17885/30685
# Processing file 17886/30685
# Processing file 17887/30685
# Processing file 17888/30685
# Processing file 17889/30685
# Processing file 17890/30685
# Processing file 17891/30685
# Processing file 17892/30685
# Processing file 17893/30685
# Processing file 17894/30685
# Processing file 17895/30685
# Processing file 17896/30685
# Processing file 17897/30685
# Processing file 17898/30685
# Processing file 17899/30685
# Processing file 17900/30685
# Processing file 17901/30685
# Processing file 17902/30685
# Processing file 17903/30685
# Processing file 17904/30685
# Processing file 17905/30685
# Processing file 17906/30685
# Processing file 17907/30685
# Processing file 17908/30685
# Processing file 17909/30685
# Processing file 17910/30685
# Processing file 17911/30685
# Processing file 17912/30685
# Processing file 17913/30685
# Processing file 17914/30685
# Processing file 17915/30685
# Processing file 17916/30685
# Processing file 17917/30685
# Processing file 17918/30685
# Processing file 17919/30685
# Processing file 17920/30685
# Processing file 17921/30685
# Processing file 17922/30685
# Processing file 17923/30685
# Processing file 17924/30685
# Processing file 17925/30685
# Processing file 17926/30685
# Processing file 17927/30685
# Processing file 17928/30685
# Processing file 17929/30685
# Processing file 17930/30685
# Processing file 17931/30685
# Processing file 17932/30685
# Processing file 17933/30685
# Processing file 17934/30685
# Processing file 17935/30685
# Processing file 17936/30685
# Processing file 17937/30685
# Processing file 17938/30685
# Processing file 17939/30685
# Processing file 17940/30685
# Processing file 17941/30685
# Processing file 17942/30685
# Processing file 17943/30685
# Processing file 17944/30685
# Processing file 17945/30685
# Processing file 17946/30685
# Processing file 17947/30685
# Processing file 17948/30685
# Processing file 17949/30685
# Processing file 17950/30685
# Processing file 17951/30685
# Processing file 17952/30685
# Processing file 17953/30685
# Processing file 17954/30685
# Processing file 17955/30685
# Processing file 17956/30685
# Processing file 17957/30685
# Processing file 17958/30685
# Processing file 17959/30685
# Processing file 17960/30685
# Processing file 17961/30685
# Processing file 17962/30685
# Processing file 17963/30685
# Processing file 17964/30685
# Processing file 17965/30685
# Processing file 17966/30685
# Processing file 17967/30685
# Processing file 17968/30685
# Processing file 17969/30685
# Processing file 17970/30685
# Processing file 17971/30685
# Processing file 17972/30685
# Processing file 17973/30685
# Processing file 17974/30685
# Processing file 17975/30685
# Processing file 17976/30685
# Processing file 17977/30685
# Processing file 17978/30685
# Processing file 17979/30685
# Processing file 17980/30685
# Processing file 17981/30685
# Processing file 17982/30685
# Processing file 17983/30685
# Processing file 17984/30685
# Processing file 17985/30685
# Processing file 17986/30685
# Processing file 17987/30685
# Processing file 17988/30685
# Processing file 17989/30685
# Processing file 17990/30685
# Processing file 17991/30685
# Processing file 17992/30685
# Processing file 17993/30685
# Processing file 17994/30685
# Processing file 17995/30685
# Processing file 17996/30685
# Processing file 17997/30685
# Processing file 17998/30685
# Processing file 17999/30685
# Processing file 18000/30685
# Processing file 18001/30685
# Processing file 18002/30685
# Processing file 18003/30685
# Processing file 18004/30685
# Processing file 18005/30685
# Processing file 18006/30685
# Processing file 18007/30685
# Processing file 18008/30685
# Processing file 18009/30685
# Processing file 18010/30685
# Processing file 18011/30685
# Processing file 18012/30685
# Processing file 18013/30685
# Processing file 18014/30685
# Processing file 18015/30685
# Processing file 18016/30685
# Processing file 18017/30685
# Processing file 18018/30685
# Processing file 18019/30685
# Processing file 18020/30685
# Processing file 18021/30685
# Processing file 18022/30685
# Processing file 18023/30685
# Processing file 18024/30685
# Processing file 18025/30685
# Processing file 18026/30685
# Processing file 18027/30685
# Processing file 18028/30685
# Processing file 18029/30685
# Processing file 18030/30685
# Processing file 18031/30685
# Processing file 18032/30685
# Processing file 18033/30685
# Processing file 18034/30685
# Processing file 18035/30685
# Processing file 18036/30685
# Processing file 18037/30685
# Processing file 18038/30685
# Processing file 18039/30685
# Processing file 18040/30685
# Processing file 18041/30685
# Processing file 18042/30685
# Processing file 18043/30685
# Processing file 18044/30685
# Processing file 18045/30685
# Processing file 18046/30685
# Processing file 18047/30685
# Processing file 18048/30685
# Processing file 18049/30685
# Processing file 18050/30685
# Processing file 18051/30685
# Processing file 18052/30685
# Processing file 18053/30685
# Processing file 18054/30685
# Processing file 18055/30685
# Processing file 18056/30685
# Processing file 18057/30685
# Processing file 18058/30685
# Processing file 18059/30685
# Processing file 18060/30685
# Processing file 18061/30685
# Processing file 18062/30685
# Processing file 18063/30685
# Processing file 18064/30685
# Processing file 18065/30685
# Processing file 18066/30685
# Processing file 18067/30685
# Processing file 18068/30685
# Processing file 18069/30685
# Processing file 18070/30685
# Processing file 18071/30685
# Processing file 18072/30685
# Processing file 18073/30685
# Processing file 18074/30685
# Processing file 18075/30685
# Processing file 18076/30685
# Processing file 18077/30685
# Processing file 18078/30685
# Processing file 18079/30685
# Processing file 18080/30685
# Processing file 18081/30685
# Processing file 18082/30685
# Processing file 18083/30685
# Processing file 18084/30685
# Processing file 18085/30685
# Processing file 18086/30685
# Processing file 18087/30685
# Processing file 18088/30685
# Processing file 18089/30685
# Processing file 18090/30685
# Processing file 18091/30685
# Processing file 18092/30685
# Processing file 18093/30685
# Processing file 18094/30685
# Processing file 18095/30685
# Processing file 18096/30685
# Processing file 18097/30685
# Processing file 18098/30685
# Processing file 18099/30685
# Processing file 18100/30685
# Processing file 18101/30685
# Processing file 18102/30685
# Processing file 18103/30685
# Processing file 18104/30685
# Processing file 18105/30685
# Processing file 18106/30685
# Processing file 18107/30685
# Processing file 18108/30685
# Processing file 18109/30685
# Processing file 18110/30685
# Processing file 18111/30685
# Processing file 18112/30685
# Processing file 18113/30685
# Processing file 18114/30685
# Processing file 18115/30685
# Processing file 18116/30685
# Processing file 18117/30685
# Processing file 18118/30685
# Processing file 18119/30685
# Processing file 18120/30685
# Processing file 18121/30685
# Processing file 18122/30685
# Processing file 18123/30685
# Processing file 18124/30685
# Processing file 18125/30685
# Processing file 18126/30685
# Processing file 18127/30685
# Processing file 18128/30685
# Processing file 18129/30685
# Processing file 18130/30685
# Processing file 18131/30685
# Processing file 18132/30685
# Processing file 18133/30685
# Processing file 18134/30685
# Processing file 18135/30685
# Processing file 18136/30685
# Processing file 18137/30685
# Processing file 18138/30685
# Processing file 18139/30685
# Processing file 18140/30685
# Processing file 18141/30685
# Processing file 18142/30685
# Processing file 18143/30685
# Processing file 18144/30685
# Processing file 18145/30685
# Processing file 18146/30685
# Processing file 18147/30685
# Processing file 18148/30685
# Processing file 18149/30685
# Processing file 18150/30685
# Processing file 18151/30685
# Processing file 18152/30685
# Processing file 18153/30685
# Processing file 18154/30685
# Processing file 18155/30685
# Processing file 18156/30685
# Processing file 18157/30685
# Processing file 18158/30685
# Processing file 18159/30685
# Processing file 18160/30685
# Processing file 18161/30685
# Processing file 18162/30685
# Processing file 18163/30685
# Processing file 18164/30685
# Processing file 18165/30685
# Processing file 18166/30685
# Processing file 18167/30685
# Processing file 18168/30685
# Processing file 18169/30685
# Processing file 18170/30685
# Processing file 18171/30685
# Processing file 18172/30685
# Processing file 18173/30685
# Processing file 18174/30685
# Processing file 18175/30685
# Processing file 18176/30685
# Processing file 18177/30685
# Processing file 18178/30685
# Processing file 18179/30685
# Processing file 18180/30685
# Processing file 18181/30685
# Processing file 18182/30685
# Processing file 18183/30685
# Processing file 18184/30685
# Processing file 18185/30685
# Processing file 18186/30685
# Processing file 18187/30685
# Processing file 18188/30685
# Processing file 18189/30685
# Processing file 18190/30685
# Processing file 18191/30685
# Processing file 18192/30685
# Processing file 18193/30685
# Processing file 18194/30685
# Processing file 18195/30685
# Processing file 18196/30685
# Processing file 18197/30685
# Processing file 18198/30685
# Processing file 18199/30685
# Processing file 18200/30685
# Processing file 18201/30685
# Processing file 18202/30685
# Processing file 18203/30685
# Processing file 18204/30685
# Processing file 18205/30685
# Processing file 18206/30685
# Processing file 18207/30685
# Processing file 18208/30685
# Processing file 18209/30685
# Processing file 18210/30685
# Processing file 18211/30685
# Processing file 18212/30685
# Processing file 18213/30685
# Processing file 18214/30685
# Processing file 18215/30685
# Processing file 18216/30685
# Processing file 18217/30685
# Processing file 18218/30685
# Processing file 18219/30685
# Processing file 18220/30685
# Processing file 18221/30685
# Processing file 18222/30685
# Processing file 18223/30685
# Processing file 18224/30685
# Processing file 18225/30685
# Processing file 18226/30685
# Processing file 18227/30685
# Processing file 18228/30685
# Processing file 18229/30685
# Processing file 18230/30685
# Processing file 18231/30685
# Processing file 18232/30685
# Processing file 18233/30685
# Processing file 18234/30685
# Processing file 18235/30685
# Processing file 18236/30685
# Processing file 18237/30685
# Processing file 18238/30685
# Processing file 18239/30685
# Processing file 18240/30685
# Processing file 18241/30685
# Processing file 18242/30685
# Processing file 18243/30685
# Processing file 18244/30685
# Processing file 18245/30685
# Processing file 18246/30685
# Processing file 18247/30685
# Processing file 18248/30685
# Processing file 18249/30685
# Processing file 18250/30685
# Processing file 18251/30685
# Processing file 18252/30685
# Processing file 18253/30685
# Processing file 18254/30685
# Processing file 18255/30685
# Processing file 18256/30685
# Processing file 18257/30685
# Processing file 18258/30685
# Processing file 18259/30685
# Processing file 18260/30685
# Processing file 18261/30685
# Processing file 18262/30685
# Processing file 18263/30685
# Processing file 18264/30685
# Processing file 18265/30685
# Processing file 18266/30685
# Processing file 18267/30685
# Processing file 18268/30685
# Processing file 18269/30685
# Processing file 18270/30685
# Processing file 18271/30685
# Processing file 18272/30685
# Processing file 18273/30685
# Processing file 18274/30685
# Processing file 18275/30685
# Processing file 18276/30685
# Processing file 18277/30685
# Processing file 18278/30685
# Processing file 18279/30685
# Processing file 18280/30685
# Processing file 18281/30685
# Processing file 18282/30685
# Processing file 18283/30685
# Processing file 18284/30685
# Processing file 18285/30685
# Processing file 18286/30685
# Processing file 18287/30685
# Processing file 18288/30685
# Processing file 18289/30685
# Processing file 18290/30685
# Processing file 18291/30685
# Processing file 18292/30685
# Processing file 18293/30685
# Processing file 18294/30685
# Processing file 18295/30685
# Processing file 18296/30685
# Processing file 18297/30685
# Processing file 18298/30685
# Processing file 18299/30685
# Processing file 18300/30685
# Processing file 18301/30685
# Processing file 18302/30685
# Processing file 18303/30685
# Processing file 18304/30685
# Processing file 18305/30685
# Processing file 18306/30685
# Processing file 18307/30685
# Processing file 18308/30685
# Processing file 18309/30685
# Processing file 18310/30685
# Processing file 18311/30685
# Processing file 18312/30685
# Processing file 18313/30685
# Processing file 18314/30685
# Processing file 18315/30685
# Processing file 18316/30685
# Processing file 18317/30685
# Processing file 18318/30685
# Processing file 18319/30685
# Processing file 18320/30685
# Processing file 18321/30685
# Processing file 18322/30685
# Processing file 18323/30685
# Processing file 18324/30685
# Processing file 18325/30685
# Processing file 18326/30685
# Processing file 18327/30685
# Processing file 18328/30685
# Processing file 18329/30685
# Processing file 18330/30685
# Processing file 18331/30685
# Processing file 18332/30685
# Processing file 18333/30685
# Processing file 18334/30685
# Processing file 18335/30685
# Processing file 18336/30685
# Processing file 18337/30685
# Processing file 18338/30685
# Processing file 18339/30685
# Processing file 18340/30685
# Processing file 18341/30685
# Processing file 18342/30685
# Processing file 18343/30685
# Processing file 18344/30685
# Processing file 18345/30685
# Processing file 18346/30685
# Processing file 18347/30685
# Processing file 18348/30685
# Processing file 18349/30685
# Processing file 18350/30685
# Processing file 18351/30685
# Processing file 18352/30685
# Processing file 18353/30685
# Processing file 18354/30685
# Processing file 18355/30685
# Processing file 18356/30685
# Processing file 18357/30685
# Processing file 18358/30685
# Processing file 18359/30685
# Processing file 18360/30685
# Processing file 18361/30685
# Processing file 18362/30685
# Processing file 18363/30685
# Processing file 18364/30685
# Processing file 18365/30685
# Processing file 18366/30685
# Processing file 18367/30685
# Processing file 18368/30685
# Processing file 18369/30685
# Processing file 18370/30685
# Processing file 18371/30685
# Processing file 18372/30685
# Processing file 18373/30685
# Processing file 18374/30685
# Processing file 18375/30685
# Processing file 18376/30685
# Processing file 18377/30685
# Processing file 18378/30685
# Processing file 18379/30685
# Processing file 18380/30685
# Processing file 18381/30685
# Processing file 18382/30685
# Processing file 18383/30685
# Processing file 18384/30685
# Processing file 18385/30685
# Processing file 18386/30685
# Processing file 18387/30685
# Processing file 18388/30685
# Processing file 18389/30685
# Processing file 18390/30685
# Processing file 18391/30685
# Processing file 18392/30685
# Processing file 18393/30685
# Processing file 18394/30685
# Processing file 18395/30685
# Processing file 18396/30685
# Processing file 18397/30685
# Processing file 18398/30685
# Processing file 18399/30685
# Processing file 18400/30685
# Processing file 18401/30685
# Processing file 18402/30685
# Processing file 18403/30685
# Processing file 18404/30685
# Processing file 18405/30685
# Processing file 18406/30685
# Processing file 18407/30685
# Processing file 18408/30685
# Processing file 18409/30685
# Processing file 18410/30685
# Processing file 18411/30685
# Processing file 18412/30685
# Processing file 18413/30685
# Processing file 18414/30685
# Processing file 18415/30685
# Processing file 18416/30685
# Processing file 18417/30685
# Processing file 18418/30685
# Processing file 18419/30685
# Processing file 18420/30685
# Processing file 18421/30685
# Processing file 18422/30685
# Processing file 18423/30685
# Processing file 18424/30685
# Processing file 18425/30685
# Processing file 18426/30685
# Processing file 18427/30685
# Processing file 18428/30685
# Processing file 18429/30685
# Processing file 18430/30685
# Processing file 18431/30685
# Processing file 18432/30685
# Processing file 18433/30685
# Processing file 18434/30685
# Processing file 18435/30685
# Processing file 18436/30685
# Processing file 18437/30685
# Processing file 18438/30685
# Processing file 18439/30685
# Processing file 18440/30685
# Processing file 18441/30685
# Processing file 18442/30685
# Processing file 18443/30685
# Processing file 18444/30685
# Processing file 18445/30685
# Processing file 18446/30685
# Processing file 18447/30685
# Processing file 18448/30685
# Processing file 18449/30685
# Processing file 18450/30685
# Processing file 18451/30685
# Processing file 18452/30685
# Processing file 18453/30685
# Processing file 18454/30685
# Processing file 18455/30685
# Processing file 18456/30685
# Processing file 18457/30685
# Processing file 18458/30685
# Processing file 18459/30685
# Processing file 18460/30685
# Processing file 18461/30685
# Processing file 18462/30685
# Processing file 18463/30685
# Processing file 18464/30685
# Processing file 18465/30685
# Processing file 18466/30685
# Processing file 18467/30685
# Processing file 18468/30685
# Processing file 18469/30685
# Processing file 18470/30685
# Processing file 18471/30685
# Processing file 18472/30685
# Processing file 18473/30685
# Processing file 18474/30685
# Processing file 18475/30685
# Processing file 18476/30685
# Processing file 18477/30685
# Processing file 18478/30685
# Processing file 18479/30685
# Processing file 18480/30685
# Processing file 18481/30685
# Processing file 18482/30685
# Processing file 18483/30685
# Processing file 18484/30685
# Processing file 18485/30685
# Processing file 18486/30685
# Processing file 18487/30685
# Processing file 18488/30685
# Processing file 18489/30685
# Processing file 18490/30685
# Processing file 18491/30685
# Processing file 18492/30685
# Processing file 18493/30685
# Processing file 18494/30685
# Processing file 18495/30685
# Processing file 18496/30685
# Processing file 18497/30685
# Processing file 18498/30685
# Processing file 18499/30685
# Processing file 18500/30685
# Processing file 18501/30685
# Processing file 18502/30685
# Processing file 18503/30685
# Processing file 18504/30685
# Processing file 18505/30685
# Processing file 18506/30685
# Processing file 18507/30685
# Processing file 18508/30685
# Processing file 18509/30685
# Processing file 18510/30685
# Processing file 18511/30685
# Processing file 18512/30685
# Processing file 18513/30685
# Processing file 18514/30685
# Processing file 18515/30685
# Processing file 18516/30685
# Processing file 18517/30685
# Processing file 18518/30685
# Processing file 18519/30685
# Processing file 18520/30685
# Processing file 18521/30685
# Processing file 18522/30685
# Processing file 18523/30685
# Processing file 18524/30685
# Processing file 18525/30685
# Processing file 18526/30685
# Processing file 18527/30685
# Processing file 18528/30685
# Processing file 18529/30685
# Processing file 18530/30685
# Processing file 18531/30685
# Processing file 18532/30685
# Processing file 18533/30685
# Processing file 18534/30685
# Processing file 18535/30685
# Processing file 18536/30685
# Processing file 18537/30685
# Processing file 18538/30685
# Processing file 18539/30685
# Processing file 18540/30685
# Processing file 18541/30685
# Processing file 18542/30685
# Processing file 18543/30685
# Processing file 18544/30685
# Processing file 18545/30685
# Processing file 18546/30685
# Processing file 18547/30685
# Processing file 18548/30685
# Processing file 18549/30685
# Processing file 18550/30685
# Processing file 18551/30685
# Processing file 18552/30685
# Processing file 18553/30685
# Processing file 18554/30685
# Processing file 18555/30685
# Processing file 18556/30685
# Processing file 18557/30685
# Processing file 18558/30685
# Processing file 18559/30685
# Processing file 18560/30685
# Processing file 18561/30685
# Processing file 18562/30685
# Processing file 18563/30685
# Processing file 18564/30685
# Processing file 18565/30685
# Processing file 18566/30685
# Processing file 18567/30685
# Processing file 18568/30685
# Processing file 18569/30685
# Processing file 18570/30685
# Processing file 18571/30685
# Processing file 18572/30685
# Processing file 18573/30685
# Processing file 18574/30685
# Processing file 18575/30685
# Processing file 18576/30685
# Processing file 18577/30685
# Processing file 18578/30685
# Processing file 18579/30685
# Processing file 18580/30685
# Processing file 18581/30685
# Processing file 18582/30685
# Processing file 18583/30685
# Processing file 18584/30685
# Processing file 18585/30685
# Processing file 18586/30685
# Processing file 18587/30685
# Processing file 18588/30685
# Processing file 18589/30685
# Processing file 18590/30685
# Processing file 18591/30685
# Processing file 18592/30685
# Processing file 18593/30685
# Processing file 18594/30685
# Processing file 18595/30685
# Processing file 18596/30685
# Processing file 18597/30685
# Processing file 18598/30685
# Processing file 18599/30685
# Processing file 18600/30685
# Processing file 18601/30685
# Processing file 18602/30685
# Processing file 18603/30685
# Processing file 18604/30685
# Processing file 18605/30685
# Processing file 18606/30685
# Processing file 18607/30685
# Processing file 18608/30685
# Processing file 18609/30685
# Processing file 18610/30685
# Processing file 18611/30685
# Processing file 18612/30685
# Processing file 18613/30685
# Processing file 18614/30685
# Processing file 18615/30685
# Processing file 18616/30685
# Processing file 18617/30685
# Processing file 18618/30685
# Processing file 18619/30685
# Processing file 18620/30685
# Processing file 18621/30685
# Processing file 18622/30685
# Processing file 18623/30685
# Processing file 18624/30685
# Processing file 18625/30685
# Processing file 18626/30685
# Processing file 18627/30685
# Processing file 18628/30685
# Processing file 18629/30685
# Processing file 18630/30685
# Processing file 18631/30685
# Processing file 18632/30685
# Processing file 18633/30685
# Processing file 18634/30685
# Processing file 18635/30685
# Processing file 18636/30685
# Processing file 18637/30685
# Processing file 18638/30685
# Processing file 18639/30685
# Processing file 18640/30685
# Processing file 18641/30685
# Processing file 18642/30685
# Processing file 18643/30685
# Processing file 18644/30685
# Processing file 18645/30685
# Processing file 18646/30685
# Processing file 18647/30685
# Processing file 18648/30685
# Processing file 18649/30685
# Processing file 18650/30685
# Processing file 18651/30685
# Processing file 18652/30685
# Processing file 18653/30685
# Processing file 18654/30685
# ...
# Processing file 30115/30685
# Processing file 30116/30685
# Processing file 30117/30685
# Processing file 30118/30685
# Processing file 30119/30685
# Processing file 30120/30685
# Processing file 30121/30685
# Processing file 30122/30685
# Processing file 30123/30685
# Processing file 30124/30685
# Processing file 30125/30685
# Processing file 30126/30685
# Processing file 30127/30685
# Processing file 30128/30685
# Processing file 30129/30685
# Processing file 30130/30685
# Processing file 30131/30685
# Processing file 30132/30685
# Processing file 30133/30685
# Processing file 30134/30685
# Processing file 30135/30685
# Processing file 30136/30685
# Processing file 30137/30685
# Processing file 30138/30685
# Processing file 30139/30685
# Processing file 30140/30685
# Processing file 30141/30685
# Processing file 30142/30685
# Processing file 30143/30685
# Processing file 30144/30685
# Processing file 30145/30685
# Processing file 30146/30685
# Processing file 30147/30685
# Processing file 30148/30685
# Processing file 30149/30685
# Processing file 30150/30685
# Processing file 30151/30685
# Processing file 30152/30685
# Processing file 30153/30685
# Processing file 30154/30685
# Processing file 30155/30685
# Processing file 30156/30685
# Processing file 30157/30685
# Processing file 30158/30685
# Processing file 30159/30685
# Processing file 30160/30685
# Processing file 30161/30685
# Processing file 30162/30685
# Processing file 30163/30685
# Processing file 30164/30685
# Processing file 30165/30685
# Processing file 30166/30685
# Processing file 30167/30685
# Processing file 30168/30685
# Processing file 30169/30685
# Processing file 30170/30685
# Processing file 30171/30685
# Processing file 30172/30685
# Processing file 30173/30685
# Processing file 30174/30685
# Processing file 30175/30685
# Processing file 30176/30685
# Processing file 30177/30685
# Processing file 30178/30685
# Processing file 30179/30685
# Processing file 30180/30685
# Processing file 30181/30685
# Processing file 30182/30685
# Processing file 30183/30685
# Processing file 30184/30685
# Processing file 30185/30685
# Processing file 30186/30685
# Processing file 30187/30685
# Processing file 30188/30685
# Processing file 30189/30685
# Processing file 30190/30685
# Processing file 30191/30685
# Processing file 30192/30685
# Processing file 30193/30685
# Processing file 30194/30685
# Processing file 30195/30685
# Processing file 30196/30685
# Processing file 30197/30685
# Processing file 30198/30685
# Processing file 30199/30685
# Processing file 30200/30685
# Processing file 30201/30685
# Processing file 30202/30685
# Processing file 30203/30685
# Processing file 30204/30685
# Processing file 30205/30685
# Processing file 30206/30685
# Processing file 30207/30685
# Processing file 30208/30685
# Processing file 30209/30685
# Processing file 30210/30685
# Processing file 30211/30685
# Processing file 30212/30685
# Processing file 30213/30685
# Processing file 30214/30685
# Processing file 30215/30685
# Processing file 30216/30685
# Processing file 30217/30685
# Processing file 30218/30685
# Processing file 30219/30685
# Processing file 30220/30685
# Processing file 30221/30685
# Processing file 30222/30685
# Processing file 30223/30685
# Processing file 30224/30685
# Processing file 30225/30685
# Processing file 30226/30685
# Processing file 30227/30685
# Processing file 30228/30685
# Processing file 30229/30685
# Processing file 30230/30685
# Processing file 30231/30685
# Processing file 30232/30685
# Processing file 30233/30685
# Processing file 30234/30685
# Processing file 30235/30685
# Processing file 30236/30685
# Processing file 30237/30685
# Processing file 30238/30685
# Processing file 30239/30685
# Processing file 30240/30685
# Processing file 30241/30685
# Processing file 30242/30685
# Processing file 30243/30685
# Processing file 30244/30685
# Processing file 30245/30685
# Processing file 30246/30685
# Processing file 30247/30685
# Processing file 30248/30685
# Processing file 30249/30685
# Processing file 30250/30685
# Processing file 30251/30685
# Processing file 30252/30685
# Processing file 30253/30685
# Processing file 30254/30685
# Processing file 30255/30685
# Processing file 30256/30685
# Processing file 30257/30685
# Processing file 30258/30685
# Processing file 30259/30685
# Processing file 30260/30685
# Processing file 30261/30685
# Processing file 30262/30685
# Processing file 30263/30685
# Processing file 30264/30685
# Processing file 30265/30685
# Processing file 30266/30685
# Processing file 30267/30685
# Processing file 30268/30685
# Processing file 30269/30685
# Processing file 30270/30685
# Processing file 30271/30685
# Processing file 30272/30685
# Processing file 30273/30685
# Processing file 30274/30685
# Processing file 30275/30685
# Processing file 30276/30685
# Processing file 30277/30685
# Processing file 30278/30685
# Processing file 30279/30685
# Processing file 30280/30685
# Processing file 30281/30685
# Processing file 30282/30685
# Processing file 30283/30685
# Processing file 30284/30685
# Processing file 30285/30685
# Processing file 30286/30685
# Processing file 30287/30685
# Processing file 30288/30685
# Processing file 30289/30685
# Processing file 30290/30685
# Processing file 30291/30685
# Processing file 30292/30685
# Processing file 30293/30685
# Processing file 30294/30685
# Processing file 30295/30685
# Processing file 30296/30685
# Processing file 30297/30685
# Processing file 30298/30685
# Processing file 30299/30685
# Processing file 30300/30685
# Processing file 30301/30685
# Processing file 30302/30685
# Processing file 30303/30685
# Processing file 30304/30685
# Processing file 30305/30685
# Processing file 30306/30685
# Processing file 30307/30685
# Processing file 30308/30685
# Processing file 30309/30685
# Processing file 30310/30685
# Processing file 30311/30685
# Processing file 30312/30685
# Processing file 30313/30685
# Processing file 30314/30685
# Processing file 30315/30685
# Processing file 30316/30685
# Processing file 30317/30685
# Processing file 30318/30685
# Processing file 30319/30685
# Processing file 30320/30685
# Processing file 30321/30685
# Processing file 30322/30685
# Processing file 30323/30685
# Processing file 30324/30685
# Processing file 30325/30685
# Processing file 30326/30685
# Processing file 30327/30685
# Processing file 30328/30685
# Processing file 30329/30685
# Processing file 30330/30685
# Processing file 30331/30685
# Processing file 30332/30685
# Processing file 30333/30685
# Processing file 30334/30685
# Processing file 30335/30685
# Processing file 30336/30685
# Processing file 30337/30685
# Processing file 30338/30685
# Processing file 30339/30685
# Processing file 30340/30685
# Processing file 30341/30685
# Processing file 30342/30685
# Processing file 30343/30685
# Processing file 30344/30685
# Processing file 30345/30685
# Processing file 30346/30685
# Processing file 30347/30685
# Processing file 30348/30685
# Processing file 30349/30685
# Processing file 30350/30685
# Processing file 30351/30685
# Processing file 30352/30685
# Processing file 30353/30685
# Processing file 30354/30685
# Processing file 30355/30685
# Processing file 30356/30685
# Processing file 30357/30685
# Processing file 30358/30685
# Processing file 30359/30685
# Processing file 30360/30685
# Processing file 30361/30685
# Processing file 30362/30685
# Processing file 30363/30685
# Processing file 30364/30685
# Processing file 30365/30685
# Processing file 30366/30685
# Processing file 30367/30685
# Processing file 30368/30685
# Processing file 30369/30685
# Processing file 30370/30685
# Processing file 30371/30685
# Processing file 30372/30685
# Processing file 30373/30685
# Processing file 30374/30685
# Processing file 30375/30685
# Processing file 30376/30685
# Processing file 30377/30685
# Processing file 30378/30685
# Processing file 30379/30685
# Processing file 30380/30685
# Processing file 30381/30685
# Processing file 30382/30685
# Processing file 30383/30685
# Processing file 30384/30685
# Processing file 30385/30685
# Processing file 30386/30685
# Processing file 30387/30685
# Processing file 30388/30685
# Processing file 30389/30685
# Processing file 30390/30685
# Processing file 30391/30685
# Processing file 30392/30685
# Processing file 30393/30685
# Processing file 30394/30685
# Processing file 30395/30685
# Processing file 30396/30685
# Processing file 30397/30685
# Processing file 30398/30685
# Processing file 30399/30685
# Processing file 30400/30685
# Processing file 30401/30685
# Processing file 30402/30685
# Processing file 30403/30685
# Processing file 30404/30685
# Processing file 30405/30685
# Processing file 30406/30685
# Processing file 30407/30685
# Processing file 30408/30685
# Processing file 30409/30685
# Processing file 30410/30685
# Processing file 30411/30685
# Processing file 30412/30685
# Processing file 30413/30685
# Processing file 30414/30685
# Processing file 30415/30685
# Processing file 30416/30685
# Processing file 30417/30685
# Processing file 30418/30685
# Processing file 30419/30685
# Processing file 30420/30685
# Processing file 30421/30685
# Processing file 30422/30685
# Processing file 30423/30685
# Processing file 30424/30685
# Processing file 30425/30685
# Processing file 30426/30685
# Processing file 30427/30685
# Processing file 30428/30685
# Processing file 30429/30685
# Processing file 30430/30685
# Processing file 30431/30685
# Processing file 30432/30685
# Processing file 30433/30685
# Processing file 30434/30685
# Processing file 30435/30685
# Processing file 30436/30685
# Processing file 30437/30685
# Processing file 30438/30685
# Processing file 30439/30685
# Processing file 30440/30685
# Processing file 30441/30685
# Processing file 30442/30685
# Processing file 30443/30685
# Processing file 30444/30685
# Processing file 30445/30685
# Processing file 30446/30685
# Processing file 30447/30685
# Processing file 30448/30685
# Processing file 30449/30685
# Processing file 30450/30685
# Processing file 30451/30685
# Processing file 30452/30685
# Processing file 30453/30685
# Processing file 30454/30685
# Processing file 30455/30685
# Processing file 30456/30685
# Processing file 30457/30685
# Processing file 30458/30685
# Processing file 30459/30685
# Processing file 30460/30685
# Processing file 30461/30685
# Processing file 30462/30685
# Processing file 30463/30685
# Processing file 30464/30685
# Processing file 30465/30685
# Processing file 30466/30685
# Processing file 30467/30685
# Processing file 30468/30685
# Processing file 30469/30685
# Processing file 30470/30685
# Processing file 30471/30685
# Processing file 30472/30685
# Processing file 30473/30685
# Processing file 30474/30685
# Processing file 30475/30685
# Processing file 30476/30685
# Processing file 30477/30685
# Processing file 30478/30685
# Processing file 30479/30685
# Processing file 30480/30685
# Processing file 30481/30685
# Processing file 30482/30685
# Processing file 30483/30685
# Processing file 30484/30685
# Processing file 30485/30685
# Processing file 30486/30685
# Processing file 30487/30685
# Processing file 30488/30685
# Processing file 30489/30685
# Processing file 30490/30685
# Processing file 30491/30685
# Processing file 30492/30685
# Processing file 30493/30685
# Processing file 30494/30685
# Processing file 30495/30685
# Processing file 30496/30685
# Processing file 30497/30685
# Processing file 30498/30685
# Processing file 30499/30685
# Processing file 30500/30685
# Processing file 30501/30685
# Processing file 30502/30685
# Processing file 30503/30685
# Processing file 30504/30685
# Processing file 30505/30685
# Processing file 30506/30685
# Processing file 30507/30685
# Processing file 30508/30685
# Processing file 30509/30685
# Processing file 30510/30685
# Processing file 30511/30685
# Processing file 30512/30685
# Processing file 30513/30685
# Processing file 30514/30685
# Processing file 30515/30685
# Processing file 30516/30685
# Processing file 30517/30685
# Processing file 30518/30685
# Processing file 30519/30685
# Processing file 30520/30685
# Processing file 30521/30685
# Processing file 30522/30685
# Processing file 30523/30685
# Processing file 30524/30685
# Processing file 30525/30685
# Processing file 30526/30685
# Processing file 30527/30685
# Processing file 30528/30685
# Processing file 30529/30685
# Processing file 30530/30685
# Processing file 30531/30685
# Processing file 30532/30685
# Processing file 30533/30685
# Processing file 30534/30685
# Processing file 30535/30685
# Processing file 30536/30685
# Processing file 30537/30685
# Processing file 30538/30685
# Processing file 30539/30685
# Processing file 30540/30685
# Processing file 30541/30685
# Processing file 30542/30685
# Processing file 30543/30685
# Processing file 30544/30685
# Processing file 30545/30685
# Processing file 30546/30685
# Processing file 30547/30685
# Processing file 30548/30685
# Processing file 30549/30685
# Processing file 30550/30685
# Processing file 30551/30685
# Processing file 30552/30685
# Processing file 30553/30685
# Processing file 30554/30685
# Processing file 30555/30685
# Processing file 30556/30685
# Processing file 30557/30685
# Processing file 30558/30685
# Processing file 30559/30685
# Processing file 30560/30685
# Processing file 30561/30685
# Processing file 30562/30685
# Processing file 30563/30685
# Processing file 30564/30685
# Processing file 30565/30685
# Processing file 30566/30685
# Processing file 30567/30685
# Processing file 30568/30685
# Processing file 30569/30685
# Processing file 30570/30685
# Processing file 30571/30685
# Processing file 30572/30685
# Processing file 30573/30685
# Processing file 30574/30685
# Processing file 30575/30685
# Processing file 30576/30685
# Processing file 30577/30685
# Processing file 30578/30685
# Processing file 30579/30685
# Processing file 30580/30685
# Processing file 30581/30685
# Processing file 30582/30685
# Processing file 30583/30685
# Processing file 30584/30685
# Processing file 30585/30685
# Processing file 30586/30685
# Processing file 30587/30685
# Processing file 30588/30685
# Processing file 30589/30685
# Processing file 30590/30685
# Processing file 30591/30685
# Processing file 30592/30685
# Processing file 30593/30685
# Processing file 30594/30685
# Processing file 30595/30685
# Processing file 30596/30685
# Processing file 30597/30685
# Processing file 30598/30685
# Processing file 30599/30685
# Processing file 30600/30685
# Processing file 30601/30685
# Processing file 30602/30685
# Processing file 30603/30685
# Processing file 30604/30685
# Processing file 30605/30685
# Processing file 30606/30685
# Processing file 30607/30685
# Processing file 30608/30685
# Processing file 30609/30685
# Processing file 30610/30685
# Processing file 30611/30685
# Processing file 30612/30685
# Processing file 30613/30685
# Processing file 30614/30685
# Processing file 30615/30685
# Processing file 30616/30685
# Processing file 30617/30685
# Processing file 30618/30685
# Processing file 30619/30685
# Processing file 30620/30685
# Processing file 30621/30685
# Processing file 30622/30685
# Processing file 30623/30685
# Processing file 30624/30685
# Processing file 30625/30685
# Processing file 30626/30685
# Processing file 30627/30685
# Processing file 30628/30685
# Processing file 30629/30685
# Processing file 30630/30685
# Processing file 30631/30685
# Processing file 30632/30685
# Processing file 30633/30685
# Processing file 30634/30685
# Processing file 30635/30685
# Processing file 30636/30685
# Processing file 30637/30685
# Processing file 30638/30685
# Processing file 30639/30685
# Processing file 30640/30685
# Processing file 30641/30685
# Processing file 30642/30685
# Processing file 30643/30685
# Processing file 30644/30685
# Processing file 30645/30685
# Processing file 30646/30685
# Processing file 30647/30685
# Processing file 30648/30685
# Processing file 30649/30685
# Processing file 30650/30685
# Processing file 30651/30685
# Processing file 30652/30685
# Processing file 30653/30685
# Processing file 30654/30685
# Processing file 30655/30685
# Processing file 30656/30685
# Processing file 30657/30685
# Processing file 30658/30685
# Processing file 30659/30685
# Processing file 30660/30685
# Processing file 30661/30685
# Processing file 30662/30685
# Processing file 30663/30685
# Processing file 30664/30685
# Processing file 30665/30685
# Processing file 30666/30685
# Processing file 30667/30685
# Processing file 30668/30685
# Processing file 30669/30685
# Processing file 30670/30685
# Processing file 30671/30685
# Processing file 30672/30685
# Processing file 30673/30685
# Processing file 30674/30685
# Processing file 30675/30685
# Processing file 30676/30685
# Processing file 30677/30685
# Processing file 30678/30685
# Processing file 30679/30685
# Processing file 30680/30685
# Processing file 30681/30685
# Processing file 30682/30685
# Processing file 30683/30685
# Processing file 30684/30685
# Processing file 30685/30685

# %%
print(input_data.shape)  # (n, 200, 200, 1) 
print(labels.shape)      # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
type(input_data)
# Out:
# numpy.ndarray

# %%
type(labels)
# Out:
# numpy.ndarray

# %%
def check_duplicates_within_set(X, Y):
    unique_X, unique_indices = np.unique(X, axis=0, return_index=True)
    unique_Y = Y[unique_indices]

    print(f"{len(X)-len(unique_X)} duplicates found.")

    return unique_X, unique_Y

# %%
X, Y = check_duplicates_within_set(input_data, labels)
# Out:
# 0 duplicates found.

# %%
print(X.shape)  # (n, 200, 200, 1) 
print(Y.shape)  # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, stratify=Y, test_size=0.4, random_state=42) # stratify with labels (Y)

# %%
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5, random_state=42)

# %%
print(X_train.shape)  # (n, 200, 200, 1)
print(X_test.shape)   # (n, 200, 200, 1)
print(X_val.shape)    # (n, 200, 200, 1)
# Out:
# (7722, 200, 200, 1)
# (2574, 200, 200, 1)
# (2574, 200, 200, 1)

# %%
print(Y_train.shape)  # (n,) 
print(Y_test.shape)   # (n,) 
print(Y_val.shape)    # (n,)
# Out:
# (7722,)
# (2574,)
# (2574,)

# %% [markdown]
# *The training set, validation set and test set were split in the ratio 60 : 20 : 20.*

# %% [markdown]
# ## Augmentation

# %%
def custom_rotation(x):
    angle = np.random.choice([90, 180, 270])  # Randomly selects between 90, 180, and 270 degrees
    return np.rot90(x, k=angle // 90)  # k specifies the number of 90° rotations

# Define data augmentation (only for training data)
datagen = ImageDataGenerator(
    preprocessing_function=custom_rotation,  # Limit rotations to 90°, 180°, and 270°
    horizontal_flip=True,   # Flip images horizontally
)

# Fit the generator to the training data
datagen.fit(X_train)

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Check if x any y fit together

# %%
X_train[1].shape
# Out:
# (200, 200, 1)

# %%
type(X_train[1])
# Out:
# numpy.ndarray

# %%
# Convert to float32
image = X_train[1].squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()

# %%
Y_train[1]
# Out:
# 0.636

# %% [markdown]
# ### Check histogramm for image values

# %%
plt.hist(X_train[1].flatten(), bins=50, range=(0, 1))
plt.title('Verteilung der Pixelwerte')
plt.show()

# %%
print(f"Min: {np.min(X_train)}, Max: {np.max(X_train)}")
# Out:
# Min: 0.1412353515625, Max: 1.0

# %% [markdown]
# ### Check if null or inf values in train_y

# %%
assert not np.any(np.isnan(image)), "NaN-values found"
assert not np.any(np.isinf(image)), "infinite values found"
assert X_train[5].shape == (200, 200, 1), "image has unexpected form"

# %% [markdown]
# ### Check Data Distribution

# %%
# Plot histogram
plt.hist(Y_train, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Train")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_test, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Test")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_val, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Val")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Training

# %%
logdir = r'..\logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    r'..\checkpoints\best_weights.weights.h5',
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    initial_value_threshold=None
)

# %% [markdown]
# *It was trained with the Keras library on an Intel® Core™ I7-4970 CPU running at 3.60 GHz using 8 parallel processing units. Training was completed in 5 h—for 30 epochs total. A batch size of 32 was used for the training.*
#
# I will instead use my GPU, since its simply way faster.

# %%
# Check if GPU's are available
gpus = tf.config.list_physical_devices('GPU')
print(f"{len(gpus)} GPUs erkannt:")
for gpu in gpus:
    print(gpu)
# Out:
# 1 GPUs erkannt:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# If a GPU is available, enable memory growth (prevents memory issues)
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled.")
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %% [markdown]
# *Verify loss @ init. Verify that your loss starts at the correct loss value*

# %%
# Calculate the initial loss before training
init_loss = model.evaluate(X_val, Y_val, verbose=1)
print(f"Initial Loss: {init_loss[0]}")  # Should be approximately 1/3
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747057716.792407  183248 service.cc:152] XLA service 0x7f1970002390 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747057716.792539  183248 service.cc:160]   StreamExecutor device (0): NVIDIA A30 MIG 4g.24gb, Compute Capability 8.0
# 2025-05-12 13:48:36.998356: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 13:48:36.999011: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-12 13:48:37.004025: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747057717.460792  183248 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-05-12 13:48:38.228755: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 309.01MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-05-12 13:48:38.230839: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 308.99MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 12/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - RootMeanSquaredError: 0.2149 - loss: 0.0462
# I0000 00:00:1747057721.023213  183248 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - RootMeanSquaredError: 0.2192 - loss: 0.0481
# 2025-05-12 13:48:42.288444: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 13:48:42.288538: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - RootMeanSquaredError: 0.2192 - loss: 0.0481
# Initial Loss: 0.04814057797193527

# %%
# CALLBACKS (optional)

# EarlyStopping callback, stops training when validation loss does not improve
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# ModelCheckpoint callback, saves the best model based on validation loss
# checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)

def scheduler(epoch, lr): # Exponential Decay
    decay_rate = 0.90     # reduced 10% every decay_epochs...
    decay_epoch = 100     
    return lr * decay_rate**(epoch // decay_epoch)

lr_scheduler = LearningRateScheduler(scheduler)

# HYPERPARAMETER

batch_size = 32    # the original paper used a batch size of 32
epochs = 1000       # the original paper used 30 epochs 
shuffle = True

hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=batch_size),  # Use the generator here
    epochs=epochs,
    validation_data=(X_val, Y_val),
    shuffle=shuffle,
    verbose=0,  # muss 0 sein für tqdm
    callbacks=[TqdmCallback(verbose=1), lr_scheduler, early_stopping]
)
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# /opt/conda/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-05-12 13:48:51.954126: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 13:48:51.955743: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-12 13:48:58.226394: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 13:48:58.226494: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert

# %% [markdown]
# ## Plot Train, Test and Val Loss

# %% [markdown]
# *add significant digits to your eval. When plotting the test loss run the evaluation over the entire (large) test set. Do not just plot test losses over batches and then rely on smoothing them in Tensorboard. We are in pursuit of correctness and are very willing to give up time for staying sane.*

# %%
# Evaluation on the entire test set
test_loss = model.evaluate(X_test, Y_test, batch_size = 1, verbose=1)
# Out:
# 2025-05-12 14:06:45.714699: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 14:06:45.714814: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_2_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2574/2574 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - RootMeanSquaredError: 0.1123 - loss: 0.0126

# %%
print(hist.history.keys())
# Out:
# dict_keys(['RootMeanSquaredError', 'loss', 'val_RootMeanSquaredError', 'val_loss', 'learning_rate'])

# %%
print(hist.history)
# Out:
# {'RootMeanSquaredError': [0.3951779007911682, 0.360304057598114, 0.33927157521247864, 0.3178279399871826, 0.2970387935638428, 0.2765515446662903, 0.2568444609642029, 0.2366405725479126, 0.21862557530403137, 0.2013474702835083, 0.18416079878807068, 0.1696484088897705, 0.15540093183517456, 0.14522068202495575, 0.13528157770633698, 0.12747563421726227, 0.12206495553255081, 0.11794238537549973, 0.11540008336305618, 0.11475628614425659, 0.11192275583744049, 0.1117221787571907, 0.11171340197324753, 0.11222042143344879, 0.1122264638543129, 0.1130155473947525, 0.11143290996551514, 0.11134970933198929, 0.11074771732091904, 0.11128537356853485, 0.11080899089574814, 0.11153433471918106, 0.11077074706554413, 0.1111765131354332, 0.1105773076415062, 0.11087295413017273, 0.11111146956682205, 0.11012569069862366, 0.1102670356631279, 0.11045481264591217, 0.11031040549278259, 0.1106872484087944, 0.11038918048143387, 0.11031615734100342, 0.11037459224462509, 0.11014603078365326, 0.10991609841585159, 0.1099541187286377, 0.10981743782758713, 0.10982627421617508, 0.10979537665843964, 0.11035428941249847, 0.10981233417987823, 0.10985157638788223, 0.10991878807544708, 0.11035113781690598, 0.11018918454647064, 0.11015584319829941, 0.11007040739059448, 0.10971710085868835, 0.10954108089208603, 0.10978435724973679, 0.109565369784832, 0.10980280488729477, 0.10978277027606964, 0.10987801849842072, 0.10948847979307175, 0.11015634983778, 0.10970534384250641, 0.10942352563142776, 0.10909954458475113, 0.109415702521801, 0.10922695696353912, 0.10988573729991913, 0.10951342433691025, 0.10962717980146408, 0.10981505364179611, 0.10997172445058823, 0.1092902198433876, 0.10952876508235931, 0.10935784876346588, 0.10937640070915222, 0.1095777153968811, 0.109435074031353, 0.10914067924022675, 0.10971622169017792, 0.10932999104261398, 0.10932481288909912, 0.10898257046937943, 0.10934232920408249, 0.10909721255302429, 0.10941044241189957, 0.10978586971759796, 0.10949745029211044, 0.10952148586511612, 0.10920687764883041, 0.10916010290384293, 0.109101802110672, 0.10982083529233932, 0.10902566462755203, 0.1092134565114975, 0.10903912782669067, 0.10884147137403488, 0.10898958891630173, 0.10846215486526489, 0.108673594892025, 0.1085214912891388, 0.10859225690364838, 0.10840439796447754, 0.10820238292217255, 0.10817594081163406, 0.10817141085863113, 0.10813149064779282, 0.10803279280662537, 0.1080206036567688, 0.10804517567157745, 0.10814570635557175, 0.10791745781898499, 0.10800153017044067, 0.1080550104379654, 0.10798585414886475, 0.10795183479785919, 0.10788953304290771, 0.10781307518482208, 0.10787451267242432, 0.10796096175909042, 0.10781517624855042, 0.10785937309265137, 0.10785601288080215, 0.10785423964262009, 0.10784099996089935, 0.10780177265405655, 0.10782540589570999, 0.10784249007701874, 0.10777463763952255, 0.10780534148216248, 0.1077846884727478, 0.1078285202383995, 0.10779855400323868, 0.10784459859132767, 0.10776421427726746, 0.10777562856674194, 0.1077830120921135, 0.10776231437921524, 0.1078023910522461, 0.10777503997087479, 0.10775458067655563, 0.10777844488620758, 0.10782323777675629, 0.10780008882284164, 0.10781307518482208, 0.10779119282960892, 0.1078171581029892, 0.10777825862169266, 0.10780651867389679, 0.1077737808227539, 0.10781080275774002, 0.10777028650045395, 0.10779912024736404, 0.10778556019067764, 0.10782185941934586, 0.10776196420192719, 0.10783814638853073, 0.10778317600488663, 0.10779024660587311, 0.10778991132974625, 0.10779184103012085, 0.10777775198221207, 0.10779700428247452, 0.10780812799930573, 0.10776043683290482, 0.1077655479311943, 0.10774155706167221, 0.10778842121362686, 0.10783118009567261, 0.1077737957239151, 0.10780881345272064, 0.10780797153711319, 0.10780511051416397, 0.1077798381447792, 0.10776561498641968, 0.10780831426382065, 0.1078045591711998, 0.10779023915529251, 0.10776598006486893, 0.10777153074741364, 0.1077844500541687, 0.10778986662626266, 0.10778477042913437, 0.10780001431703568, 0.10774508863687515, 0.107738159 ...

# %%
# Mean Squared Errors (Loss)
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='train_loss', marker='.')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss', marker='.')
plt.axhline(y=test_loss[0], color='gray', linestyle='--', label='test_loss (final)')
plt.ylim(0, 0.1) # try commenting this...
fig.suptitle('Loss = Mean Squared Error', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
# # Root Mean Squared Errors (Metric) 
fig = plt.figure()
plt.plot(hist.history['RootMeanSquaredError'], color='teal', label='train_rmse', marker='.') # depends on tensorflow version if root_mean_squared_error or RootMeanSquaredError
plt.plot(hist.history['val_RootMeanSquaredError'], color='orange', label='val_rmse', marker='.')
plt.axhline(y=test_loss[1], color='gray', linestyle='--', label='test_rmse (final)')
plt.ylim(0, 1)
fig.suptitle('Root Mean Squared Error', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Evaluate Performance

# %% [markdown]
# The labels from the paper are in a range from 0.06 to 0.65.

# %% [markdown]
# ### Performance

# %%
mse = MeanSquaredError()
rmse = RootMeanSquaredError()
mape = MeanAbsolutePercentageError()
mae = MeanAbsoluteError()

# %%
batch_size = 1  # If your model was trained with batches (for a more accurate test, it's still better to use 1)

y_true = []
y_pred = []

# Calculate metrics over all test data in batches
for i in range(0, len(X_test), batch_size):
    X_batch = X_test[i:i+batch_size]  # Take a batch of test data
    y_batch = Y_test[i:i+batch_size]  # Corresponding labels
    yhat_batch = model.predict(X_batch, verbose=0)  # Model prediction for the batch
    
    # Store true values and predictions
    y_true.append(y_batch)
    y_pred.append(yhat_batch)

    # Update metrics
    mse.update_state(y_batch, yhat_batch)
    rmse.update_state(y_batch, yhat_batch)
    mae.update_state(y_batch, yhat_batch)
    mape.update_state(y_batch, yhat_batch)
    
y_true = np.concatenate(y_true, axis=0)
y_pred = np.concatenate(y_pred, axis=0)

# R²-Score
r2 = r2_score(y_true, y_pred)

# %%
print(f"Mean Squared Error (MSE): {mse.result().numpy():.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse.result().numpy():.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape.result().numpy():.2f}%")
print(f"Mean Absolute Error (MAPE): {mae.result().numpy():.2f}")
print(f"R²-Score: {r2}")
# Out:
# Mean Squared Error (MSE): 0.0122
# Root Mean Squared Error (RMSE): 0.1103
# Mean Absolute Percentage Error (MAPE): 23.85%
# Mean Absolute Error (MAPE): 0.08
# R²-Score: 0.002454519271850586

# %% [markdown]
# ## Predict SDAS for some specific test image

# %%
test_index = 1001
test_image = X_test[test_index]
test_label = Y_test[test_index]

print(test_image.shape)

# Convert Image to float32 numpy array
image = test_image.squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()
# Out:
# (200, 200, 1)

# %%
print(np.expand_dims(test_image, axis=0).shape)
# Out:
# (1, 200, 200, 1)

# %%
yhat = model.predict(np.expand_dims(test_image, axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
print("Ground Truth S_value: ", test_label*100)
print("Predicted S_value: ", round(yhat[0][0] * 100, 2))
# Out:
# Ground Truth S_value:  27.2705078125
# Predicted S_value:  37.42

# %% [markdown]
# ## Export Model

# %%
model.save(os.path.join(r'../models', 'EfficientNetB0_v2.keras'), save_format="keras")

# %% [markdown]
# ## Make Predictions on real images

# %%
#test_dataset_version = "bmw_data" #210 images

test_dir = r'../data/bmw_test'

# %%
min_size = 200

results = []

# for all images in test_dir
for idx, img_name in enumerate(os.listdir(test_dir)):
    if img_name.endswith('.jpg') or img_name.endswith('.png'):
        
        img_path = os.path.join(test_dir, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        height, width = img.shape
        
        # Calculate the number of tiles
        rows = height // min_size
        cols = width // min_size
        
        # Split the image into tiles
        images = []
        for i in range(rows):
            for j in range(cols):
                y_start = i * min_size
                x_start = j * min_size
                y_end = min(y_start + min_size, height)
                x_end = min(x_start + min_size, width)
                image = img[y_start:y_end, x_start:x_end]
                images.append(image)
        
        # Collect model predictions
        predictions = []
        for image in images:
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction)
        
        # Calculate the prediction
        S_value_pred = np.median(predictions) * 100 # * 100, because we normalized the data when we imported it 
        
        SDAS_pred = S_value_pred * F_value  
        
        # Extract the actual SDAS value from the filename
        try:
            SDAS_true = float(img_name.split('_')[1])
            results.append((SDAS_true, SDAS_pred))
        except:
            print(f"Warning: Couldn't extract SDAS-value from '{img_name}'!")

        if idx % 5 == 0:
            print(f"⏳ Processed {idx}/{len(os.listdir(test_dir))} images...")

# %%
# Separate true and predicted values
y_true = [true for true, pred in results]
y_pred = [pred for true, pred in results]

# Calculate the metrics
SDAS_mse = mean_squared_error(y_true, y_pred)
SDAS_rmse = np.sqrt(SDAS_mse)
SDAS_mae = mean_absolute_error(y_true, y_pred)
SDAS_r2 = r2_score(y_true, y_pred)

# MAPE (with protection against division by zero)
y_true_array = np.array(y_true)
y_pred_array = np.array(y_pred)
SDAS_mape = np.mean(np.abs((y_true_array - y_pred_array) / y_true_array)) * 100

# Output the results
print(f"MSE: {SDAS_mse:.4f}")
print(f"RMSE: {SDAS_rmse:.4f}")
print(f"MAE: {SDAS_mae:.4f}")
print(f"MAPE: {SDAS_mape:.2f}%")
print(f"R²: {SDAS_r2:.4f}")

# %%
len(y_true_array)

# %%
#plotting predicted vs ground truth SDAS values for all images

plt.figure(figsize=(6, 6))  
plt.plot([0, 100], [0, 100], 'r--')  # Reference diagonal line
plt.scatter(y_true_array, y_pred_array)
plt.xlabel("Ground Truth SDAS")
plt.ylabel("Predicted SDAS")
plt.axis("equal")  # Ensure equal scaling on both axes
plt.title("Predicted vs. Ground Truth SDAS")
plt.show()

# %% [markdown]
# ## Showing Sclices Predictions for an given image

# %%
def process_image(test_dir, img_name, model):
    img_path = os.path.join(test_dir, img_name)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    height, width = img.shape
    
    # Calculate the number of tiles
    rows = height // min_size
    cols = width // min_size
    
    # Split the image into tiles
    images = []
    predictions = []
    for i in range(rows):
        for j in range(cols):
            y_start = i * min_size
            x_start = j * min_size
            y_end = min(y_start + min_size, height)
            x_end = min(x_start + min_size, width)
            image = img[y_start:y_end, x_start:x_end]
            images.append(image)
            
            # Normalize and resize the image for prediction
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # Add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction * 100 * F_value)
    
    return img, predictions, rows, cols

def plot_heatmap_with_image(img, predictions, rows, cols, min_size):
    # Reshape predictions to match the number of tiles
    heatmap = np.array(predictions).reshape((rows, cols))
    
    # Create a figure
    plt.figure(figsize=(10, 10))
    
    # Display the original image
    plt.imshow(img, cmap='gray', extent=[0, img.shape[1], img.shape[0], 0])
    
    # Overlay the heatmap on top of the image
    plt.imshow(heatmap, cmap='jet', alpha=0.5, extent=[0, img.shape[1], img.shape[0], 0])
    
    # Add color bar (legend for the heatmap)
    cbar = plt.colorbar()
    cbar.set_label('SDAS Prediction')

    # Show the plot
    plt.title("Image with SDAS Heatmap Overlay")
    plt.show()

# %%
test_dir = r'../data/bmw_test'
img_name = 'AC_39_B9.jpg'  # Replace with the image you want to test

# Process the selected image
img, predictions, rows, cols = process_image(test_dir, img_name, model)

# %%
print(np.median(predictions))

# Plot the heatmap over the image
plot_heatmap_with_image(img, predictions, rows, cols, min_size)

# %% [markdown]
# ## ML-Flow

# %%
# !pip install --user mlflow
# !pip install mlflow

# %%
import mlflow
import mlflow.keras
from mlflow.tracking import MlflowClient

# %% [markdown]
# Tutorial: https://www.youtube.com/watch?v=6ngxBkx05Fs&ab_channel=codebasics
#
# What do we want to log for every run:
# - model (with summary)
# - hyperparameter
# - dataset version
# - metrics
# - notebook

# %% [markdown]
# Run "mlflow ui" in your CMD first!

# %%
# !mlflow --version

# %%
mlflow.set_experiment("SDAS_Prediciton")
mlflow.set_tracking_uri("file:../mlruns")

with mlflow.start_run(run_name = 'v1_CNN_paperArchitecture_bmw_unaugmented'): # change with every run 
    
    # Save hyperparameters
    
    mlflow.log_params({
        'learning_rate': learning_rate,
        'batch_size': batch_size,
        'epochs': epochs,
        'shuffle': shuffle,
        'optimizer': optimizer,
        # Save Data
        #'dataset_version': dataset_version,  
        #'test_dataset_version': test_dataset_version,
        'pixel_per_µm': pixel_per_µm
    }) 
    
    # Save metrics
    
    mlflow.log_metrics({
        'S_norm_Mean Squared Error': mse.result().numpy(),
        'S_norm_Root Mean Squared Error': rmse.result().numpy(), 
        'S_norm_Mean Absolute Percentage Error': mape.result().numpy(),
        'S_norm_Mean Absolute Error': mae.result().numpy(),
        'S_norm_R2-Score': r2,
        'SDAS_Mean Squared Error': SDAS_mse,
        'SDAS_Root_Mean Squared Error': SDAS_rmse,
        'SDAS_Mean Absolute Percentage Error': SDAS_mape, 
        'SDAS_Mean Absolute Error': SDAS_mae,
        'SDAS_R2-Score': SDAS_r2
    }) 
    
    # Save model
    
    if isinstance(model, tf.keras.Model):
        mlflow.keras.log_model(model, artifact_path="cnn_model")
    else:
        print("The model isn't from the type tf.keras.Model!") 
        
    # Save notebook
    
    mlflow.log_artifact("CNN_SDAS_Prediction_Pipeline.ipynb", artifact_path="notebooks") # Name of notebook has to be correct

# %% [markdown]
# ## Load model from ML-Flow

# %%
# Enter RunID and Path
run_id = input("Enter your RunID: ")  # Ersetze mit deiner RunID
model_path = "cnn_model"

# load model
loaded_model = mlflow.keras.load_model(f"runs:/{run_id}/{model_path}")

# print model architecture
loaded_model.summary()

# %%
y_pred = loaded_model.predict(X_test)
y_pred[:4]

# %%
# optional

client = MlflowClient()

# load hyperparameter and metrcis
run_data = client.get_run(run_id).data
print("Hyperparameter:", run_data.params)
print("Metriken:", run_data.metrics)

# download current notebook
client.download_artifacts(run_id, f"notebooks_from_mlflow/{run_id}.ipynb", "./")
