# %% [markdown]
# # Training a CNN for Image-Regression to predict the SDAS of a given image

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from opencv-python) (1.26.2)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np        #library for matrices (useful for data preparation)
import os                 #library for package manage
import cv2                #library for loading images
import tensorflow as tf   #library/framework for all kinds of machine learning tasks
import matplotlib.pyplot as plt #libary for visualisation
import random             #for random seeds

import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Input, Lambda
from tensorflow.keras.initializers import Constant, he_normal

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator #for Augmentation of Training Data

from tqdm.keras import TqdmCallback # for loading-bar
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

from tensorflow.keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2025-05-16 08:47:05.086611: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747385225.101937 1962213 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747385225.106441 1962213 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747385225.119801 1962213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747385225.119812 1962213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747385225.119814 1962213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747385225.119816 1962213 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-16 08:47:05.124081: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !nvidia-smi
# Out:
# Fri May 16 08:47:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A30                     On  |   00000000:E2:00.0 Off |                   On |
# | N/A   39C    P0             55W /  165W |                  N/A   |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | MIG devices:                                                                            |
# +------------------+----------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                     Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                       BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                  |        ECC|                       |
# |==================+==================================+===========+=======================|
# |  0    0   0   0  |               2MiB / 24050MiB    | 56      0 |  4   0    4    1    1 |
# |                  |                 1MiB / 32768MiB  |           |                       |
# +------------------+----------------------------------+-----------+-----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# speicher test

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
gpus
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17170983434649704123
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 23360897024
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1349804708616082304
# physical_device_desc: "device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]
# I0000 00:00:1747385228.436190 1962213 gpu_device.cc:2019] Created device /device:GPU:0 with 22278 MB memory:  -> device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0

# %% [markdown]
# fix random seed. Always use a fixed random seed to guarantee that when you run the code twice you will get the same outcome. This removes a factor of variation and will help keep you sane.

# %%
# 1. Python-Seed für allgemeine Zufallszahlen
random.seed(42)

# 2. NumPy-Seed für alle Operationen mit NumPy
np.random.seed(42)

# 3. TensorFlow-Seed für TensorFlow-Operationen
tf.random.set_seed(42)

# 4. Optional: OS-Level Seed für bestimmte Bibliotheken
os.environ['PYTHONHASHSEED'] = '42'

# %% [markdown]
# ## Model Architecture

# %%
def to_rgb(x):
    return tf.image.grayscale_to_rgb(x)

input_layer = Input(shape=(200, 200, 1))
x = Lambda(to_rgb)(input_layer)

base_model = Xception(weights='imagenet', include_top=False, input_shape=(200, 200, 3))
base_model.trainable = False

x = base_model(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
x = BatchNormalization()(x)
output = Dense(1, activation='linear', kernel_initializer=he_normal())(x)

model = Model(inputs=input_layer, outputs=output)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5)
model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError'])
# Out:
# I0000 00:00:1747385228.485110 1962213 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22278 MB memory:  -> device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0

# %%
# learning_rate = 0.00001 
# optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# # Modell kompilieren
# model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError']) #mse = mean sqaured error learning_rate=0.0005

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 200, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 200, 200, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 7, 7, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     6,422,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,284,393 (104.08 MB)
#  Trainable params: 27,229,737 (103.87 MB)
#  Non-trainable params: 54,656 (213.50 KB)

# %% [markdown]
# ## Import Dataset and Preprocessing

# %%
# Path to the folder containing the original images (no subfolders)
data_dir = r'../data/bmw_train'
image_exts = ('.jpeg', '.jpg', '.bmp', '.png')
pixel_per_micrometer = 1/0.728265817023213 # for our training data from bmw
F_value = 1.36/pixel_per_micrometer        # F_value from paper

# List all image filenames
files = [f for f in os.listdir(data_dir) if f.lower().endswith(image_exts)] 

tiles = []
labels = []
tile_size = 200

for idx, file in enumerate(files, 1):
    img_path = os.path.join(data_dir, file)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"⚠️ Could not load {file}, skipping.")
        continue

    # --- Extract label from filename exactly as in the original script ---
    try:
        filename_parts = file.split('_')
        if len(filename_parts) < 2:
            print(f"⚠️ Unexpected filename format: {file}")
            continue
        sdas_value_str = filename_parts[1]   # e.g., '33' from 'AC_33_B2.jpg'
        SDAS = float(sdas_value_str)         # Convert string to float
        s_value = round(SDAS / F_value, 2)  # Apply formula
    except Exception as e:
        print(f"⚠️ Error parsing label from '{file}': {e}")
        continue
        
    norm_label = s_value / 100.0  # Normalize to 0–1 range

    h, w = img.shape

    # Split image into 200×200 tiles
    for y in range(0, h, tile_size):
        for x in range(0, w, tile_size):
            tile = img[y:y+tile_size, x:x+tile_size]
            if tile.shape != (tile_size, tile_size):
                continue  # Skip incomplete tiles at the edges

            # Normalize pixel values and add channel dimension
            tile = tile.astype(np.float16) / 255.0
            tile = tile[..., np.newaxis]  # Shape: (200, 200, 1)

            tiles.append(tile)
            labels.append(norm_label)

            # Apply 90°, 180°, and 270° rotations and store them as additional samples
            # for k in [1, 2, 3]:  # 1 = 90°, 2 = 180°, 3 = 270°
            #     rotated = np.rot90(tile, k)  # Rotate k times 90° counter-clockwise
            #     tiles.append(rotated)
            #     labels.append(norm_label)

    if idx % 50 == 0:
        print(f"⏳ Processed {idx}/{len(files)} images...")

# Convert lists to NumPy arrays
input_data = np.array(tiles, dtype=np.float16)
labels     = np.array(labels, dtype=np.float16)

print(f"✅ Done: {input_data.shape[0]} tiles created, input shape {input_data.shape[1:]}")
# Out:
# ⏳ Processed 50/130 images...
# ⏳ Processed 100/130 images...
# ✅ Done: 12870 tiles created, input shape (200, 200, 1)
# Processing file 20769/30685
# Processing file 20770/30685
# Processing file 20771/30685
# Processing file 20772/30685
# Processing file 20773/30685
# Processing file 20774/30685
# Processing file 20775/30685
# Processing file 20776/30685
# Processing file 20777/30685
# Processing file 20778/30685
# Processing file 20779/30685
# Processing file 20780/30685
# Processing file 20781/30685
# Processing file 20782/30685
# Processing file 20783/30685
# Processing file 20784/30685
# Processing file 20785/30685
# Processing file 20786/30685
# Processing file 20787/30685
# Processing file 20788/30685
# Processing file 20789/30685
# Processing file 20790/30685
# Processing file 20791/30685
# Processing file 20792/30685
# Processing file 20793/30685
# Processing file 20794/30685
# Processing file 20795/30685
# Processing file 20796/30685
# Processing file 20797/30685
# Processing file 20798/30685
# Processing file 20799/30685
# Processing file 20800/30685
# Processing file 20801/30685
# Processing file 20802/30685
# Processing file 20803/30685
# Processing file 20804/30685
# Processing file 20805/30685
# Processing file 20806/30685
# Processing file 20807/30685
# Processing file 20808/30685
# Processing file 20809/30685
# Processing file 20810/30685
# Processing file 20811/30685
# Processing file 20812/30685
# Processing file 20813/30685
# Processing file 20814/30685
# Processing file 20815/30685
# Processing file 20816/30685
# Processing file 20817/30685
# Processing file 30627/30685
# Processing file 30628/30685
# Processing file 30629/30685
# Processing file 30630/30685
# Processing file 30631/30685
# Processing file 30632/30685
# Processing file 30633/30685
# Processing file 30634/30685
# Processing file 30635/30685
# Processing file 30636/30685
# Processing file 30637/30685
# Processing file 30638/30685
# Processing file 30639/30685
# Processing file 30640/30685
# Processing file 30641/30685
# Processing file 30642/30685
# Processing file 30643/30685
# Processing file 30644/30685
# Processing file 30645/30685
# Processing file 30646/30685
# Processing file 30647/30685
# Processing file 30648/30685
# Processing file 30649/30685
# Processing file 30650/30685
# Processing file 30651/30685
# Processing file 30652/30685
# Processing file 30653/30685
# Processing file 30654/30685
# Processing file 30655/30685
# Processing file 30656/30685
# Processing file 30657/30685
# Processing file 30658/30685
# Processing file 30659/30685
# Processing file 30660/30685
# Processing file 30661/30685
# Processing file 30662/30685
# Processing file 30663/30685
# Processing file 30664/30685
# Processing file 30665/30685
# Processing file 30666/30685
# Processing file 30667/30685
# Processing file 30668/30685
# Processing file 30669/30685
# Processing file 30670/30685
# Processing file 30671/30685
# Processing file 30672/30685
# Processing file 30673/30685
# Processing file 30674/30685
# Processing file 30675/30685
# Processing file 30676/30685
# Processing file 30677/30685
# Processing file 30678/30685
# Processing file 30679/30685
# Processing file 30680/30685
# Processing file 30681/30685
# Processing file 30682/30685
# Processing file 30683/30685
# Processing file 30684/30685
# Processing file 30685/30685

# %%
print(input_data.shape)  # (n, 200, 200, 1) 
print(labels.shape)      # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
type(input_data)
# Out:
# numpy.ndarray

# %%
type(labels)
# Out:
# numpy.ndarray

# %%
def check_duplicates_within_set(X, Y):
    unique_X, unique_indices = np.unique(X, axis=0, return_index=True)
    unique_Y = Y[unique_indices]

    print(f"{len(X)-len(unique_X)} duplicates found.")

    return unique_X, unique_Y

# %%
X, Y = check_duplicates_within_set(input_data, labels)
# Out:
# 0 duplicates found.

# %%
print(X.shape)  # (n, 200, 200, 1) 
print(Y.shape)  # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, stratify=Y, test_size=0.4, random_state=42) # stratify with labels (Y)

# %%
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5, random_state=42)

# %%
print(X_train.shape)  # (n, 200, 200, 1)
print(X_test.shape)   # (n, 200, 200, 1)
print(X_val.shape)    # (n, 200, 200, 1)
# Out:
# (7722, 200, 200, 1)
# (2574, 200, 200, 1)
# (2574, 200, 200, 1)

# %%
print(Y_train.shape)  # (n,) 
print(Y_test.shape)   # (n,) 
print(Y_val.shape)    # (n,)
# Out:
# (7722,)
# (2574,)
# (2574,)

# %% [markdown]
# *The training set, validation set and test set were split in the ratio 60 : 20 : 20.*

# %% [markdown]
# ## Augmentation

# %%
def custom_rotation(x):
    angle = np.random.choice([90, 180, 270])  # Randomly selects between 90, 180, and 270 degrees
    return np.rot90(x, k=angle // 90)  # k specifies the number of 90° rotations

# Define data augmentation (only for training data)
datagen = ImageDataGenerator(
    preprocessing_function=custom_rotation,  # Limit rotations to 90°, 180°, and 270°
    horizontal_flip=True,   # Flip images horizontally
)

# Fit the generator to the training data
datagen.fit(X_train)

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Check if x any y fit together

# %%
X_train[1].shape
# Out:
# (200, 200, 1)

# %%
type(X_train[1])
# Out:
# numpy.ndarray

# %%
# Convert to float32
image = X_train[1].squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()

# %%
Y_train[1]
# Out:
# 0.636

# %% [markdown]
# ### Check histogramm for image values

# %%
plt.hist(X_train[1].flatten(), bins=50, range=(0, 1))
plt.title('Verteilung der Pixelwerte')
plt.show()

# %%
print(f"Min: {np.min(X_train)}, Max: {np.max(X_train)}")
# Out:
# Min: 0.1412353515625, Max: 1.0

# %% [markdown]
# ### Check if null or inf values in train_y

# %%
assert not np.any(np.isnan(image)), "NaN-values found"
assert not np.any(np.isinf(image)), "infinite values found"
assert X_train[5].shape == (200, 200, 1), "image has unexpected form"

# %% [markdown]
# ### Check Data Distribution

# %%
# Plot histogram
plt.hist(Y_train, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Train")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_test, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Test")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_val, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Val")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Training

# %%
logdir = r'..\logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    r'..\checkpoints\best_weights.weights.h5',
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    initial_value_threshold=None
)

# %% [markdown]
# *It was trained with the Keras library on an Intel® Core™ I7-4970 CPU running at 3.60 GHz using 8 parallel processing units. Training was completed in 5 h—for 30 epochs total. A batch size of 32 was used for the training.*
#
# I will instead use my GPU, since its simply way faster.

# %%
# Check if GPU's are available
gpus = tf.config.list_physical_devices('GPU')
print(f"{len(gpus)} GPUs erkannt:")
for gpu in gpus:
    print(gpu)
# Out:
# 1 GPUs erkannt:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# If a GPU is available, enable memory growth (prevents memory issues)
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled.")
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %% [markdown]
# *Verify loss @ init. Verify that your loss starts at the correct loss value*

# %%
# Calculate the initial loss before training
init_loss = model.evaluate(X_val, Y_val, verbose=1)
print(f"Initial Loss: {init_loss[0]}")  # Should be approximately 1/3
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747385249.587021 1962557 service.cc:152] XLA service 0x7fb85c07a380 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747385249.587142 1962557 service.cc:160]   StreamExecutor device (0): NVIDIA A30 MIG 4g.24gb, Compute Capability 8.0
# 2025-05-16 08:47:29.643309: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-16 08:47:29.643971: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-16 08:47:29.654214: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747385249.958240 1962557 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  7/81 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - RootMeanSquaredError: 0.3809 - loss: 0.1451
# I0000 00:00:1747385252.263475 1962557 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 79/81 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - RootMeanSquaredError: 0.3870 - loss: 0.1498
# 2025-05-16 08:47:34.719328: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-16 08:47:34.719482: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - RootMeanSquaredError: 0.3870 - loss: 0.1498
# Initial Loss: 0.14977043867111206

# %%
# CALLBACKS (optional)

# EarlyStopping callback, stops training when validation loss does not improve
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# ModelCheckpoint callback, saves the best model based on validation loss
# checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)

def scheduler(epoch, lr): # Exponential Decay
    decay_rate = 0.90     # reduced 10% every decay_epochs...
    decay_epoch = 100     
    return lr * decay_rate**(epoch // decay_epoch)

lr_scheduler = LearningRateScheduler(scheduler)

# HYPERPARAMETER

batch_size = 32    # the original paper used a batch size of 32
epochs = 1000       # the original paper used 30 epochs 
shuffle = True

hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=batch_size),  # Use the generator here
    epochs=epochs,
    validation_data=(X_val, Y_val),
    shuffle=shuffle,
    verbose=0,  # muss 0 sein für tqdm 
    callbacks=[TqdmCallback(verbose=1), early_stopping, lr_scheduler] 
    #callbacks=[TqdmCallback(verbose=1, leave=True, tqdm_class=tqdm)]  # klassisch, kein Widget -> bug fix?
)
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# /opt/conda/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-05-16 08:47:50.317247: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-16 08:47:50.318707: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-16 08:48:11.222122: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-16 08:48:11.222256: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert

# %% [markdown]
# ## Plot Train, Test and Val Loss

# %% [markdown]
# *add significant digits to your eval. When plotting the test loss run the evaluation over the entire (large) test set. Do not just plot test losses over batches and then rely on smoothing them in Tensorboard. We are in pursuit of correctness and are very willing to give up time for staying sane.*

# %%
# Evaluation on the entire test set
test_loss = model.evaluate(X_test, Y_test, batch_size = 1, verbose=1)
# Out:
# 2025-05-16 10:05:03.121343: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-16 10:05:03.121684: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2574/2574 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - RootMeanSquaredError: 0.0658 - loss: 0.0043

# %%
print(hist.history.keys())
# Out:
# dict_keys(['RootMeanSquaredError', 'loss', 'val_RootMeanSquaredError', 'val_loss', 'learning_rate'])

# %%
print(hist.history)
# Out:
# {'RootMeanSquaredError': [0.6636510491371155, 0.4341406524181366, 0.3827950358390808, 0.34191009402275085, 0.3146340847015381, 0.29038769006729126, 0.26745283603668213, 0.247163787484169, 0.22688300907611847, 0.20929357409477234, 0.19040144979953766, 0.17335186898708344, 0.1585504710674286, 0.14484098553657532, 0.131632000207901, 0.11854516714811325, 0.10777749121189117, 0.10077675431966782, 0.09275525063276291, 0.08429355919361115, 0.08177674561738968, 0.07866442203521729, 0.07702812552452087, 0.07425469905138016, 0.07065378129482269, 0.07082197815179825, 0.06979506462812424, 0.06835391372442245, 0.06564459949731827, 0.06614111363887787, 0.0657162070274353, 0.06394845992326736, 0.06324046850204468, 0.06196167692542076, 0.061785873025655746, 0.061489734798669815, 0.06385244429111481, 0.05681915953755379, 0.057473015040159225, 0.05628958344459534, 0.05715363845229149, 0.05554438754916191, 0.053638968616724014, 0.05425068736076355, 0.056872718036174774, 0.054772526025772095, 0.05025326833128929, 0.049220554530620575, 0.05023420229554176, 0.05099133029580116, 0.04937927424907684, 0.04977007955312729, 0.04639153927564621, 0.04641908034682274, 0.04493223503232002, 0.04414617642760277, 0.04421219602227211, 0.04395348206162453, 0.04271342605352402, 0.04377061128616333, 0.041747547686100006, 0.04294860363006592, 0.041697777807712555, 0.0431625172495842, 0.041817180812358856, 0.04034074395895004, 0.04018901288509369, 0.03985762223601341, 0.03798254579305649, 0.039726462215185165, 0.039239514619112015, 0.03929486125707626, 0.03780915215611458, 0.039122238755226135, 0.03758242726325989, 0.035593174397945404, 0.03632982075214386, 0.03689822182059288, 0.038532
fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Evaluate Performance

# %% [markdown]
# The labels from the paper are in a range from 0.06 to 0.65.

# %% [markdown]
# ### Performance

# %%
mse = MeanSquaredError()
rmse = RootMeanSquaredError()
mape = MeanAbsolutePercentageError()
mae = MeanAbsoluteError()

# %%
batch_size = 1  # If your model was trained with batches (for a more accurate test, it's still better to use 1)

y_true = []
y_pred = []

# Calculate metrics over all test data in batches
for i in range(0, len(X_test), batch_size):
    X_batch = X_test[i:i+batch_size]  # Take a batch of test data
    y_batch = Y_test[i:i+batch_size]  # Corresponding labels
    yhat_batch = model.predict(X_batch, verbose=0)  # Model prediction for the batch
    
    # Store true values and predictions
    y_true.append(y_batch)
    y_pred.append(yhat_batch)

    # Update metrics
    mse.update_state(y_batch, yhat_batch)
    rmse.update_state(y_batch, yhat_batch)
    mae.update_state(y_batch, yhat_batch)
    mape.update_state(y_batch, yhat_batch)
    
y_true = np.concatenate(y_true, axis=0)
y_pred = np.concatenate(y_pred, axis=0)

# R²-Score
r2 = r2_score(y_true, y_pred)

# %%
print(f"Mean Squared Error (MSE): {mse.result().numpy():.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse.result().numpy():.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape.result().numpy():.2f}%")
print(f"Mean Absolute Error (MAPE): {mae.result().numpy():.2f}")
print(f"R²-Score: {r2}")
# Out:
# Mean Squared Error (MSE): 0.0045
# Root Mean Squared Error (RMSE): 0.0674
# Mean Absolute Percentage Error (MAPE): 13.49%
# Mean Absolute Error (MAPE): 0.05
# R²-Score: 0.6277598142623901

# %% [markdown]
# ## Predict SDAS for some specific test image

# %%
test_index = 1001
test_image = X_test[test_index]
test_label = Y_test[test_index]

print(test_image.shape)

# Convert Image to float32 numpy array
image = test_image.squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()
# Out:
# (200, 200, 1)

# %%
print(np.expand_dims(test_image, axis=0).shape)
# Out:
# (1, 200, 200, 1)

# %%
yhat = model.predict(np.expand_dims(test_image, axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
print("Ground Truth S_value: ", test_label*100)
print("Predicted S_value: ", round(yhat[0][0] * 100, 2))
# Out:
# Ground Truth S_value:  27.2705078125
# Predicted S_value:  33.02

# %% [markdown]
# ## Export Model

# %%
model.save(os.path.join(r'../models', 'Xception_v2.keras'))

# %% [markdown]
# ## Make Predictions on real images

# %%
#test_dataset_version = "bmw_data" #210 images

test_dir = r'../data/bmw_test'

# %%
min_size = 200

results = []

# for all images in test_dir
for idx, img_name in enumerate(os.listdir(test_dir)):
    if img_name.endswith('.jpg') or img_name.endswith('.png'):
        
        img_path = os.path.join(test_dir, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        height, width = img.shape
        
        # Calculate the number of tiles
        rows = height // min_size
        cols = width // min_size
        
        # Split the image into tiles
        images = []
        for i in range(rows):
            for j in range(cols):
                y_start = i * min_size
                x_start = j * min_size
                y_end = min(y_start + min_size, height)
                x_end = min(x_start + min_size, width)
                image = img[y_start:y_end, x_start:x_end]
                images.append(image)
        
        # Collect model predictions
        predictions = []
        for image in images:
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction)
        
        # Calculate the prediction
        S_value_pred = np.median(predictions) * 100 # * 100, because we normalized the data when we imported it 
        
        SDAS_pred = S_value_pred * F_value  
        
        # Extract the actual SDAS value from the filename
        try:
            SDAS_true = float(img_name.split('_')[1])
            results.append((SDAS_true, SDAS_pred))
        except:
            print(f"Warning: Couldn't extract SDAS-value from '{img_name}'!")

        if idx % 5 == 0:
            print(f"⏳ Processed {idx}/{len(os.listdir(test_dir))} images...")
# Out:
# ⏳ Processed 0/81 images...
# ⏳ Processed 5/81 images...
# ⏳ Processed 10/81 images...
# ⏳ Processed 15/81 images...
# ⏳ Processed 20/81 images...
# ⏳ Processed 25/81 images...
# ⏳ Processed 30/81 images...
# ⏳ Processed 35/81 images...
# ⏳ Processed 40/81 images...
# ⏳ Processed 45/81 images...
# ⏳ Processed 50/81 images...
# ⏳ Processed 55/81 images...
# ⏳ Processed 60/81 images...
# ⏳ Processed 65/81 images...
# ⏳ Processed 70/81 images...
# ⏳ Processed 75/81 images...
# ⏳ Processed 80/81 images...

# %%
# Separate true and predicted values
y_true = [true for true, pred in results]
y_pred = [pred for true, pred in results]

# Calculate the metrics
SDAS_mse = mean_squared_error(y_true, y_pred)
SDAS_rmse = np.sqrt(SDAS_mse)
SDAS_mae = mean_absolute_error(y_true, y_pred)
SDAS_r2 = r2_score(y_true, y_pred)

# MAPE (with protection against division by zero)
y_true_array = np.array(y_true)
y_pred_array = np.array(y_pred)
SDAS_mape = np.mean(np.abs((y_true_array - y_pred_array) / y_true_array)) * 100

# Output the results
print(f"MSE: {SDAS_mse:.4f}")
print(f"RMSE: {SDAS_rmse:.4f}")
print(f"MAE: {SDAS_mae:.4f}")
print(f"MAPE: {SDAS_mape:.2f}%")
print(f"R²: {SDAS_r2:.4f}")
# Out:
# MSE: 30.2686
# RMSE: 5.5017
# MAE: 4.0680
# MAPE: 11.43%
# R²: 0.7535

# %%
len(y_true_array)
# Out:
# 80

# %%
#plotting predicted vs ground truth SDAS values for all images

plt.figure(figsize=(6, 6))  
plt.plot([0, 100], [0, 100], 'r--')  # Reference diagonal line
plt.scatter(y_true_array, y_pred_array)
plt.xlabel("Ground Truth SDAS")
plt.ylabel("Predicted SDAS")
plt.axis("equal")  # Ensure equal scaling on both axes
plt.title("Predicted vs. Ground Truth SDAS")
plt.show()

# %% [markdown]
# ## Showing Sclices Predictions for an given image

# %%
def process_image(test_dir, img_name, model):
    img_path = os.path.join(test_dir, img_name)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    height, width = img.shape
    
    # Calculate the number of tiles
    rows = height // min_size
    cols = width // min_size
    
    # Split the image into tiles
    images = []
    predictions = []
    for i in range(rows):
        for j in range(cols):
            y_start = i * min_size
            x_start = j * min_size
            y_end = min(y_start + min_size, height)
            x_end = min(x_start + min_size, width)
            image = img[y_start:y_end, x_start:x_end]
            images.append(image)
            
            # Normalize and resize the image for prediction
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # Add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction * 100 * F_value)
    
    return img, predictions, rows, cols

def plot_heatmap_with_image(img, predictions, rows, cols, min_size):
    # Reshape predictions to match the number of tiles
    heatmap = np.array(predictions).reshape((rows, cols))
    
    # Create a figure
    plt.figure(figsize=(10, 10))
    
    # Display the original image
    plt.imshow(img, cmap='gray', extent=[0, img.shape[1], img.shape[0], 0])
    
    # Overlay the heatmap on top of the image
    plt.imshow(heatmap, cmap='jet', alpha=0.5, extent=[0, img.shape[1], img.shape[0], 0])
    
    # Add color bar (legend for the heatmap)
    cbar = plt.colorbar()
    cbar.set_label('SDAS Prediction')

    # Show the plot
    plt.title("Image with SDAS Heatmap Overlay")
    plt.show()

# %%
test_dir = r'../data/bmw_test'
img_name = 'AC_39_B9.jpg'  # Replace with the image you want to test

# Process the selected image
img, predictions, rows, cols = process_image(test_dir, img_name, model)

# %%
print(np.median(predictions))

# Plot the heatmap over the image
plot_heatmap_with_image(img, predictions, rows, cols, min_size)
# Out:
# 39.84345187368204

# %% [markdown]
# ## ML-Flow

# %%
# !pip install --user mlflow
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.22.0-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==2.22.0 (from mlflow)
#   Downloading mlflow_skinny-2.22.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.9.4)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.26.2)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.9/site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from mlflow) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.9/site-packages (from mlflow) (2.0.23)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading databricks_sdk-0.53.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (7.0.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading opentelemetry_api-1.33.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading opentelemetry_sdk-1.33.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (23.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.29.4)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.31.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Collecting uvicorn<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.0)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading google_auth-2.40.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.9/site-packages (from docker<8,>=4.0.0->mlflow) (2.1.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.22.0->mlflow)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from Flask<4->mlflow) (3.0.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.9/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.9/site-packages (from Flask<4->mlflow) (1.7.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/conda/lib/python3.9/site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (6.1.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting opentelemetry-semantic-conventions==0.54b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.54b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas<3->mlflow) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas<3->mlflow) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow)
#   Downloading pydantic_core-2.33.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2025.1.31)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/conda/lib/python3.9/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.2.0)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==2.22.0->mlflow)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.9/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.17.2)
# Downloading mlflow-2.22.0-py3-none-any.whl (29.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 42.0 MB/s eta 0:00:00a 0:00:01
# Downloading mlflow_skinny-2.22.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 37.2 MB/s eta 0:00:00
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading databricks_sdk-0.53.0-py3-none-any.whl (700 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 700.2/700.2 kB 43.6 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading google_auth-2.40.1-py2.py3-none-any.whl (216 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading opentelemetry_api-1.33.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_sdk-1.33.0-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.54b0-py3-none-any.whl (194 kB)
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.0 MB/s eta 0:00:00
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, sqlparse, smmap, pydantic-core, pyasn1, h11, gunicorn, graphql-core, deprecated, cachetools, annotated-types, uvicorn, starlette, rsa, pydantic, pyasn1-modules, opentelemetry-api, graphql-relay, gitdb, docker, opentelemetry-semantic-conventions, graphene, google-auth, gitpython, fastapi, opentelemetry-sdk, databricks-sdk, mlflow-skinny, mlflow
#   WARNING: The script sqlformat is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/29 [gunicorn]  WARNING: The script gunicorn is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 11/29 [uvicorn]  WARNING: The script uvicorn is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt, pyrsa-encrypt, pyrsa-keygen, pyrsa-priv2pub, pyrsa-sign and pyrsa-verify are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 22/29 [google-auth]ntic-conventions]  WARNING: The script fastapi is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 27/29 [mlflow-skinny]  WARNING: The script mlflow is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━ 28/29 [mlflow]  WARNING: The script mlflow is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [mlflow]28/29 [mlflow]
# Successfully installed annotated-types-0.7.0 cachetools-5.5.2 databricks-sdk-0.53.0 deprecated-1.2.18 docker-7.1.0 fastapi-0.115.12 gitdb-4.0.12 gitpython-3.1.44 google-auth-2.40.1 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 h11-0.16.0 mlflow-2.22.0 mlflow-skinny-2.22.0 opentelemetry-api-1.33.0 opentelemetry-sdk-1.33.0 opentelemetry-semantic-conventions-0.54b0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.4 pydantic-core-2.33.2 rsa-4.9.1 smmap-5.0.2 sqlparse-0.5.3 starlette-0.46.2 typing-inspection-0.4.0 uvicorn-0.34.2
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: mlflow in /home/jovyan/.local/lib/python3.9/site-packages (2.22.0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.9/site-packages (from mlflow) (3.9.4)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.26.2)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.9/site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from mlflow) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.9/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.9/site-packages (from mlflow) (2.0.23)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.53.0)
# Requirement already satisfied: fastapi<1 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (7.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.33.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.33.0)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (23.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.11.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.31.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Requirement already satisfied: uvicorn<1 in /home/jovyan/.local/lib/python3.9/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.34.2)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.0)
# Requirement already satisfied: google-auth~=2.0 in /home/jovyan/.local/lib/python3.9/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (2.40.1)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.9/site-packages (from docker<8,>=4.0.0->mlflow) (2.1.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/jovyan/.local/lib/python3.9/site-packages (from fastapi<1->mlflow-skinny==2.22.0->mlflow) (0.46.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from Flask<4->mlflow) (3.0.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.9/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.9/site-packages (from Flask<4->mlflow) (1.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jovyan/.local/lib/python3.9/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jovyan/.local/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jovyan/.local/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jovyan/.local/lib/python3.9/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/jovyan/.local/lib/python3.9/site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/jovyan/.local/lib/python3.9/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/conda/lib/python3.9/site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib<4->mlflow) (6.1.1)
# Requirement already satisfied: deprecated>=1.2.6 in /home/jovyan/.local/lib/python3.9/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b0 in /home/jovyan/.local/lib/python3.9/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.54b0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas<3->mlflow) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.9/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jovyan/.local/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/jovyan/.local/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/jovyan/.local/lib/python3.9/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2025.1.31)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/jovyan/.local/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/conda/lib/python3.9/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.2.0)
# Requirement already satisfied: h11>=0.8 in /home/jovyan/.local/lib/python3.9/site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.9/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.17.2)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import mlflow
import mlflow.keras
from mlflow.tracking import MlflowClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 import mlflow
#       2 import mlflow.keras
#       3 from mlflow.tracking import MlflowClient
#
# ModuleNotFoundError: No module named 'mlflow'

# %% [markdown]
# Tutorial: https://www.youtube.com/watch?v=6ngxBkx05Fs&ab_channel=codebasics
#
# What do we want to log for every run:
# - model (with summary)
# - hyperparameter
# - dataset version
# - metrics
# - notebook

# %% [markdown]
# Run "mlflow ui" in your CMD first!

# %%
# !mlflow --version

# %%
mlflow.set_experiment("SDAS_Prediciton")
mlflow.set_tracking_uri("file:../mlruns")

with mlflow.start_run(run_name = 'v1_CNN_paperArchitecture_bmw_unaugmented'): # change with every run 
    
    # Save hyperparameters
    
    mlflow.log_params({
        'learning_rate': learning_rate,
        'batch_size': batch_size,
        'epochs': epochs,
        'shuffle': shuffle,
        'optimizer': optimizer,
        # Save Data
        #'dataset_version': dataset_version,  
        #'test_dataset_version': test_dataset_version,
        'pixel_per_µm': pixel_per_µm
    }) 
    
    # Save metrics
    
    mlflow.log_metrics({
        'S_norm_Mean Squared Error': mse.result().numpy(),
        'S_norm_Root Mean Squared Error': rmse.result().numpy(), 
        'S_norm_Mean Absolute Percentage Error': mape.result().numpy(),
        'S_norm_Mean Absolute Error': mae.result().numpy(),
        'S_norm_R2-Score': r2,
        'SDAS_Mean Squared Error': SDAS_mse,
        'SDAS_Root_Mean Squared Error': SDAS_rmse,
        'SDAS_Mean Absolute Percentage Error': SDAS_mape, 
        'SDAS_Mean Absolute Error': SDAS_mae,
        'SDAS_R2-Score': SDAS_r2
    }) 
    
    # Save model
    
    if isinstance(model, tf.keras.Model):
        mlflow.keras.log_model(model, artifact_path="cnn_model")
    else:
        print("The model isn't from the type tf.keras.Model!") 
        
    # Save notebook
    
    mlflow.log_artifact("CNN_SDAS_Prediction_Pipeline.ipynb", artifact_path="notebooks") # Name of notebook has to be correct

# %% [markdown]
# ## Load model from ML-Flow

# %%
# Enter RunID and Path
run_id = input("Enter your RunID: ")  # Ersetze mit deiner RunID
model_path = "cnn_model"

# load model
loaded_model = mlflow.keras.load_model(f"runs:/{run_id}/{model_path}")

# print model architecture
loaded_model.summary()

# %%
y_pred = loaded_model.predict(X_test)
y_pred[:4]

# %%
# optional

client = MlflowClient()

# load hyperparameter and metrcis
run_data = client.get_run(run_id).data
print("Hyperparameter:", run_data.params)
print("Metriken:", run_data.metrics)

# download current notebook
client.download_artifacts(run_id, f"notebooks_from_mlflow/{run_id}.ipynb", "./")
