# %% [markdown]
# # Training a CNN for Image-Regression to predict the SDAS of a given image

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from opencv-python) (1.26.2)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np        #library for matrices (useful for data preparation)
import os                 #library for package manage
import cv2                #library for loading images
import tensorflow as tf   #library/framework for all kinds of machine learning tasks
import matplotlib.pyplot as plt #libary for visualisation
import random             #for random seeds

import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Input, Lambda
from tensorflow.keras.initializers import Constant, he_normal

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator #for Augmentation of Training Data

from tqdm.keras import TqdmCallback # for loading-bar
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

from tensorflow.keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2025-05-12 12:58:42.792005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747054722.806187 1955906 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747054722.810359 1955906 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747054722.823326 1955906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747054722.823343 1955906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747054722.823345 1955906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747054722.823346 1955906 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-12 12:58:42.827250: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !nvidia-smi
# Out:
# Mon May 12 12:58:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A30                     On  |   00000000:E2:00.0 Off |                   On |
# | N/A   43C    P0             57W /  165W |                  N/A   |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | MIG devices:                                                                            |
# +------------------+----------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                     Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                       BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                  |        ECC|                       |
# |==================+==================================+===========+=======================|
# |  0    0   0   0  |           22517MiB / 24050MiB    | 56      0 |  4   0    4    1    1 |
# |                  |                 4MiB / 32768MiB  |           |                       |
# +------------------+----------------------------------+-----------+-----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# speicher test

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
gpus
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 702860577501144359
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1130233856
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9136788684151275912
# physical_device_desc: "device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]
# I0000 00:00:1747054726.126053 1955906 gpu_device.cc:2019] Created device /device:GPU:0 with 1077 MB memory:  -> device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0

# %% [markdown]
# fix random seed. Always use a fixed random seed to guarantee that when you run the code twice you will get the same outcome. This removes a factor of variation and will help keep you sane.

# %%
# 1. Python-Seed für allgemeine Zufallszahlen
random.seed(42)

# 2. NumPy-Seed für alle Operationen mit NumPy
np.random.seed(42)

# 3. TensorFlow-Seed für TensorFlow-Operationen
tf.random.set_seed(42)

# 4. Optional: OS-Level Seed für bestimmte Bibliotheken
os.environ['PYTHONHASHSEED'] = '42'

# %% [markdown]
# ## Model Architecture

# %%
# Input layer
input_layer = Input(shape=(200, 200, 1))

# 1-Kanal -> 3-Kanal (weil ResNet50 RGB erwartet)
x = Lambda(lambda x: tf.image.grayscale_to_rgb(x), output_shape=(200, 200, 3))(input_layer)

# ResNet50 laden ohne Klassifikationskopf
resnet_base = ResNet50(weights='imagenet', include_top=False, input_shape=(200, 200, 3))

# ResNet einfrieren
for layer in resnet_base.layers:
    layer.trainable = False

# Durch ResNet schicken
x = resnet_base(x)

# Feature map -> Flatten + eigene Regression
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
x = BatchNormalization()(x)
output = Dense(1, activation='linear', kernel_initializer=he_normal())(x)

model = Model(inputs=input_layer, outputs=output)
# Out:
# I0000 00:00:1747054726.153683 1955906 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1077 MB memory:  -> device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:e2:00.0, compute capability: 8.0

# %%
learning_rate = 0.00001 
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Modell kompilieren
model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError']) #mse = mean sqaured error learning_rate=0.0005

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 200, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 200, 200, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     6,422,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,010,625 (114.48 MB)
#  Trainable params: 6,422,785 (24.50 MB)
#  Non-trainable params: 23,587,840 (89.98 MB)

# %% [markdown]
# ## Import Dataset and Preprocessing

# %%
# Path to the folder containing the original images (no subfolders)
data_dir = r'../data/bmw_train'
image_exts = ('.jpeg', '.jpg', '.bmp', '.png')
pixel_per_micrometer = 1/0.728265817023213 # for our training data from bmw
F_value = 1.36/pixel_per_micrometer        # F_value from paper

# List all image filenames
files = [f for f in os.listdir(data_dir) if f.lower().endswith(image_exts)] 

tiles = []
labels = []
tile_size = 200

for idx, file in enumerate(files, 1):
    img_path = os.path.join(data_dir, file)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"⚠️ Could not load {file}, skipping.")
        continue

    # --- Extract label from filename exactly as in the original script ---
    try:
        filename_parts = file.split('_')
        if len(filename_parts) < 2:
            print(f"⚠️ Unexpected filename format: {file}")
            continue
        sdas_value_str = filename_parts[1]   # e.g., '33' from 'AC_33_B2.jpg'
        SDAS = float(sdas_value_str)         # Convert string to float
        s_value = round(SDAS / F_value, 2)  # Apply formula
    except Exception as e:
        print(f"⚠️ Error parsing label from '{file}': {e}")
        continue
        
    norm_label = s_value / 100.0  # Normalize to 0–1 range

    h, w = img.shape

    # Split image into 200×200 tiles
    for y in range(0, h, tile_size):
        for x in range(0, w, tile_size):
            tile = img[y:y+tile_size, x:x+tile_size]
            if tile.shape != (tile_size, tile_size):
                continue  # Skip incomplete tiles at the edges

            # Normalize pixel values and add channel dimension
            tile = tile.astype(np.float16) / 255.0
            tile = tile[..., np.newaxis]  # Shape: (200, 200, 1)

            tiles.append(tile)
            labels.append(norm_label)

            # Apply 90°, 180°, and 270° rotations and store them as additional samples
            # for k in [1, 2, 3]:  # 1 = 90°, 2 = 180°, 3 = 270°
            #     rotated = np.rot90(tile, k)  # Rotate k times 90° counter-clockwise
            #     tiles.append(rotated)
            #     labels.append(norm_label)

    if idx % 50 == 0:
        print(f"⏳ Processed {idx}/{len(files)} images...")

# Convert lists to NumPy arrays
input_data = np.array(tiles, dtype=np.float16)
labels     = np.array(labels, dtype=np.float16)

print(f"✅ Done: {input_data.shape[0]} tiles created, input shape {input_data.shape[1:]}")
# Out:
# ⏳ Processed 50/130 images...
# ⏳ Processed 100/130 images...
# ✅ Done: 12870 tiles created, input shape (200, 200, 1)
# Processing file 18411/30685
# Processing file 18412/30685
# Processing file 18413/30685
# Processing file 18414/30685
# Processing file 18415/30685
# Processing file 18416/30685
# Processing file 18417/30685
# Processing file 18418/30685
# Processing file 18419/30685
# Processing file 18420/30685
# Processing file 18421/30685
# Processing file 18422/30685
# Processing file 18423/30685
# Processing file 18424/30685
# Processing file 18425/30685
# Processing file 18426/30685
# Processing file 18427/30685
# Processing file 18428/30685
# Processing file 18429/30685
# Processing file 18430/30685
# Processing file 18431/30685
# Processing file 18432/30685
# Processing file 18433/30685
# Processing file 18434/30685
# Processing file 18435/30685
# Processing file 18436/30685
# Processing file 18437/30685
# Processing file 18438/30685
# Processing file 18439/30685
# Processing file 18440/30685
# Processing file 18441/30685
# Processing file 18442/30685
# Processing file 18443/30685
# Processing file 18444/30685
# Processing file 18445/30685
# Processing file 18446/30685
# Processing file 18447/30685
# Processing file 18448/30685
# Processing file 18449/30685
# Processing file 18450/30685
# Processing file 18451/30685
# Processing file 18452/30685
# Processing file 18453/30685
# Processing file 18454/30685
# Processing file 18455/30685
# Processing file 18456/30685
# Processing file 18457/30685
# Processing file 18458/30685
# Processing file 18459/30685
# Processing file 18460/30685
# Processing file 18461/30685
# Processing file 18462/30685
# Processing file 18463/30685
# Processing file 18464/30685
# Processing file 18465/30685
# Processing file 18466/30685
# Processing file 18467/30685
# Processing file 18468/30685
# Processing file 18469/30685
# Processing file 18470/30685
# Processing file 18471/30685
# Processing file 18472/30685
# Processing file 18473/30685
# Processing file 18474/30685
# Processing file 18475/30685
# Processing file 18476/30685
# Processing file 18477/30685
# Processing file 18478/30685
# Processing file 18479/30685
# Processing file 18480/30685
# Processing file 18481/30685
# Processing file 18482/30685
# Processing file 18483/30685
# Processing file 18484/30685
# Processing file 18485/30685
# Processing file 18486/30685
# Processing file 18487/30685
# Processing file 18488/30685
# Processing file 18489/30685
# Processing file 18490/30685
# Processing file 18491/30685
# Processing file 18492/30685
# Processing file 18493/30685
# Processing file 18494/30685
# Processing file 18495/30685
# Processing file 18496/30685
# Processing file 18497/30685
# Processing file 18498/30685
# Processing file 18499/30685
# Processing file 18500/30685
# Processing file 18501/30685
# Processing file 18502/30685
# Processing file 18503/30685
# Processing file 18504/30685
# Processing file 18505/30685
# Processing file 18506/30685
# Processing file 18507/30685
# Processing file 18508/30685
# Processing file 18509/30685
# Processing file 18510/30685
# Processing file 18511/30685
# Processing file 18512/30685
# Processing file 18513/30685
# Processing file 18514/30685
# Processing file 18515/30685
# Processing file 18516/30685
# Processing file 18517/30685
# Processing file 18518/30685
# Processing file 18519/30685
# Processing file 18520/30685
# Processing file 18521/30685
# Processing file 18522/30685
# Processing file 18523/30685
# Processing file 18524/30685
# Processing file 18525/30685
# Processing file 18526/30685
# Processing file 18527/30685
# Processing file 18528/30685
# Processing file 18529/30685
# Processing file 18530/30685
# Processing file 18531/30685
# Processing file 18532/30685
# Processing file 18533/30685
# Processing file 18534/30685
# Processing file 18535/30685
# Processing file 18536/30685
# Processing file 18537/30685
# Processing file 18538/30685
# Processing file 18539/30685
# Processing file 18540/30685
# Processing file 18541/30685
# Processing file 18542/30685
# Processing file 18543/30685
# Processing file 18544/30685
# Processing file 18545/30685
# Processing file 18546/30685
# Processing file 18547/30685
# Processing file 18548/30685
# Processing file 18549/30685
# Processing file 18550/30685
# Processing file 18551/30685
# Processing file 18552/30685
# Processing file 18553/30685
# Processing file 18554/30685
# Processing file 18555/30685
# Processing file 18556/30685
# Processing file 18557/30685
# Processing file 18558/30685
# Processing file 18559/30685
# Processing file 18560/30685
# Processing file 18561/30685
# Processing file 18562/30685
# Processing file 18563/30685
# Processing file 18564/30685
# Processing file 18565/30685
# Processing file 18566/30685
# Processing file 18567/30685
# Processing file 18568/30685
# Processing file 18569/30685
# Processing file 18570/30685
# Processing file 18571/30685
# Processing file 18572/30685
# Processing file 18573/30685
# Processing file 18574/30685
# Processing file 18575/30685
# Processing file 18576/30685
# Processing file 18577/30685
# Processing file 18578/30685
# Processing file 18579/30685
# Processing file 18580/30685
# Processing file 18581/30685
# Processing file 18582/30685
# Processing file 18583/30685
# Processing file 18584/30685
# Processing file 18585/30685
# Processing file 18586/30685
# Processing file 18587/30685
# Processing file 18588/30685
# Processing file 18589/30685
# Processing file 18590/30685
# Processing file 18591/30685
# Processing file 18592/30685
# Processing file 18593/30685
# Processing file 18594/30685
# Processing file 18595/30685
# Processing file 18596/30685
# Processing file 18597/30685
# Processing file 18598/30685
# Processing file 18599/30685
# Processing file 18600/30685
# Processing file 18601/30685
# Processing file 18602/30685
# Processing file 18603/30685
# Processing file 18604/30685
# Processing file 18605/30685
# Processing file 18606/30685
# Processing file 18607/30685
# Processing file 18608/30685
# Processing file 18609/30685
# Processing file 18610/30685
# Processing file 18611/30685
# Processing file 18612/30685
# Processing file 18613/30685
# Processing file 18614/30685
# Processing file 18615/30685
# Processing file 18616/30685
# Processing file 18617/30685
# Processing file 18618/30685
# Processing file 18619/30685
# Processing file 18620/30685
# Processing file 18621/30685
# Processing file 18622/30685
# Processing file 18623/30685
# Processing file 18624/30685
# Processing file 18625/30685
# Processing file 18626/30685
# Processing file 18627/30685
# Processing file 18628/30685
# Processing file 18629/30685
# Processing file 18630/30685
# Processing file 18631/30685
# Processing file 18632/30685
# Processing file 18633/30685
# Processing file 18634/30685
# Processing file 18635/30685
# Processing file 18636/30685
# Processing file 18637/30685
# Processing file 18638/30685
# Processing file 18639/30685
# Processing file 18640/30685
# Processing file 18641/30685
# Processing file 18642/30685
# Processing file 18643/30685
# Processing file 18644/30685
# Processing file 18645/30685
# Processing file 18646/30685
# Processing file 18647/30685
# Processing file 18648/30685
# Processing file 18649/30685
# Processing file 18650/30685
# Processing file 18651/30685
# Processing file 18652/30685
# Processing file 18653/30685
# Processing file 18654/30685
# Processing file 18655/30685
# Processing file 18656/30685
# Processing file 18657/30685
# Processing file 18658/30685
# Processing file 18659/30685
# Processing file 18660/30685
# Processing file 18661/30685
# Processing file 18662/30685
# Processing file 18663/30685
# Processing file 18664/30685
# Processing file 18665/30685
# Processing file 18666/30685
# Processing file 18667/30685
# Processing file 18668/30685
# Processing file 18669/30685
# Processing file 18670/30685
# Processing file 18671/30685
# Processing file 18672/30685
# Processing file 18673/30685
# Processing file 18674/30685
# Processing file 18675/30685
# Processing file 18676/30685
# Processing file 18677/30685
# Processing file 18678/30685
# Processing file 18679/30685
# Processing file 18680/30685
# Processing file 18681/30685
# Processing file 18682/30685
# Processing file 18683/30685
# Processing file 18684/30685
# Processing file 18685/30685
# Processing file 18686/30685
# Processing file 18687/30685
# Processing file 18688/30685
# Processing file 18689/30685
# Processing file 18690/30685
# Processing file 18691/30685
# Processing file 18692/30685
# Processing file 18693/30685
# Processing file 18694/30685
# Processing file 18695/30685
# Processing file 18696/30685
# Processing file 18697/30685
# Processing file 18698/30685
# Processing file 18699/30685
# Processing file 18700/30685
# Processing file 18701/30685
# Processing file 18702/30685
# Processing file 18703/30685
# Processing file 18704/30685
# Processing file 18705/30685
# Processing file 18706/30685
# Processing file 18707/30685
# Processing file 18708/30685
# Processing file 18709/30685
# Processing file 18710/30685
# Processing file 18711/30685
# Processing file 18712/30685
# Processing file 18713/30685
# Processing file 18714/30685
# Processing file 18715/30685
# Processing file 18716/30685
# Processing file 18717/30685
# Processing file 18718/30685
# Processing file 18719/30685
# Processing file 18720/30685
# Processing file 18721/30685
# Processing file 18722/30685
# Processing file 18723/30685
# Processing file 18724/30685
# Processing file 18725/30685
# Processing file 18726/30685
# Processing file 18727/30685
# Processing file 18728/30685
# Processing file 18729/30685
# Processing file 18730/30685
# Processing file 18731/30685
# Processing file 18732/30685
# Processing file 18733/30685
# Processing file 18734/30685
# Processing file 18735/30685
# Processing file 18736/30685
# Processing file 18737/30685
# Processing file 18738/30685
# Processing file 18739/30685
# Processing file 18740/30685
# Processing file 18741/30685
# Processing file 18742/30685
# Processing file 18743/30685
# Processing file 18744/30685
# Processing file 18745/30685
# Processing file 18746/30685
# Processing file 18747/30685
# Processing file 18748/30685
# Processing file 18749/30685
# Processing file 18750/30685
# Processing file 18751/30685
# Processing file 18752/30685
# Processing file 18753/30685
# Processing file 18754/30685
# Processing file 18755/30685
# Processing file 18756/30685
# Processing file 18757/30685
# Processing file 18758/30685
# Processing file 18759/30685
# Processing file 18760/30685
# Processing file 18761/30685
# Processing file 18762/30685
# Processing file 18763/30685
# Processing file 18764/30685
# Processing file 18765/30685
# Processing file 18766/30685
# Processing file 18767/30685
# Processing file 18768/30685
# Processing file 18769/30685
# Processing file 18770/30685
# Processing file 18771/30685
# Processing file 18772/30685
# Processing file 18773/30685
# Processing file 18774/30685
# Processing file 18775/30685
# Processing file 18776/30685
# Processing file 18777/30685
# Processing file 18778/30685
# Processing file 18779/30685
# Processing file 18780/30685
# Processing file 18781/30685
# Processing file 18782/30685
# Processing file 18783/30685
# Processing file 18784/30685
# Processing file 18785/30685
# Processing file 18786/30685
# Processing file 18787/30685
# Processing file 18788/30685
# Processing file 18789/30685
# Processing file 18790/30685
# Processing file 18791/30685
# Processing file 18792/30685
# Processing file 18793/30685
# Processing file 18794/30685
# Processing file 18795/30685
# Processing file 18796/30685
# Processing file 18797/30685
# Processing file 18798/30685
# Processing file 18799/30685
# Processing file 18800/30685
# Processing file 18801/30685
# Processing file 18802/30685
# Processing file 18803/30685
# Processing file 18804/30685
# Processing file 18805/30685
# Processing file 18806/30685
# Processing file 18807/30685
# Processing file 18808/30685
# Processing file 18809/30685
# Processing file 18810/30685
# Processing file 18811/30685
# Processing file 18812/30685
# Processing file 18813/30685
# Processing file 18814/30685
# Processing file 18815/30685
# Processing file 18816/30685
# Processing file 18817/30685
# Processing file 18818/30685
# Processing file 18819/30685
# Processing file 18820/30685
# Processing file 18821/30685
# Processing file 18822/30685
# Processing file 18823/30685
# Processing file 18824/30685
# Processing file 18825/30685
# Processing file 18826/30685
# Processing file 18827/30685
# Processing file 18828/30685
# Processing file 18829/30685
# Processing file 18830/30685
# Processing file 18831/30685
# Processing file 18832/30685
# Processing file 18833/30685
# Processing file 18834/30685
# Processing file 18835/30685
# Processing file 18836/30685
# Processing file 18837/30685
# Processing file 18838/30685
# Processing file 18839/30685
# Processing file 18840/30685
# Processing file 18841/30685
# Processing file 18842/30685
# Processing file 18843/30685
# Processing file 18844/30685
# Processing file 18845/30685
# Processing file 18846/30685
# Processing file 18847/30685
# Processing file 18848/30685
# Processing file 18849/30685
# Processing file 18850/30685
# Processing file 18851/30685
# Processing file 18852/30685
# Processing file 18853/30685
# Processing file 18854/30685
# Processing file 18855/30685
# Processing file 18856/30685
# Processing file 18857/30685
# Processing file 18858/30685
# Processing file 18859/30685
# Processing file 18860/30685
# Processing file 18861/30685
# Processing file 18862/30685
# Processing file 18863/30685
# Processing file 18864/30685
# Processing file 18865/30685
# Processing file 18866/30685
# Processing file 18867/30685
# Processing file 18868/30685
# Processing file 18869/30685
# Processing file 18870/30685
# Processing file 18871/30685
# Processing file 18872/30685
# Processing file 18873/30685
# Processing file 18874/30685
# Processing file 18875/30685
# Processing file 18876/30685
# Processing file 18877/30685
# Processing file 18878/30685
# Processing file 18879/30685
# Processing file 18880/30685
# Processing file 18881/30685
# Processing file 18882/30685
# Processing file 18883/30685
# Processing file 18884/30685
# Processing file 18885/30685
# Processing file 18886/30685
# Processing file 18887/30685
# Processing file 18888/30685
# Processing file 18889/30685
# Processing file 18890/30685
# Processing file 18891/30685
# Processing file 18892/30685
# Processing file 18893/30685
# Processing file 18894/30685
# Processing file 18895/30685
# Processing file 18896/30685
# Processing file 18897/30685
# Processing file 18898/30685
# Processing file 18899/30685
# Processing file 18900/30685
# Processing file 18901/30685
# Processing file 18902/30685
# Processing file 18903/30685
# Processing file 18904/30685
# Processing file 18905/30685
# Processing file 18906/30685
# Processing file 18907/30685
# Processing file 18908/30685
# Processing file 18909/30685
# Processing file 18910/30685
# Processing file 18911/30685
# Processing file 18912/30685
# Processing file 18913/30685
# Processing file 18914/30685
# Processing file 18915/30685
# Processing file 18916/30685
# Processing file 18917/30685
# Processing file 18918/30685
# Processing file 18919/30685
# Processing file 18920/30685
# Processing file 18921/30685
# Processing file 18922/30685
# Processing file 18923/30685
# Processing file 18924/30685
# Processing file 18925/30685
# Processing file 18926/30685
# Processing file 18927/30685
# Processing file 18928/30685
# Processing file 18929/30685
# Processing file 18930/30685
# Processing file 18931/30685
# Processing file 18932/30685
# Processing file 18933/30685
# Processing file 18934/30685
# Processing file 18935/30685
# Processing file 18936/30685
# Processing file 18937/30685
# Processing file 18938/30685
# Processing file 18939/30685
# Processing file 18940/30685
# Processing file 18941/30685
# Processing file 18942/30685
# Processing file 18943/30685
# Processing file 18944/30685
# Processing file 18945/30685
# Processing file 18946/30685
# Processing file 18947/30685
# Processing file 18948/30685
# Processing file 18949/30685
# Processing file 18950/30685
# Processing file 18951/30685
# Processing file 18952/30685
# Processing file 18953/30685
# Processing file 18954/30685
# Processing file 18955/30685
# Processing file 18956/30685
# Processing file 18957/30685
# Processing file 18958/30685
# Processing file 18959/30685
# Processing file 18960/30685
# Processing file 18961/30685
# Processing file 18962/30685
# Processing file 18963/30685
# Processing file 18964/30685
# Processing file 18965/30685
# Processing file 18966/30685
# Processing file 18967/30685
# Processing file 18968/30685
# Processing file 18969/30685
# Processing file 18970/30685
# Processing file 18971/30685
# Processing file 18972/30685
# Processing file 18973/30685
# Processing file 18974/30685
# Processing file 18975/30685
# Processing file 18976/30685
# Processing file 18977/30685
# Processing file 18978/30685
# Processing file 18979/30685
# Processing file 18980/30685
# Processing file 18981/30685
# Processing file 18982/30685
# Processing file 18983/30685
# Processing file 18984/30685
# Processing file 18985/30685
# Processing file 18986/30685
# Processing file 18987/30685
# Processing file 18988/30685
# Processing file 18989/30685
# Processing file 18990/30685
# Processing file 18991/30685
# Processing file 18992/30685
# Processing file 18993/30685
# Processing file 18994/30685
# Processing file 18995/30685
# Processing file 18996/30685
# Processing file 18997/30685
# Processing file 18998/30685
# Processing file 18999/30685
# Processing file 19000/30685
# Processing file 19001/30685
# Processing file 19002/30685
# Processing file 19003/30685
# Processing file 19004/30685
# Processing file 19005/30685
# Processing file 19006/30685
# Processing file 19007/30685
# Processing file 19008/30685
# Processing file 19009/30685
# Processing file 19010/30685
# Processing file 19011/30685
# Processing file 19012/30685
# Processing file 19013/30685
# Processing file 19014/30685
# Processing file 19015/30685
# Processing file 19016/30685
# Processing file 19017/30685
# Processing file 19018/30685
# Processing file 19019/30685
# Processing file 19020/30685
# Processing file 19021/30685
# Processing file 19022/30685
# Processing file 19023/30685
# Processing file 19024/30685
# Processing file 19025/30685
# Processing file 19026/30685
# Processing file 19027/30685
# Processing file 19028/30685
# Processing file 19029/30685
# Processing file 19030/30685
# Processing file 19031/30685
# Processing file 19032/30685
# Processing file 19033/30685
# Processing file 19034/30685
# Processing file 19035/30685
# Processing file 19036/30685
# Processing file 19037/30685
# Processing file 19038/30685
# Processing file 19039/30685
# Processing file 19040/30685
# Processing file 19041/30685
# Processing file 19042/30685
# Processing file 19043/30685
# Processing file 19044/30685
# Processing file 19045/30685
# Processing file 19046/30685
# Processing file 19047/30685
# Processing file 19048/30685
# Processing file 19049/30685
# Processing file 19050/30685
# Processing file 19051/30685
# Processing file 19052/30685
# Processing file 19053/30685
# Processing file 19054/30685
# Processing file 19055/30685
# Processing file 19056/30685
# Processing file 19057/30685
# Processing file 19058/30685
# Processing file 19059/30685
# Processing file 19060/30685
# Processing file 19061/30685
# Processing file 19062/30685
# Processing file 19063/30685
# Processing file 19064/30685
# Processing file 19065/30685
# Processing file 19066/30685
# Processing file 19067/30685
# Processing file 19068/30685
# Processing file 19069/30685
# Processing file 19070/30685
# Processing file 19071/30685
# Processing file 19072/30685
# Processing file 19073/30685
# Processing file 19074/30685
# Processing file 19075/30685
# Processing file 19076/30685
# Processing file 19077/30685
# Processing file 19078/30685
# Processing file 19079/30685
# Processing file 19080/30685
# Processing file 19081/30685
# Processing file 19082/30685
# Processing file 19083/30685
# Processing file 19084/30685
# Processing file 19085/30685
# Processing file 19086/30685
# Processing file 19087/30685
# Processing file 19088/30685
# Processing file 19089/30685
# Processing file 19090/30685
# Processing file 19091/30685
# Processing file 19092/30685
# Processing file 19093/30685
# Processing file 19094/30685
# Processing file 19095/30685
# Processing file 19096/30685
# Processing file 19097/30685
# Processing file 19098/30685
# Processing file 19099/30685
# Processing file 19100/30685
# Processing file 19101/30685
# Processing file 19102/30685
# Processing file 19103/30685
# Processing file 19104/30685
# Processing file 19105/30685
# Processing file 19106/30685
# Processing file 19107/30685
# Processing file 19108/30685
# Processing file 19109/30685
# Processing file 19110/30685
# Processing file 19111/30685
# Processing file 19112/30685
# Processing file 19113/30685
# Processing file 19114/30685
# Processing file 19115/30685
# Processing file 19116/30685
# Processing file 19117/30685
# Processing file 19118/30685
# Processing file 19119/30685
# Processing file 19120/30685
# Processing file 19121/30685
# Processing file 19122/30685
# Processing file 19123/30685
# Processing file 19124/30685
# Processing file 19125/30685
# Processing file 19126/30685
# Processing file 19127/30685
# Processing file 19128/30685
# Processing file 19129/30685
# Processing file 19130/30685
# Processing file 19131/30685
# Processing file 19132/30685
# Processing file 19133/30685
# Processing file 19134/30685
# Processing file 19135/30685
# Processing file 19136/30685
# Processing file 19137/30685
# Processing file 19138/30685
# Processing file 19139/30685
# Processing file 19140/30685
# Processing file 19141/30685
# Processing file 19142/30685
# Processing file 19143/30685
# Processing file 19144/30685
# Processing file 19145/30685
# Processing file 19146/30685
# Processing file 19147/30685
# Processing file 19148/30685
# Processing file 19149/30685
# Processing file 19150/30685
# Processing file 19151/30685
# Processing file 19152/30685
# Processing file 19153/30685
# Processing file 19154/30685
# Processing file 19155/30685
# Processing file 19156/30685
# Processing file 19157/30685
# Processing file 19158/30685
# Processing file 19159/30685
# Processing file 19160/30685
# Processing file 19161/30685
# Processing file 19162/30685
# Processing file 19163/30685
# Processing file 19164/30685
# Processing file 19165/30685
# Processing file 19166/30685
# Processing file 19167/30685
# Processing file 19168/30685
# Processing file 19169/30685
# Processing file 19170/30685
# Processing file 19171/30685
# Processing file 19172/30685
# Processing file 19173/30685
# Processing file 19174/30685
# Processing file 19175/30685
# Processing file 19176/30685
# Processing file 19177/30685
# Processing file 19178/30685
# Processing file 19179/30685
# Processing file 19180/30685
# Processing file 19181/30685
# Processing file 19182/30685
# Processing file 19183/30685
# Processing file 19184/30685
# Processing file 19185/30685
# Processing file 19186/30685
# Processing file 19187/30685
# Processing file 19188/30685
# Processing file 19189/30685
# Processing file 19190/30685
# Processing file 19191/30685
# Processing file 19192/30685
# Processing file 19193/30685
# Processing file 19194/30685
# Processing file 19195/30685
# Processing file 19196/30685
# Processing file 19197/30685
# Processing file 19198/30685
# Processing file 19199/30685
# Processing file 19200/30685
# Processing file 19201/30685
# Processing file 19202/30685
# Processing file 19203/30685
# Processing file 19204/30685
# Processing file 19205/30685
# Processing file 19206/30685
# Processing file 19207/30685
# Processing file 19208/30685
# Processing file 19209/30685
# Processing file 19210/30685
# Processing file 19211/30685
# Processing file 19212/30685
# Processing file 19213/30685
# Processing file 19214/30685
# Processing file 19215/30685
# Processing file 19216/30685
# Processing file 19217/30685
# Processing file 19218/30685
# Processing file 19219/30685
# Processing file 19220/30685
# Processing file 19221/30685
# Processing file 19222/30685
# Processing file 19223/30685
# Processing file 19224/30685
# Processing file 19225/30685
# Processing file 19226/30685
# Processing file 19227/30685
# Processing file 19228/30685
# Processing file 19229/30685
# Processing file 19230/30685
# Processing file 19231/30685
# Processing file 19232/30685
# Processing file 19233/30685
# Processing file 19234/30685
# Processing file 19235/30685
# Processing file 19236/30685
# Processing file 19237/30685
# Processing file 19238/30685
# Processing file 19239/30685
# Processing file 19240/30685
# Processing file 19241/30685
# Processing file 19242/30685
# Processing file 19243/30685
# Processing file 19244/30685
# Processing file 19245/30685
# Processing file 19246/30685
# Processing file 19247/30685
# Processing file 19248/30685
# Processing file 19249/30685
# Processing file 19250/30685
# Processing file 19251/30685
# Processing file 19252/30685
# Processing file 19253/30685
# Processing file 19254/30685
# Processing file 19255/30685
# Processing file 19256/30685
# Processing file 19257/30685
# Processing file 19258/30685
# Processing file 19259/30685
# Processing file 19260/30685
# Processing file 19261/30685
# Processing file 19262/30685
# Processing file 19263/30685
# Processing file 19264/30685
# Processing file 19265/30685
# Processing file 19266/30685
# Processing file 19267/30685
# Processing file 19268/30685
# Processing file 19269/30685
# Processing file 19270/30685
# Processing file 19271/30685
# Processing file 19272/30685
# Processing file 19273/30685
# Processing file 19274/30685
# Processing file 19275/30685
# Processing file 19276/30685
# Processing file 19277/30685
# Processing file 19278/30685
# Processing file 19279/30685
# Processing file 19280/30685
# Processing file 19281/30685
# Processing file 19282/30685
# Processing file 19283/30685
# Processing file 19284/30685
# Processing file 19285/30685
# Processing file 19286/30685
# Processing file 19287/30685
# Processing file 19288/30685
# Processing file 19289/30685
# Processing file 19290/30685
# Processing file 19291/30685
# Processing file 19292/30685
# Processing file 19293/30685
# Processing file 19294/30685
# Processing file 19295/30685
# Processing file 19296/30685
# Processing file 19297/30685
# Processing file 19298/30685
# Processing file 19299/30685
# Processing file 19300/30685
# Processing file 19301/30685
# Processing file 19302/30685
# Processing file 19303/30685
# Processing file 19304/30685
# Processing file 19305/30685
# Processing file 19306/30685
# Processing file 19307/30685
# Processing file 19308/30685
# Processing file 19309/30685
# Processing file 19310/30685
# Processing file 19311/30685
# Processing file 19312/30685
# Processing file 19313/30685
# Processing file 19314/30685
# Processing file 19315/30685
# Processing file 19316/30685
# Processing file 19317/30685
# Processing file 19318/30685
# Processing file 19319/30685
# Processing file 19320/30685
# Processing file 19321/30685
# Processing file 19322/30685
# Processing file 19323/30685
# Processing file 19324/30685
# Processing file 19325/30685
# Processing file 19326/30685
# Processing file 19327/30685
# Processing file 19328/30685
# Processing file 19329/30685
# Processing file 19330/30685
# Processing file 19331/30685
# Processing file 19332/30685
# Processing file 19333/30685
# Processing file 19334/30685
# Processing file 19335/30685
# Processing file 19336/30685
# Processing file 19337/30685
# Processing file 19338/30685
# Processing file 19339/30685
# Processing file 19340/30685
# Processing file 19341/30685
# Processing file 19342/30685
# Processing file 19343/30685
# Processing file 19344/30685
# Processing file 19345/30685
# Processing file 19346/30685
# Processing file 19347/30685
# Processing file 19348/30685
# Processing file 19349/30685
# Processing file 19350/30685
# Processing file 19351/30685
# Processing file 19352/30685
# Processing file 19353/30685
# Processing file 19354/30685
# Processing file 19355/30685
# Processing file 19356/30685
# Processing file 19357/30685
# Processing file 19358/30685
# Processing file 19359/30685
# Processing file 19360/30685
# Processing file 19361/30685
# Processing file 19362/30685
# Processing file 19363/30685
# Processing file 19364/30685
# Processing file 19365/30685
# Processing file 19366/30685
# Processing file 19367/30685
# Processing file 19368/30685
# Processing file 19369/30685
# Processing file 19370/30685
# Processing file 19371/30685
# Processing file 19372/30685
# Processing file 19373/30685
# Processing file 19374/30685
# Processing file 19375/30685
# Processing file 19376/30685
# Processing file 19377/30685
# Processing file 19378/30685
# Processing file 19379/30685
# Processing file 19380/30685
# Processing file 19381/30685
# Processing file 19382/30685
# Processing file 19383/30685
# Processing file 19384/30685
# Processing file 19385/30685
# Processing file 19386/30685
# Processing file 19387/30685
# Processing file 19388/30685
# Processing file 19389/30685
# Processing file 19390/30685
# Processing file 19391/30685
# Processing file 19392/30685
# Processing file 19393/30685
# Processing file 19394/30685
# Processing file 19395/30685
# Processing file 19396/30685
# Processing file 19397/30685
# Processing file 19398/30685
# Processing file 19399/30685
# Processing file 19400/30685
# Processing file 19401/30685
# Processing file 19402/30685
# Processing file 19403/30685
# Processing file 19404/30685
# Processing file 19405/30685
# Processing file 19406/30685
# Processing file 19407/30685
# Processing file 19408/30685
# Processing file 19409/30685
# Processing file 19410/30685
# Processing file 19411/30685
# Processing file 19412/30685
# Processing file 19413/30685
# Processing file 19414/30685
# Processing file 19415/30685
# Processing file 19416/30685
# Processing file 19417/30685
# Processing file 19418/30685
# Processing file 19419/30685
# Processing file 19420/30685
# Processing file 19421/30685
# Processing file 19422/30685
# Processing file 19423/30685
# Processing file 19424/30685
# Processing file 19425/30685
# Processing file 19426/30685
# Processing file 19427/30685
# Processing file 19428/30685
# Processing file 19429/30685
# Processing file 19430/30685
# Processing file 19431/30685
# Processing file 19432/30685
# Processing file 19433/30685
# Processing file 19434/30685
# Processing file 19435/30685
# Processing file 19436/30685
# Processing file 19437/30685
# Processing file 19438/30685
# Processing file 19439/30685
# Processing file 19440/30685
# Processing file 19441/30685
# Processing file 19442/30685
# Processing file 19443/30685
# Processing file 19444/30685
# Processing file 19445/30685
# Processing file 19446/30685
# Processing file 19447/30685
# Processing file 19448/30685
# Processing file 19449/30685
# Processing file 19450/30685
# Processing file 19451/30685
# Processing file 19452/30685
# Processing file 19453/30685
# Processing file 19454/30685
# Processing file 19455/30685
# Processing file 19456/30685
# Processing file 19457/30685
# Processing file 19458/30685
# Processing file 19459/30685
# Processing file 19460/30685
# Processing file 19461/30685
# Processing file 19462/30685
# Processing file 19463/30685
# Processing file 19464/30685
# Processing file 19465/30685
# Processing file 19466/30685
# Processing file 19467/30685
# Processing file 19468/30685
# Processing file 19469/30685
# Processing file 19470/30685
# Processing file 19471/30685
# Processing file 19472/30685
# Processing file 19473/30685
# Processing file 19474/30685
# Processing file 19475/30685
# Processing file 19476/30685
# Processing file 19477/30685
# Processing file 19478/30685
# Processing file 19479/30685
# Processing file 19480/30685
# Processing file 19481/30685
# Processing file 19482/30685
# Processing file 19483/30685
# Processing file 19484/30685
# Processing file 19485/30685
# Processing file 19486/30685
# Processing file 19487/30685
# Processing file 19488/30685
# Processing file 19489/30685
# Processing file 19490/30685
# Processing file 19491/30685
# Processing file 19492/30685
# Processing file 19493/30685
# Processing file 19494/30685
# Processing file 19495/30685
# Processing file 19496/30685
# Processing file 19497/30685
# Processing file 19498/30685
# Processing file 19499/30685
# Processing file 19500/30685
# Processing file 19501/30685
# Processing file 19502/30685
# Processing file 19503/30685
# Processing file 19504/30685
# Processing file 19505/30685
# Processing file 19506/30685
# Processing file 19507/30685
# Processing file 19508/30685
# Processing file 19509/30685
# Processing file 19510/30685
# Processing file 19511/30685
# Processing file 19512/30685
# Processing file 19513/30685
# Processing file 19514/30685
# Processing file 19515/30685
# Processing file 19516/30685
# Processing file 19517/30685
# Processing file 19518/30685
# Processing file 19519/30685
# Processing file 19520/30685
# Processing file 19521/30685
# Processing file 19522/30685
# Processing file 19523/30685
# Processing file 19524/30685
# Processing file 19525/30685
# Processing file 19526/30685
# Processing file 19527/30685
# Processing file 19528/30685
# Processing file 19529/30685
# Processing file 19530/30685
# Processing file 19531/30685
# Processing file 19532/30685
# Processing file 19533/30685
# Processing file 19534/30685
# Processing file 19535/30685
# Processing file 19536/30685
# Processing file 19537/30685
# Processing file 19538/30685
# Processing file 19539/30685
# Processing file 19540/30685
# Processing file 19541/30685
# Processing file 19542/30685
# Processing file 19543/30685
# Processing file 19544/30685
# Processing file 19545/30685
# Processing file 19546/30685
# Processing file 19547/30685
# Processing file 19548/30685
# Processing file 19549/30685
# Processing file 19550/30685
# Processing file 19551/30685
# Processing file 19552/30685
# Processing file 19553/30685
# Processing file 19554/30685
# Processing file 19555/30685
# Processing file 19556/30685
# Processing file 19557/30685
# Processing file 19558/30685
# Processing file 19559/30685
# Processing file 19560/30685
# Processing file 19561/30685
# Processing file 19562/30685
# Processing file 19563/30685
# Processing file 19564/30685
# Processing file 19565/30685
# Processing file 19566/30685
# Processing file 19567/30685
# Processing file 19568/30685
# Processing file 19569/30685
# Processing file 19570/30685
# Processing file 19571/30685
# Processing file 19572/30685
# Processing file 19573/30685
# Processing file 19574/30685
# Processing file 19575/30685
# Processing file 19576/30685
# Processing file 19577/30685
# Processing file 19578/30685
# Processing file 19579/30685
# Processing file 19580/30685
# Processing file 19581/30685
# Processing file 19582/30685
# Processing file 19583/30685
# Processing file 19584/30685
# Processing file 19585/30685
# Processing file 19586/30685
# Processing file 19587/30685
# Processing file 19588/30685
# Processing file 19589/30685
# Processing file 19590/30685
# Processing file 19591/30685
# Processing file 19592/30685
# Processing file 19593/30685
# Processing file 19594/30685
# Processing file 19595/30685
# Processing file 19596/30685
# Processing file 19597/30685
# Processing file 19598/30685
# Processing file 19599/30685
# Processing file 19600/30685
# Processing file 19601/30685
# Processing file 19602/30685
# Processing file 19603/30685
# Processing file 19604/30685
# Processing file 19605/30685
# Processing file 19606/30685
# Processing file 19607/30685
# Processing file 19608/30685
# Processing file 19609/30685
# Processing file 19610/30685
# Processing file 19611/30685
# Processing file 19612/30685
# Processing file 19613/30685
# Processing file 19614/30685
# Processing file 19615/30685
# Processing file 19616/30685
# Processing file 19617/30685
# Processing file 19618/30685
# Processing file 19619/30685
# Processing file 19620/30685
# Processing file 19621/30685
# Processing file 19622/30685
# Processing file 19623/30685
# Processing file 19624/30685
# Processing file 19625/30685
# Processing file 19626/30685
# Processing file 19627/30685
# Processing file 19628/30685
# Processing file 19629/30685
# Processing file 19630/30685
# Processing file 19631/30685
# Processing file 19632/30685
# Processing file 19633/30685
# Processing file 19634/30685
# Processing file 19635/30685
# Processing file 19636/30685
# Processing file 19637/30685
# Processing file 19638/30685
# Processing file 19639/30685
# Processing file 19640/30685
# Processing file 19641/30685
# Processing file 19642/30685
# Processing file 19643/30685
# Processing file 19644/30685
# Processing file 19645/30685
# Processing file 19646/30685
# Processing file 19647/30685
# Processing file 19648/30685
# Processing file 19649/30685
# Processing file 19650/30685
# Processing file 19651/30685
# Processing file 19652/30685
# Processing file 19653/30685
# Processing file 19654/30685
# Processing file 19655/30685
# Processing file 19656/30685
# Processing file 19657/30685
# Processing file 19658/30685
# Processing file 19659/30685
# Processing file 19660/30685
# Processing file 19661/30685
# Processing file 19662/30685
# Processing file 19663/30685
# Processing file 19664/30685
# Processing file 19665/30685
# Processing file 19666/30685
# Processing file 19667/30685
# Processing file 19668/30685
# Processing file 19669/30685
# Processing file 19670/30685
# Processing file 19671/30685
# Processing file 19672/30685
# Processing file 19673/30685
# Processing file 19674/30685
# Processing file 19675/30685
# Processing file 19676/30685
# Processing file 19677/30685
# Processing file 19678/30685
# Processing file 19679/30685
# Processing file 19680/30685
# Processing file 19681/30685
# Processing file 19682/30685
# Processing file 19683/30685
# Processing file 19684/30685
# Processing file 19685/30685
# Processing file 19686/30685
# Processing file 19687/30685
# Processing file 19688/30685
# Processing file 19689/30685
# Processing file 19690/30685
# Processing file 19691/30685
# Processing file 19692/30685
# Processing file 19693/30685
# Processing file 19694/30685
# Processing file 19695/30685
# Processing file 19696/30685
# Processing file 19697/30685
# Processing file 19698/30685
# Processing file 19699/30685
# Processing file 19700/30685
# Processing file 19701/30685
# Processing file 19702/30685
# Processing file 19703/30685
# Processing file 19704/30685
# Processing file 19705/30685
# Processing file 19706/30685
# Processing file 19707/30685
# Processing file 19708/30685
# Processing file 19709/30685
# Processing file 19710/30685
# Processing file 19711/30685
# Processing file 19712/30685
# Processing file 19713/30685
# Processing file 19714/30685
# Processing file 19715/30685
# Processing file 19716/30685
# Processing file 19717/30685
# Processing file 19718/30685
# Processing file 19719/30685
# Processing file 19720/30685
# Processing file 19721/30685
# Processing file 19722/30685
# Processing file 19723/30685
# Processing file 19724/30685
# Processing file 19725/30685
# Processing file 19726/30685
# Processing file 19727/30685
# Processing file 19728/30685
# Processing file 19729/30685
# Processing file 19730/30685
# Processing file 19731/30685
# Processing file 19732/30685
# Processing file 19733/30685
# Processing file 19734/30685
# Processing file 19735/30685
# Processing file 19736/30685
# Processing file 19737/30685
# Processing file 19738/30685
# Processing file 19739/30685
# Processing file 19740/30685
# Processing file 19741/30685
# Processing file 19742/30685
# Processing file 19743/30685
# Processing file 19744/30685
# Processing file 19745/30685
# Processing file 19746/30685
# Processing file 19747/30685
# Processing file 19748/30685
# Processing file 19749/30685
# Processing file 19750/30685
# Processing file 19751/30685
# Processing file 19752/30685
# Processing file 19753/30685
# Processing file 19754/30685
# Processing file 19755/30685
# Processing file 19756/30685
# Processing file 19757/30685
# Processing file 19758/30685
# Processing file 19759/30685
# Processing file 19760/30685
# Processing file 19761/30685
# Processing file 19762/30685
# Processing file 19763/30685
# Processing file 19764/30685
# Processing file 19765/30685
# Processing file 19766/30685
# Processing file 19767/30685
# Processing file 19768/30685
# Processing file 19769/30685
# Processing file 19770/30685
# Processing file 19771/30685
# Processing file 19772/30685
# Processing file 19773/30685
# Processing file 19774/30685
# Processing file 19775/30685
# Processing file 19776/30685
# Processing file 19777/30685
# Processing file 19778/30685
# Processing file 19779/30685
# Processing file 19780/30685
# Processing file 19781/30685
# Processing file 19782/30685
# Processing file 19783/30685
# Processing file 19784/30685
# Processing file 19785/30685
# Processing file 19786/30685
# Processing file 19787/30685
# Processing file 19788/30685
# Processing file 19789/30685
# Processing file 19790/30685
# Processing file 19791/30685
# Processing file 19792/30685
# Processing file 19793/30685
# Processing file 19794/30685
# Processing file 19795/30685
# Processing file 19796/30685
# Processing file 19797/30685
# Processing file 19798/30685
# Processing file 19799/30685
# Processing file 19800/30685
# Processing file 19801/30685
# Processing file 19802/30685
# Processing file 19803/30685
# Processing file 19804/30685
# Processing file 19805/30685
# Processing file 19806/30685
# Processing file 19807/30685
# Processing file 19808/30685
# Processing file 19809/30685
# Processing file 19810/30685
# Processing file 19811/30685
# Processing file 19812/30685
# Processing file 19813/30685
# Processing file 19814/30685
# Processing file 19815/30685
# Processing file 19816/30685
# Processing file 19817/30685
# Processing file 19818/30685
# Processing file 19819/30685
# Processing file 19820/30685
# Processing file 19821/30685
# Processing file 19822/30685
# Processing file 19823/30685
# Processing file 19824/30685
# Processing file 19825/30685
# Processing file 19826/30685
# Processing file 19827/30685
# Processing file 19828/30685
# Processing file 19829/30685
# Processing file 19830/30685
# Processing file 19831/30685
# Processing file 19832/30685
# Processing file 19833/30685
# Processing file 19834/30685
# Processing file 19835/30685
# Processing file 19836/30685
# Processing file 19837/30685
# Processing file 19838/30685
# Processing file 19839/30685
# Processing file 19840/30685
# Processing file 19841/30685
# Processing file 19842/30685
# Processing file 19843/30685
# Processing file 19844/30685
# Processing file 19845/30685
# Processing file 19846/30685
# Processing file 19847/30685
# Processing file 19848/30685
# Processing file 19849/30685
# Processing file 19850/30685
# Processing file 19851/30685
# Processing file 19852/30685
# Processing file 19853/30685
# Processing file 19854/30685
# Processing file 19855/30685
# Processing file 19856/30685
# Processing file 19857/30685
# Processing file 19858/30685
# Processing file 19859/30685
# Processing file 19860/30685
# Processing file 19861/30685
# Processing file 19862/30685
# Processing file 19863/30685
# Processing file 19864/30685
# Processing file 19865/30685
# Processing file 19866/30685
# Processing file 19867/30685
# Processing file 19868/30685
# Processing file 19869/30685
# Processing file 19870/30685
# Processing file 19871/30685
# Processing file 19872/30685
# Processing file 19873/30685
# Processing file 19874/30685
# Processing file 19875/30685
# Processing file 19876/30685
# Processing file 19877/30685
# Processing file 19878/30685
# Processing file 19879/30685
# Processing file 19880/30685
# Processing file 19881/30685
# Processing file 19882/30685
# Processing file 19883/30685
# Processing file 19884/30685
# Processing file 19885/30685
# Processing file 19886/30685
# Processing file 19887/30685
# Processing file 19888/30685
# Processing file 19889/30685
# Processing file 19890/30685
# Processing file 19891/30685
# Processing file 19892/30685
# Processing file 19893/30685
# Processing file 19894/30685
# Processing file 19895/30685
# Processing file 19896/30685
# Processing file 19897/30685
# Processing file 19898/30685
# Processing file 19899/30685
# Processing file 19900/30685
# Processing file 19901/30685
# Processing file 19902/30685
# Processing file 19903/30685
# Processing file 19904/30685
# Processing file 19905/30685
# Processing file 19906/30685
# Processing file 19907/30685
# Processing file 19908/30685
# Processing file 19909/30685
# Processing file 19910/30685
# Processing file 19911/30685
# Processing file 19912/30685
# Processing file 19913/30685
# Processing file 19914/30685
# Processing file 19915/30685
# Processing file 19916/30685
# Processing file 19917/30685
# Processing file 19918/30685
# Processing file 19919/30685
# Processing file 19920/30685
# Processing file 19921/30685
# Processing file 19922/30685
# Processing file 19923/30685
# Processing file 19924/30685
# Processing file 19925/30685
# Processing file 19926/30685
# Processing file 19927/30685
# Processing file 19928/30685
# Processing file 19929/30685
# Processing file 19930/30685
# Processing file 19931/30685
# Processing file 19932/30685
# Processing file 19933/30685
# Processing file 19934/30685
# Processing file 19935/30685
# Processing file 19936/30685
# Processing file 19937/30685
# Processing file 19938/30685
# Processing file 19939/30685
# Processing file 19940/30685
# Processing file 19941/30685
# Processing file 19942/30685
# Processing file 19943/30685
# Processing file 19944/30685
# Processing file 19945/30685
# Processing file 19946/30685
# Processing file 19947/30685
# Processing file 19948/30685
# Processing file 19949/30685
# Processing file 19950/30685
# Processing file 19951/30685
# Processing file 19952/30685
# Processing file 19953/30685
# Processing file 19954/30685
# Processing file 19955/30685
# Processing file 19956/30685
# Processing file 19957/30685
# Processing file 19958/30685
# Processing file 19959/30685
# Processing file 19960/30685
# Processing file 19961/30685
# Processing file 19962/30685
# Processing file 19963/30685
# Processing file 19964/30685
# Processing file 19965/30685
# Processing file 19966/30685
# Processing file 19967/30685
# Processing file 19968/30685
# Processing file 19969/30685
# Processing file 19970/30685
# Processing file 19971/30685
# Processing file 19972/30685
# Processing file 19973/30685
# Processing file 19974/30685
# Processing file 19975/30685
# Processing file 19976/30685
# Processing file 19977/30685
# Processing file 19978/30685
# Processing file 19979/30685
# Processing file 19980/30685
# Processing file 19981/30685
# Processing file 19982/30685
# Processing file 19983/30685
# Processing file 19984/30685
# Processing file 19985/30685
# Processing file 19986/30685
# Processing file 19987/30685
# Processing file 19988/30685
# Processing file 19989/30685
# Processing file 19990/30685
# Processing file 19991/30685
# Processing file 19992/30685
# Processing file 19993/30685
# Processing file 19994/30685
# Processing file 19995/30685
# Processing file 19996/30685
# Processing file 19997/30685
# Processing file 19998/30685
# Processing file 19999/30685
# Processing file 20000/30685
# Processing file 20001/30685
# Processing file 20002/30685
# Processing file 20003/30685
# Processing file 20004/30685
# Processing file 20005/30685
# Processing file 20006/30685
# Processing file 20007/30685
# Processing file 20008/30685
# Processing file 20009/30685
# Processing file 20010/30685
# Processing file 20011/30685
# Processing file 20012/30685
# Processing file 20013/30685
# Processing file 20014/30685
# Processing file 20015/30685
# Processing file 20016/30685
# Processing file 20017/30685
# Processing file 20018/30685
# Processing file 20019/30685
# Processing file 20020/30685
# Processing file 20021/30685
# Processing file 20022/30685
# Processing file 20023/30685
# Processing file 20024/30685
# Processing file 20025/30685
# Processing file 20026/30685
# Processing file 20027/30685
# Processing file 20028/30685
# Processing file 20029/30685
# Processing file 20030/30685
# Processing file 20031/30685
# Processing file 20032/30685
# Processing file 20033/30685
# Processing file 20034/30685
# Processing file 20035/30685
# Processing file 20036/30685
# Processing file 20037/30685
# Processing file 20038/30685
# Processing file 20039/30685
# Processing file 20040/30685
# Processing file 20041/30685
# Processing file 20042/30685
# Processing file 20043/30685
# Processing file 20044/30685
# Processing file 20045/30685
# Processing file 20046/30685
# Processing file 20047/30685
# Processing file 20048/30685
# Processing file 20049/30685
# Processing file 20050/30685
# Processing file 20051/30685
# Processing file 20052/30685
# Processing file 20053/30685
# Processing file 20054/30685
# Processing file 20055/30685
# Processing file 20056/30685
# Processing file 20057/30685
# Processing file 20058/30685
# Processing file 20059/30685
# Processing file 20060/30685
# Processing file 20061/30685
# Processing file 20062/30685
# Processing file 20063/30685
# Processing file 20064/30685
# Processing file 20065/30685
# Processing file 20066/30685
# Processing file 20067/30685
# Processing file 20068/30685
# Processing file 20069/30685
# Processing file 20070/30685
# Processing file 20071/30685
# Processing file 20072/30685
# Processing file 20073/30685
# Processing file 20074/30685
# Processing file 20075/30685
# Processing file 20076/30685
# Processing file 20077/30685
# Processing file 20078/30685
# Processing file 20079/30685
# Processing file 20080/30685
# Processing file 20081/30685
# Processing file 20082/30685
# Processing file 20083/30685
# Processing file 20084/30685
# Processing file 20085/30685
# Processing file 20086/30685
# Processing file 20087/30685
# Processing file 20088/30685
# Processing file 20089/30685
# Processing file 20090/30685
# Processing file 20091/30685
# Processing file 20092/30685
# Processing file 20093/30685
# Processing file 20094/30685
# Processing file 20095/30685
# Processing file 20096/30685
# Processing file 20097/30685
# Processing file 20098/30685
# Processing file 20099/30685
# Processing file 20100/30685
# Processing file 20101/30685
# Processing file 20102/30685
# Processing file 20103/30685
# Processing file 20104/30685
# Processing file 20105/30685
# Processing file 20106/30685
# Processing file 20107/30685
# Processing file 20108/30685
# Processing file 20109/30685
# Processing file 20110/30685
# Processing file 20111/30685
# Processing file 20112/30685
# Processing file 20113/30685
# Processing file 20114/30685
# Processing file 20115/30685
# Processing file 20116/30685
# Processing file 20117/30685
# Processing file 20118/30685
# Processing file 20119/30685
# Processing file 20120/30685
# ...
# Processing file 30115/30685
# Processing file 30116/30685
# Processing file 30117/30685
# Processing file 30118/30685
# Processing file 30119/30685
# Processing file 30120/30685
# Processing file 30121/30685
# Processing file 30122/30685
# Processing file 30123/30685
# Processing file 30124/30685
# Processing file 30125/30685
# Processing file 30126/30685
# Processing file 30127/30685
# Processing file 30128/30685
# Processing file 30129/30685
# Processing file 30130/30685
# Processing file 30131/30685
# Processing file 30132/30685
# Processing file 30133/30685
# Processing file 30134/30685
# Processing file 30135/30685
# Processing file 30136/30685
# Processing file 30137/30685
# Processing file 30138/30685
# Processing file 30139/30685
# Processing file 30140/30685
# Processing file 30141/30685
# Processing file 30142/30685
# Processing file 30143/30685
# Processing file 30144/30685
# Processing file 30145/30685
# Processing file 30146/30685
# Processing file 30147/30685
# Processing file 30148/30685
# Processing file 30149/30685
# Processing file 30150/30685
# Processing file 30151/30685
# Processing file 30152/30685
# Processing file 30153/30685
# Processing file 30154/30685
# Processing file 30155/30685
# Processing file 30156/30685
# Processing file 30157/30685
# Processing file 30158/30685
# Processing file 30159/30685
# Processing file 30160/30685
# Processing file 30161/30685
# Processing file 30162/30685
# Processing file 30163/30685
# Processing file 30164/30685
# Processing file 30165/30685
# Processing file 30166/30685
# Processing file 30167/30685
# Processing file 30168/30685
# Processing file 30169/30685
# Processing file 30170/30685
# Processing file 30171/30685
# Processing file 30172/30685
# Processing file 30173/30685
# Processing file 30174/30685
# Processing file 30175/30685
# Processing file 30176/30685
# Processing file 30177/30685
# Processing file 30178/30685
# Processing file 30179/30685
# Processing file 30180/30685
# Processing file 30181/30685
# Processing file 30182/30685
# Processing file 30183/30685
# Processing file 30184/30685
# Processing file 30185/30685
# Processing file 30186/30685
# Processing file 30187/30685
# Processing file 30188/30685
# Processing file 30189/30685
# Processing file 30190/30685
# Processing file 30191/30685
# Processing file 30192/30685
# Processing file 30193/30685
# Processing file 30194/30685
# Processing file 30195/30685
# Processing file 30196/30685
# Processing file 30197/30685
# Processing file 30198/30685
# Processing file 30199/30685
# Processing file 30200/30685
# Processing file 30201/30685
# Processing file 30202/30685
# Processing file 30203/30685
# Processing file 30204/30685
# Processing file 30205/30685
# Processing file 30206/30685
# Processing file 30207/30685
# Processing file 30208/30685
# Processing file 30209/30685
# Processing file 30210/30685
# Processing file 30211/30685
# Processing file 30212/30685
# Processing file 30213/30685
# Processing file 30214/30685
# Processing file 30215/30685
# Processing file 30216/30685
# Processing file 30217/30685
# Processing file 30218/30685
# Processing file 30219/30685
# Processing file 30220/30685
# Processing file 30221/30685
# Processing file 30222/30685
# Processing file 30223/30685
# Processing file 30224/30685
# Processing file 30225/30685
# Processing file 30226/30685
# Processing file 30227/30685
# Processing file 30228/30685
# Processing file 30229/30685
# Processing file 30230/30685
# Processing file 30231/30685
# Processing file 30232/30685
# Processing file 30233/30685
# Processing file 30234/30685
# Processing file 30235/30685
# Processing file 30236/30685
# Processing file 30237/30685
# Processing file 30238/30685
# Processing file 30239/30685
# Processing file 30240/30685
# Processing file 30241/30685
# Processing file 30242/30685
# Processing file 30243/30685
# Processing file 30244/30685
# Processing file 30245/30685
# Processing file 30246/30685
# Processing file 30247/30685
# Processing file 30248/30685
# Processing file 30249/30685
# Processing file 30250/30685
# Processing file 30251/30685
# Processing file 30252/30685
# Processing file 30253/30685
# Processing file 30254/30685
# Processing file 30255/30685
# Processing file 30256/30685
# Processing file 30257/30685
# Processing file 30258/30685
# Processing file 30259/30685
# Processing file 30260/30685
# Processing file 30261/30685
# Processing file 30262/30685
# Processing file 30263/30685
# Processing file 30264/30685
# Processing file 30265/30685
# Processing file 30266/30685
# Processing file 30267/30685
# Processing file 30268/30685
# Processing file 30269/30685
# Processing file 30270/30685
# Processing file 30271/30685
# Processing file 30272/30685
# Processing file 30273/30685
# Processing file 30274/30685
# Processing file 30275/30685
# Processing file 30276/30685
# Processing file 30277/30685
# Processing file 30278/30685
# Processing file 30279/30685
# Processing file 30280/30685
# Processing file 30281/30685
# Processing file 30282/30685
# Processing file 30283/30685
# Processing file 30284/30685
# Processing file 30285/30685
# Processing file 30286/30685
# Processing file 30287/30685
# Processing file 30288/30685
# Processing file 30289/30685
# Processing file 30290/30685
# Processing file 30291/30685
# Processing file 30292/30685
# Processing file 30293/30685
# Processing file 30294/30685
# Processing file 30295/30685
# Processing file 30296/30685
# Processing file 30297/30685
# Processing file 30298/30685
# Processing file 30299/30685
# Processing file 30300/30685
# Processing file 30301/30685
# Processing file 30302/30685
# Processing file 30303/30685
# Processing file 30304/30685
# Processing file 30305/30685
# Processing file 30306/30685
# Processing file 30307/30685
# Processing file 30308/30685
# Processing file 30309/30685
# Processing file 30310/30685
# Processing file 30311/30685
# Processing file 30312/30685
# Processing file 30313/30685
# Processing file 30314/30685
# Processing file 30315/30685
# Processing file 30316/30685
# Processing file 30317/30685
# Processing file 30318/30685
# Processing file 30319/30685
# Processing file 30320/30685
# Processing file 30321/30685
# Processing file 30322/30685
# Processing file 30323/30685
# Processing file 30324/30685
# Processing file 30325/30685
# Processing file 30326/30685
# Processing file 30327/30685
# Processing file 30328/30685
# Processing file 30329/30685
# Processing file 30330/30685
# Processing file 30331/30685
# Processing file 30332/30685
# Processing file 30333/30685
# Processing file 30334/30685
# Processing file 30335/30685
# Processing file 30336/30685
# Processing file 30337/30685
# Processing file 30338/30685
# Processing file 30339/30685
# Processing file 30340/30685
# Processing file 30341/30685
# Processing file 30342/30685
# Processing file 30343/30685
# Processing file 30344/30685
# Processing file 30345/30685
# Processing file 30346/30685
# Processing file 30347/30685
# Processing file 30348/30685
# Processing file 30349/30685
# Processing file 30350/30685
# Processing file 30351/30685
# Processing file 30352/30685
# Processing file 30353/30685
# Processing file 30354/30685
# Processing file 30355/30685
# Processing file 30356/30685
# Processing file 30357/30685
# Processing file 30358/30685
# Processing file 30359/30685
# Processing file 30360/30685
# Processing file 30361/30685
# Processing file 30362/30685
# Processing file 30363/30685
# Processing file 30364/30685
# Processing file 30365/30685
# Processing file 30366/30685
# Processing file 30367/30685
# Processing file 30368/30685
# Processing file 30369/30685
# Processing file 30370/30685
# Processing file 30371/30685
# Processing file 30372/30685
# Processing file 30373/30685
# Processing file 30374/30685
# Processing file 30375/30685
# Processing file 30376/30685
# Processing file 30377/30685
# Processing file 30378/30685
# Processing file 30379/30685
# Processing file 30380/30685
# Processing file 30381/30685
# Processing file 30382/30685
# Processing file 30383/30685
# Processing file 30384/30685
# Processing file 30385/30685
# Processing file 30386/30685
# Processing file 30387/30685
# Processing file 30388/30685
# Processing file 30389/30685
# Processing file 30390/30685
# Processing file 30391/30685
# Processing file 30392/30685
# Processing file 30393/30685
# Processing file 30394/30685
# Processing file 30395/30685
# Processing file 30396/30685
# Processing file 30397/30685
# Processing file 30398/30685
# Processing file 30399/30685
# Processing file 30400/30685
# Processing file 30401/30685
# Processing file 30402/30685
# Processing file 30403/30685
# Processing file 30404/30685
# Processing file 30405/30685
# Processing file 30406/30685
# Processing file 30407/30685
# Processing file 30408/30685
# Processing file 30409/30685
# Processing file 30410/30685
# Processing file 30411/30685
# Processing file 30412/30685
# Processing file 30413/30685
# Processing file 30414/30685
# Processing file 30415/30685
# Processing file 30416/30685
# Processing file 30417/30685
# Processing file 30418/30685
# Processing file 30419/30685
# Processing file 30420/30685
# Processing file 30421/30685
# Processing file 30422/30685
# Processing file 30423/30685
# Processing file 30424/30685
# Processing file 30425/30685
# Processing file 30426/30685
# Processing file 30427/30685
# Processing file 30428/30685
# Processing file 30429/30685
# Processing file 30430/30685
# Processing file 30431/30685
# Processing file 30432/30685
# Processing file 30433/30685
# Processing file 30434/30685
# Processing file 30435/30685
# Processing file 30436/30685
# Processing file 30437/30685
# Processing file 30438/30685
# Processing file 30439/30685
# Processing file 30440/30685
# Processing file 30441/30685
# Processing file 30442/30685
# Processing file 30443/30685
# Processing file 30444/30685
# Processing file 30445/30685
# Processing file 30446/30685
# Processing file 30447/30685
# Processing file 30448/30685
# Processing file 30449/30685
# Processing file 30450/30685
# Processing file 30451/30685
# Processing file 30452/30685
# Processing file 30453/30685
# Processing file 30454/30685
# Processing file 30455/30685
# Processing file 30456/30685
# Processing file 30457/30685
# Processing file 30458/30685
# Processing file 30459/30685
# Processing file 30460/30685
# Processing file 30461/30685
# Processing file 30462/30685
# Processing file 30463/30685
# Processing file 30464/30685
# Processing file 30465/30685
# Processing file 30466/30685
# Processing file 30467/30685
# Processing file 30468/30685
# Processing file 30469/30685
# Processing file 30470/30685
# Processing file 30471/30685
# Processing file 30472/30685
# Processing file 30473/30685
# Processing file 30474/30685
# Processing file 30475/30685
# Processing file 30476/30685
# Processing file 30477/30685
# Processing file 30478/30685
# Processing file 30479/30685
# Processing file 30480/30685
# Processing file 30481/30685
# Processing file 30482/30685
# Processing file 30483/30685
# Processing file 30484/30685
# Processing file 30485/30685
# Processing file 30486/30685
# Processing file 30487/30685
# Processing file 30488/30685
# Processing file 30489/30685
# Processing file 30490/30685
# Processing file 30491/30685
# Processing file 30492/30685
# Processing file 30493/30685
# Processing file 30494/30685
# Processing file 30495/30685
# Processing file 30496/30685
# Processing file 30497/30685
# Processing file 30498/30685
# Processing file 30499/30685
# Processing file 30500/30685
# Processing file 30501/30685
# Processing file 30502/30685
# Processing file 30503/30685
# Processing file 30504/30685
# Processing file 30505/30685
# Processing file 30506/30685
# Processing file 30507/30685
# Processing file 30508/30685
# Processing file 30509/30685
# Processing file 30510/30685
# Processing file 30511/30685
# Processing file 30512/30685
# Processing file 30513/30685
# Processing file 30514/30685
# Processing file 30515/30685
# Processing file 30516/30685
# Processing file 30517/30685
# Processing file 30518/30685
# Processing file 30519/30685
# Processing file 30520/30685
# Processing file 30521/30685
# Processing file 30522/30685
# Processing file 30523/30685
# Processing file 30524/30685
# Processing file 30525/30685
# Processing file 30526/30685
# Processing file 30527/30685
# Processing file 30528/30685
# Processing file 30529/30685
# Processing file 30530/30685
# Processing file 30531/30685
# Processing file 30532/30685
# Processing file 30533/30685
# Processing file 30534/30685
# Processing file 30535/30685
# Processing file 30536/30685
# Processing file 30537/30685
# Processing file 30538/30685
# Processing file 30539/30685
# Processing file 30540/30685
# Processing file 30541/30685
# Processing file 30542/30685
# Processing file 30543/30685
# Processing file 30544/30685
# Processing file 30545/30685
# Processing file 30546/30685
# Processing file 30547/30685
# Processing file 30548/30685
# Processing file 30549/30685
# Processing file 30550/30685
# Processing file 30551/30685
# Processing file 30552/30685
# Processing file 30553/30685
# Processing file 30554/30685
# Processing file 30555/30685
# Processing file 30556/30685
# Processing file 30557/30685
# Processing file 30558/30685
# Processing file 30559/30685
# Processing file 30560/30685
# Processing file 30561/30685
# Processing file 30562/30685
# Processing file 30563/30685
# Processing file 30564/30685
# Processing file 30565/30685
# Processing file 30566/30685
# Processing file 30567/30685
# Processing file 30568/30685
# Processing file 30569/30685
# Processing file 30570/30685
# Processing file 30571/30685
# Processing file 30572/30685
# Processing file 30573/30685
# Processing file 30574/30685
# Processing file 30575/30685
# Processing file 30576/30685
# Processing file 30577/30685
# Processing file 30578/30685
# Processing file 30579/30685
# Processing file 30580/30685
# Processing file 30581/30685
# Processing file 30582/30685
# Processing file 30583/30685
# Processing file 30584/30685
# Processing file 30585/30685
# Processing file 30586/30685
# Processing file 30587/30685
# Processing file 30588/30685
# Processing file 30589/30685
# Processing file 30590/30685
# Processing file 30591/30685
# Processing file 30592/30685
# Processing file 30593/30685
# Processing file 30594/30685
# Processing file 30595/30685
# Processing file 30596/30685
# Processing file 30597/30685
# Processing file 30598/30685
# Processing file 30599/30685
# Processing file 30600/30685
# Processing file 30601/30685
# Processing file 30602/30685
# Processing file 30603/30685
# Processing file 30604/30685
# Processing file 30605/30685
# Processing file 30606/30685
# Processing file 30607/30685
# Processing file 30608/30685
# Processing file 30609/30685
# Processing file 30610/30685
# Processing file 30611/30685
# Processing file 30612/30685
# Processing file 30613/30685
# Processing file 30614/30685
# Processing file 30615/30685
# Processing file 30616/30685
# Processing file 30617/30685
# Processing file 30618/30685
# Processing file 30619/30685
# Processing file 30620/30685
# Processing file 30621/30685
# Processing file 30622/30685
# Processing file 30623/30685
# Processing file 30624/30685
# Processing file 30625/30685
# Processing file 30626/30685
# Processing file 30627/30685
# Processing file 30628/30685
# Processing file 30629/30685
# Processing file 30630/30685
# Processing file 30631/30685
# Processing file 30632/30685
# Processing file 30633/30685
# Processing file 30634/30685
# Processing file 30635/30685
# Processing file 30636/30685
# Processing file 30637/30685
# Processing file 30638/30685
# Processing file 30639/30685
# Processing file 30640/30685
# Processing file 30641/30685
# Processing file 30642/30685
# Processing file 30643/30685
# Processing file 30644/30685
# Processing file 30645/30685
# Processing file 30646/30685
# Processing file 30647/30685
# Processing file 30648/30685
# Processing file 30649/30685
# Processing file 30650/30685
# Processing file 30651/30685
# Processing file 30652/30685
# Processing file 30653/30685
# Processing file 30654/30685
# Processing file 30655/30685
# Processing file 30656/30685
# Processing file 30657/30685
# Processing file 30658/30685
# Processing file 30659/30685
# Processing file 30660/30685
# Processing file 30661/30685
# Processing file 30662/30685
# Processing file 30663/30685
# Processing file 30664/30685
# Processing file 30665/30685
# Processing file 30666/30685
# Processing file 30667/30685
# Processing file 30668/30685
# Processing file 30669/30685
# Processing file 30670/30685
# Processing file 30671/30685
# Processing file 30672/30685
# Processing file 30673/30685
# Processing file 30674/30685
# Processing file 30675/30685
# Processing file 30676/30685
# Processing file 30677/30685
# Processing file 30678/30685
# Processing file 30679/30685
# Processing file 30680/30685
# Processing file 30681/30685
# Processing file 30682/30685
# Processing file 30683/30685
# Processing file 30684/30685
# Processing file 30685/30685

# %%
print(input_data.shape)  # (n, 200, 200, 1) 
print(labels.shape)      # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
type(input_data)
# Out:
# numpy.ndarray

# %%
type(labels)
# Out:
# numpy.ndarray

# %%
def check_duplicates_within_set(X, Y):
    unique_X, unique_indices = np.unique(X, axis=0, return_index=True)
    unique_Y = Y[unique_indices]

    print(f"{len(X)-len(unique_X)} duplicates found.")

    return unique_X, unique_Y

# %%
X, Y = check_duplicates_within_set(input_data, labels)
# Out:
# 0 duplicates found.

# %%
print(X.shape)  # (n, 200, 200, 1) 
print(Y.shape)  # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, stratify=Y, test_size=0.4, random_state=42) # stratify with labels (Y)

# %%
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5, random_state=42)

# %%
print(X_train.shape)  # (n, 200, 200, 1)
print(X_test.shape)   # (n, 200, 200, 1)
print(X_val.shape)    # (n, 200, 200, 1)
# Out:
# (7722, 200, 200, 1)
# (2574, 200, 200, 1)
# (2574, 200, 200, 1)

# %%
print(Y_train.shape)  # (n,) 
print(Y_test.shape)   # (n,) 
print(Y_val.shape)    # (n,)
# Out:
# (7722,)
# (2574,)
# (2574,)

# %% [markdown]
# *The training set, validation set and test set were split in the ratio 60 : 20 : 20.*

# %% [markdown]
# ## Augmentation

# %%
def custom_rotation(x):
    angle = np.random.choice([90, 180, 270])  # Randomly selects between 90, 180, and 270 degrees
    return np.rot90(x, k=angle // 90)  # k specifies the number of 90° rotations

# Define data augmentation (only for training data)
datagen = ImageDataGenerator(
    preprocessing_function=custom_rotation,  # Limit rotations to 90°, 180°, and 270°
    horizontal_flip=True,   # Flip images horizontally
)

# Fit the generator to the training data
datagen.fit(X_train)

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Check if x any y fit together

# %%
X_train[1].shape
# Out:
# (200, 200, 1)

# %%
type(X_train[1])
# Out:
# numpy.ndarray

# %%
# Convert to float32
image = X_train[1].squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()

# %%
Y_train[1]
# Out:
# 0.636

# %% [markdown]
# ### Check histogramm for image values

# %%
plt.hist(X_train[1].flatten(), bins=50, range=(0, 1))
plt.title('Verteilung der Pixelwerte')
plt.show()

# %%
print(f"Min: {np.min(X_train)}, Max: {np.max(X_train)}")
# Out:
# Min: 0.1412353515625, Max: 1.0

# %% [markdown]
# ### Check if null or inf values in train_y

# %%
assert not np.any(np.isnan(image)), "NaN-values found"
assert not np.any(np.isinf(image)), "infinite values found"
assert X_train[5].shape == (200, 200, 1), "image has unexpected form"

# %% [markdown]
# ### Check Data Distribution

# %%
# Plot histogram
plt.hist(Y_train, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Train")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_test, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Test")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_val, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Val")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Training

# %%
logdir = r'..\logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    r'..\checkpoints\best_weights.weights.h5',
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    initial_value_threshold=None
)

# %% [markdown]
# *It was trained with the Keras library on an Intel® Core™ I7-4970 CPU running at 3.60 GHz using 8 parallel processing units. Training was completed in 5 h—for 30 epochs total. A batch size of 32 was used for the training.*
#
# I will instead use my GPU, since its simply way faster.

# %%
# Check if GPU's are available
gpus = tf.config.list_physical_devices('GPU')
print(f"{len(gpus)} GPUs erkannt:")
for gpu in gpus:
    print(gpu)
# Out:
# 1 GPUs erkannt:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# If a GPU is available, enable memory growth (prevents memory issues)
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled.")
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %% [markdown]
# *Verify loss @ init. Verify that your loss starts at the correct loss value*

# %%
# Calculate the initial loss before training
init_loss = model.evaluate(X_val, Y_val, verbose=1)
print(f"Initial Loss: {init_loss[0]}")  # Should be approximately 1/3
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747054748.587311 1956252 service.cc:152] XLA service 0x7f60b0002790 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747054748.587364 1956252 service.cc:160]   StreamExecutor device (0): NVIDIA A30 MIG 4g.24gb, Compute Capability 8.0
# 2025-05-12 12:59:08.662842: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 12:59:08.663308: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-12 12:59:08.684000: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747054749.096854 1956252 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-05-12 12:59:09.362302: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 269.97MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  7/81 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - RootMeanSquaredError: 0.8674 - loss: 0.7524
# I0000 00:00:1747054751.146860 1956252 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 79/81 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - RootMeanSquaredError: 0.8726 - loss: 0.7614
# 2025-05-12 12:59:12.953635: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 12:59:12.953730: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - RootMeanSquaredError: 0.8726 - loss: 0.7614
# Initial Loss: 0.7603969573974609

# %%
# CALLBACKS (optional)

# EarlyStopping callback, stops training when validation loss does not improve
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# ModelCheckpoint callback, saves the best model based on validation loss
# checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)

def scheduler(epoch, lr): # Exponential Decay
    decay_rate = 0.90     # reduced 10% every decay_epochs...
    decay_epoch = 100     
    return lr * decay_rate**(epoch // decay_epoch)

lr_scheduler = LearningRateScheduler(scheduler)

# HYPERPARAMETER

batch_size = 32    # the original paper used a batch size of 32
epochs = 1000       # the original paper used 30 epochs 
shuffle = True

hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=batch_size),  # Use the generator here
    epochs=epochs,
    validation_data=(X_val, Y_val),
    shuffle=shuffle,
    verbose=0,  # muss 0 sein für tqdm 
    callbacks=[TqdmCallback(verbose=1), early_stopping, lr_scheduler] 
    #callbacks=[TqdmCallback(verbose=1, leave=True, tqdm_class=tqdm)]  # klassisch, kein Widget -> bug fix?
)
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# /opt/conda/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-05-12 12:59:19.293837: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 12:59:19.294801: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-12 12:59:25.146678: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 12:59:25.146783: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert

# %% [markdown]
# ## Plot Train, Test and Val Loss

# %% [markdown]
# *add significant digits to your eval. When plotting the test loss run the evaluation over the entire (large) test set. Do not just plot test losses over batches and then rely on smoothing them in Tensorboard. We are in pursuit of correctness and are very willing to give up time for staying sane.*

# %%
# Evaluation on the entire test set
test_loss = model.evaluate(X_test, Y_test, batch_size = 1, verbose=1)
# Out:
# 2025-05-12 13:32:10.476338: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-12 13:32:10.476460: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-12 13:32:11.184569: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 290.12MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2574/2574 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - RootMeanSquaredError: 0.0796 - loss: 0.0063

# %%
print(hist.history.keys())
# Out:
# dict_keys(['RootMeanSquaredError', 'loss', 'val_RootMeanSquaredError', 'val_loss', 'learning_rate'])

# %%
print(hist.history)
# Out:
# {'RootMeanSquaredError': [0.4356337785720825, 0.36968955397605896, 0.34182608127593994, 0.3180639147758484, 0.29495856165885925, 0.2727988362312317, 0.25173330307006836, 0.23163752257823944, 0.21184612810611725, 0.19406475126743317, 0.17559337615966797, 0.15972517430782318, 0.14531365036964417, 0.13275429606437683, 0.11974982917308807, 0.11201764643192291, 0.10509628802537918, 0.09889749437570572, 0.09580711275339127, 0.09340544044971466, 0.09346278011798859, 0.0916808694601059, 0.09012781083583832, 0.08989068120718002, 0.08861459791660309, 0.08922922611236572, 0.08959090709686279, 0.08862105756998062, 0.08719957619905472, 0.08760973811149597, 0.08779805153608322, 0.08795766532421112, 0.08668326586484909, 0.08659537881612778, 0.08653736859560013, 0.087389275431633, 0.08606826514005661, 0.08554279059171677, 0.0861755833029747, 0.08471454679965973, 0.08396942168474197, 0.08451807498931885, 0.08350344747304916, 0.08345074951648712, 0.08429653197526932, 0.08420680463314056, 0.08399878442287445, 0.08311034739017487, 0.08436109125614166, 0.08245670050382614, 0.08219742774963379, 0.08275964856147766, 0.08426940441131592, 0.08253408223390579, 0.08268420398235321, 0.08326926827430725, 0.08218684792518616, 0.08374135941267014, 0.08245360106229782, 0.08158819377422333, 0.08194774389266968, 0.08146856725215912, 0.08112278580665588, 0.08086100965738297, 0.08177320659160614, 0.08052565157413483, 0.08134393393993378, 0.08134236931800842, 0.08146998286247253, 0.08060743659734726, 0.0813453271985054, 0.08099465817213058, 0.08048086613416672, 0.08096165210008621, 0.08002083748579025, 0.07960060983896255, 0.0800529345870018, 0.08044404536485672, 0.080597884953022, 0.07973913848400116, 0.08107076585292816, 0.07998887449502945, 0.07963604480028152, 0.07915923744440079, 0.07933448255062103, 0.07934726029634476, 0.0790926069021225, 0.07959725707769394, 0.08018980920314789, 0.07935087382793427, 0.07856336981058121, 0.07917525619268417, 0.07901164144277573, 0.07856340706348419, 0.07859276980161667, 0.07875600457191467, 0.07899624109268188, 0.07850364595651627, 0.07756787538528442, 0.078870989382267, 0.07732569426298141, 0.077475905418396, 0.07733100652694702, 0.07713229209184647, 0.07670870423316956, 0.0764073058962822, 0.07648937404155731, 0.07565763592720032, 0.07473257184028625, 0.07545335590839386, 0.07555704563856125, 0.07539846748113632, 0.07485341280698776, 0.07447598874568939, 0.07451571524143219, 0.07429879158735275, 0.07488804310560226, 0.07440048456192017, 0.07393185794353485, 0.07450899481773376, 0.074164979159832, 0.07397802174091339, 0.07452985644340515, 0.07356858998537064, 0.0739348977804184, 0.0747678130865097, 0.07433535903692245, 0.07417062669992447, 0.07369109243154526, 0.07352368533611298, 0.07417532801628113, 0.07418444752693176, 0.0739474669098854, 0.07401404529809952, 0.07384296506643295, 0.07347601652145386, 0.07423574477434158, 0.07429015636444092, 0.07335783541202545, 0.07418215274810791, 0.07397116720676422, 0.07345537096261978, 0.07386497408151627, 0.07355660945177078, 0.07363609224557877, 0.07419130951166153, 0.07390128076076508, 0.07373525202274323, 0.07361622154712677, 0.07429241389036179, 0.07307125627994537, 0.07399523258209229, 0.07343334704637527, 0.07369336485862732, 0.07363466918468475, 0.07397470623254776, 0.0734519511461258, 0.07394640147686005, 0.07405413687229156, 0.0740685909986496, 0.07378477603197098, 0.0738205686211586, 0.07430905103683472, 0.07387753576040268, 0.0734114870429039, 0.07471498847007751, 0.07300113886594772, 0.07359945774078369, 0.07422547042369843, 0.07420491427183151, 0.07373973727226257, 0.07392073422670364, 0.0743521973490715, 0.07450622320175171, 0.07436276227235794, 0.07383628189563751, 0.07371924817562103, 0.0738224908709526, 0.0741976872086525, 0.07342149317264557, 0.07380363345146179, 0.0739593356847763, 0.07419447600841522, 0.07449042797088623, 0.07390996813774109, 0.07359553873538971, 0.0742383599281311, 0.0732666477560997, 0.07373934239149094, 0.07385175675153732, 0.07398813217878 ...

# %%
# Mean Squared Errors (Loss)
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='train_loss') # , marker='.' for akk exact points of graph
plt.plot(hist.history['val_loss'], color='orange', label='val_loss') # , marker='.' for akk exact points of graph
plt.axhline(y=test_loss[0], color='gray', linestyle='--', label='test_loss (final)')
plt.ylim(0, 0.1) # try commenting this...
fig.suptitle('Loss = Mean Squared Error', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
# # Root Mean Squared Errors (Metric) 
fig = plt.figure()
plt.plot(hist.history['RootMeanSquaredError'], color='teal', label='train_rmse', marker='.') # depends on tensorflow version if root_mean_squared_error or RootMeanSquaredError
plt.plot(hist.history['val_RootMeanSquaredError'], color='orange', label='val_rmse', marker='.')
plt.axhline(y=test_loss[1], color='gray', linestyle='--', label='test_rmse (final)')
plt.ylim(0, 1)
fig.suptitle('Root Mean Squared Error', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Evaluate Performance

# %% [markdown]
# The labels from the paper are in a range from 0.06 to 0.65.

# %% [markdown]
# ### Performance

# %%
mse = MeanSquaredError()
rmse = RootMeanSquaredError()
mape = MeanAbsolutePercentageError()
mae = MeanAbsoluteError()

# %%
batch_size = 1  # If your model was trained with batches (for a more accurate test, it's still better to use 1)

y_true = []
y_pred = []

# Calculate metrics over all test data in batches
for i in range(0, len(X_test), batch_size):
    X_batch = X_test[i:i+batch_size]  # Take a batch of test data
    y_batch = Y_test[i:i+batch_size]  # Corresponding labels
    yhat_batch = model.predict(X_batch, verbose=0)  # Model prediction for the batch
    
    # Store true values and predictions
    y_true.append(y_batch)
    y_pred.append(yhat_batch)

    # Update metrics
    mse.update_state(y_batch, yhat_batch)
    rmse.update_state(y_batch, yhat_batch)
    mae.update_state(y_batch, yhat_batch)
    mape.update_state(y_batch, yhat_batch)
    
y_true = np.concatenate(y_true, axis=0)
y_pred = np.concatenate(y_pred, axis=0)

# R²-Score
r2 = r2_score(y_true, y_pred)

# %%
print(f"Mean Squared Error (MSE): {mse.result().numpy():.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse.result().numpy():.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape.result().numpy():.2f}%")
print(f"Mean Absolute Error (MAPE): {mae.result().numpy():.2f}")
print(f"R²-Score: {r2}")
# Out:
# Mean Squared Error (MSE): 0.0064
# Root Mean Squared Error (RMSE): 0.0797
# Mean Absolute Percentage Error (MAPE): 16.29%
# Mean Absolute Error (MAPE): 0.06
# R²-Score: 0.4794977307319641

# %% [markdown]
# ## Predict SDAS for some specific test image

# %%
test_index = 1001
test_image = X_test[test_index]
test_label = Y_test[test_index]

print(test_image.shape)

# Convert Image to float32 numpy array
image = test_image.squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()
# Out:
# (200, 200, 1)

# %%
print(np.expand_dims(test_image, axis=0).shape)
# Out:
# (1, 200, 200, 1)

# %%
yhat = model.predict(np.expand_dims(test_image, axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
print("Ground Truth S_value: ", test_label*100)
print("Predicted S_value: ", round(yhat[0][0] * 100, 2))
# Out:
# Ground Truth S_value:  27.2705078125
# Predicted S_value:  26.33

# %% [markdown]
# ## Export Model

# %%
model.save(os.path.join(r'../models', 'ResNet50_v2.keras'), save_format="keras")
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras

# %% [markdown]
# ## Make Predictions on real images

# %%
#test_dataset_version = "bmw_data" #210 images

test_dir = r'../data/bmw_test'

# %%
min_size = 200

results = []

# for all images in test_dir
for idx, img_name in enumerate(os.listdir(test_dir)):
    if img_name.endswith('.jpg') or img_name.endswith('.png'):
        
        img_path = os.path.join(test_dir, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        height, width = img.shape
        
        # Calculate the number of tiles
        rows = height // min_size
        cols = width // min_size
        
        # Split the image into tiles
        images = []
        for i in range(rows):
            for j in range(cols):
                y_start = i * min_size
                x_start = j * min_size
                y_end = min(y_start + min_size, height)
                x_end = min(x_start + min_size, width)
                image = img[y_start:y_end, x_start:x_end]
                images.append(image)
        
        # Collect model predictions
        predictions = []
        for image in images:
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction)
        
        # Calculate the prediction
        S_value_pred = np.median(predictions) * 100 # * 100, because we normalized the data when we imported it 
        
        SDAS_pred = S_value_pred * F_value  
        
        # Extract the actual SDAS value from the filename
        try:
            SDAS_true = float(img_name.split('_')[1])
            results.append((SDAS_true, SDAS_pred))
        except:
            print(f"Warning: Couldn't extract SDAS-value from '{img_name}'!")

        if idx % 5 == 0:
            print(f"⏳ Processed {idx}/{len(os.listdir(test_dir))} images...")
# Out:
# ⏳ Processed 0/81 images...
# ⏳ Processed 5/81 images...
# ⏳ Processed 10/81 images...
# ⏳ Processed 15/81 images...
# ⏳ Processed 20/81 images...
# ⏳ Processed 25/81 images...
# ⏳ Processed 30/81 images...
# ⏳ Processed 35/81 images...
# ⏳ Processed 40/81 images...
# ⏳ Processed 45/81 images...
# ⏳ Processed 50/81 images...
# ⏳ Processed 55/81 images...
# ⏳ Processed 60/81 images...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 33
#      31     image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
#      32     image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # add channel dimension
# ---> 33     prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
#      34     predictions.append(prediction)
#      36 # Calculate the prediction
#
# File /opt/conda/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:557, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     555 outputs = None
#     556 with epoch_iterator.catch_stop_iteration():
# --> 557     for step, iterator in epoch_iterator:
#     558         callbacks.on_predict_batch_begin(step)
#     559         data = get_data(iterator)
#
# File /opt/conda/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:734, in TFEpochIterator.__next__(self)
#     733 def __next__(self):
# --> 734     return next(self._epoch_iterator)
#
# File /opt/conda/lib/python3.9/site-packages/keras/src/trainers/epoch_iterator.py:112, in EpochIterator._enumerate_iterator(self)
#     110         yield step, self._current_iterator
#     111     if self._num_batches and self._steps_seen >= self._num_batches:
# --> 112         self._current_iterator = iter(self._get_iterator())
#     113         self._steps_seen = 0
#     114 else:
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File /opt/conda/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Separate true and predicted values
y_true = [true for true, pred in results]
y_pred = [pred for true, pred in results]

# Calculate the metrics
SDAS_mse = mean_squared_error(y_true, y_pred)
SDAS_rmse = np.sqrt(SDAS_mse)
SDAS_mae = mean_absolute_error(y_true, y_pred)
SDAS_r2 = r2_score(y_true, y_pred)

# MAPE (with protection against division by zero)
y_true_array = np.array(y_true)
y_pred_array = np.array(y_pred)
SDAS_mape = np.mean(np.abs((y_true_array - y_pred_array) / y_true_array)) * 100

# Output the results
print(f"MSE: {SDAS_mse:.4f}")
print(f"RMSE: {SDAS_rmse:.4f}")
print(f"MAE: {SDAS_mae:.4f}")
print(f"MAPE: {SDAS_mape:.2f}%")
print(f"R²: {SDAS_r2:.4f}")

# %%
len(y_true_array)

# %%
#plotting predicted vs ground truth SDAS values for all images

plt.figure(figsize=(6, 6))  
plt.plot([0, 100], [0, 100], 'r--')  # Reference diagonal line
plt.scatter(y_true_array, y_pred_array)
plt.xlabel("Ground Truth SDAS")
plt.ylabel("Predicted SDAS")
plt.axis("equal")  # Ensure equal scaling on both axes
plt.title("Predicted vs. Ground Truth SDAS")
plt.show()

# %% [markdown]
# ## Showing Sclices Predictions for an given image

# %%
def process_image(test_dir, img_name, model):
    img_path = os.path.join(test_dir, img_name)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    height, width = img.shape
    
    # Calculate the number of tiles
    rows = height // min_size
    cols = width // min_size
    
    # Split the image into tiles
    images = []
    predictions = []
    for i in range(rows):
        for j in range(cols):
            y_start = i * min_size
            x_start = j * min_size
            y_end = min(y_start + min_size, height)
            x_end = min(x_start + min_size, width)
            image = img[y_start:y_end, x_start:x_end]
            images.append(image)
            
            # Normalize and resize the image for prediction
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # Add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction * 100 * F_value)
    
    return img, predictions, rows, cols

def plot_heatmap_with_image(img, predictions, rows, cols, min_size):
    # Reshape predictions to match the number of tiles
    heatmap = np.array(predictions).reshape((rows, cols))
    
    # Create a figure
    plt.figure(figsize=(10, 10))
    
    # Display the original image
    plt.imshow(img, cmap='gray', extent=[0, img.shape[1], img.shape[0], 0])
    
    # Overlay the heatmap on top of the image
    plt.imshow(heatmap, cmap='jet', alpha=0.5, extent=[0, img.shape[1], img.shape[0], 0])
    
    # Add color bar (legend for the heatmap)
    cbar = plt.colorbar()
    cbar.set_label('SDAS Prediction')

    # Show the plot
    plt.title("Image with SDAS Heatmap Overlay")
    plt.show()

# %%
test_dir = r'../data/bmw_test'
img_name = 'AC_39_B9.jpg'  # Replace with the image you want to test

# Process the selected image
img, predictions, rows, cols = process_image(test_dir, img_name, model)

# %%
print(np.median(predictions))

# Plot the heatmap over the image
plot_heatmap_with_image(img, predictions, rows, cols, min_size)

# %% [markdown]
# ## ML-Flow

# %%
# !pip install --user mlflow
# !pip install mlflow

# %%
import mlflow
import mlflow.keras
from mlflow.tracking import MlflowClient

# %% [markdown]
# Tutorial: https://www.youtube.com/watch?v=6ngxBkx05Fs&ab_channel=codebasics
#
# What do we want to log for every run:
# - model (with summary)
# - hyperparameter
# - dataset version
# - metrics
# - notebook

# %% [markdown]
# Run "mlflow ui" in your CMD first!

# %%
# !mlflow --version

# %%
mlflow.set_experiment("SDAS_Prediciton")
mlflow.set_tracking_uri("file:../mlruns")

with mlflow.start_run(run_name = 'v1_CNN_paperArchitecture_bmw_unaugmented'): # change with every run 
    
    # Save hyperparameters
    
    mlflow.log_params({
        'learning_rate': learning_rate,
        'batch_size': batch_size,
        'epochs': epochs,
        'shuffle': shuffle,
        'optimizer': optimizer,
        # Save Data
        #'dataset_version': dataset_version,  
        #'test_dataset_version': test_dataset_version,
        'pixel_per_µm': pixel_per_µm
    }) 
    
    # Save metrics
    
    mlflow.log_metrics({
        'S_norm_Mean Squared Error': mse.result().numpy(),
        'S_norm_Root Mean Squared Error': rmse.result().numpy(), 
        'S_norm_Mean Absolute Percentage Error': mape.result().numpy(),
        'S_norm_Mean Absolute Error': mae.result().numpy(),
        'S_norm_R2-Score': r2,
        'SDAS_Mean Squared Error': SDAS_mse,
        'SDAS_Root_Mean Squared Error': SDAS_rmse,
        'SDAS_Mean Absolute Percentage Error': SDAS_mape, 
        'SDAS_Mean Absolute Error': SDAS_mae,
        'SDAS_R2-Score': SDAS_r2
    }) 
    
    # Save model
    
    if isinstance(model, tf.keras.Model):
        mlflow.keras.log_model(model, artifact_path="cnn_model")
    else:
        print("The model isn't from the type tf.keras.Model!") 
        
    # Save notebook
    
    mlflow.log_artifact("CNN_SDAS_Prediction_Pipeline.ipynb", artifact_path="notebooks") # Name of notebook has to be correct

# %% [markdown]
# ## Load model from ML-Flow

# %%
# Enter RunID and Path
run_id = input("Enter your RunID: ")  # Ersetze mit deiner RunID
model_path = "cnn_model"

# load model
loaded_model = mlflow.keras.load_model(f"runs:/{run_id}/{model_path}")

# print model architecture
loaded_model.summary()

# %%
y_pred = loaded_model.predict(X_test)
y_pred[:4]

# %%
# optional

client = MlflowClient()

# load hyperparameter and metrcis
run_data = client.get_run(run_id).data
print("Hyperparameter:", run_data.params)
print("Metriken:", run_data.metrics)

# download current notebook
client.download_artifacts(run_id, f"notebooks_from_mlflow/{run_id}.ipynb", "./")
