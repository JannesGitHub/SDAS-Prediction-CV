# %% [markdown]
# # Training a CNN for Image-Regression to predict the SDAS of a given image

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from opencv-python) (1.26.2)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np        #library for matrices (useful for data preparation)
import os                 #library for package manage
import cv2                #library for loading images
import tensorflow as tf   #library/framework for all kinds of machine learning tasks
import matplotlib.pyplot as plt #libary for visualisation
import random             #for random seeds

import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Input, Lambda
from tensorflow.keras.initializers import Constant, he_normal

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator #for Augmentation of Training Data

from tqdm.keras import TqdmCallback # for loading-bar
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler

from tensorflow.keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2025-05-09 11:18:47.276090: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746789527.290765  610519 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746789527.295150  610519 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746789527.308033  610519 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746789527.308045  610519 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746789527.308047  610519 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746789527.308048  610519 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-09 11:18:47.312062: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !nvidia-smi
# Out:
# Fri May  9 11:18:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A30                     On  |   00000000:81:00.0 Off |                   On |
# | N/A   32C    P0             55W /  165W |                  N/A   |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | MIG devices:                                                                            |
# +------------------+----------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                     Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                       BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                  |        ECC|                       |
# |==================+==================================+===========+=======================|
# |  0    0   0   0  |               2MiB / 24050MiB    | 56      0 |  4   0    4    1    1 |
# |                  |                 1MiB / 32768MiB  |           |                       |
# +------------------+----------------------------------+-----------+-----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# speicher test

# %%
# Check if GPU is available
gpus = tf.config.list_physical_devices('GPU')
gpus
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12928726626270334587
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 23360897024
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8573503637520064328
# physical_device_desc: "device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:81:00.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]
# I0000 00:00:1746789530.603837  610519 gpu_device.cc:2019] Created device /device:GPU:0 with 22278 MB memory:  -> device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:81:00.0, compute capability: 8.0

# %% [markdown]
# fix random seed. Always use a fixed random seed to guarantee that when you run the code twice you will get the same outcome. This removes a factor of variation and will help keep you sane.

# %%
# 1. Python-Seed für allgemeine Zufallszahlen
random.seed(42)

# 2. NumPy-Seed für alle Operationen mit NumPy
np.random.seed(42)

# 3. TensorFlow-Seed für TensorFlow-Operationen
tf.random.set_seed(42)

# 4. Optional: OS-Level Seed für bestimmte Bibliotheken
os.environ['PYTHONHASHSEED'] = '42'

# %% [markdown]
# ## Model Architecture

# %%
# Input layer
input_layer = Input(shape=(200, 200, 1))

# 1-Kanal -> 3-Kanal (weil ResNet50 RGB erwartet)
x = Lambda(lambda x: tf.image.grayscale_to_rgb(x))(input_layer)

# ResNet50 laden ohne Klassifikationskopf (include_top=False), mit unseren Bildern
resnet_base = ResNet50(weights = 'imagenet', include_top=False, input_tensor=x) # weights = 'imagenet' for preloaded weights

# Optional: ResNet einfrieren, wenn du nur die oberste Schicht trainieren willst
for layer in resnet_base.layers:
   layer.trainable = False

# Feature map -> Flatten + eigene Regression
x = resnet_base.output
x = Flatten()(x) 
x = Dense(64, activation='relu')(x)
x = BatchNormalization()(x)
output = Dense(1, activation='linear', kernel_initializer=he_normal())(x)
# Out:
# I0000 00:00:1746789530.649748  610519 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22278 MB memory:  -> device: 0, name: NVIDIA A30 MIG 4g.24gb, pci bus id: 0000:81:00.0, compute capability: 8.0

# %%
# Modell definieren
model = Model(inputs=input_layer, outputs=output)

# %%
learning_rate = 0.000001 
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Modell kompilieren
model.compile(optimizer=optimizer, loss='mse', metrics=['RootMeanSquaredError']) #mse = mean sqaured error learning_rate=0.0005

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 200, 200,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 200, 200,  │          0 │ input_layer[0][0] │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 206, 206,  │          0 │ lambda[0][0]      │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 100, 100,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 100, 100,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 100, 100,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 102, 102,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 50, 50,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 50, 50,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 50, 50,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 50, 50,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 50, 50,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 50, 50,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 50, 50,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 50, 50,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 50, 50,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 50, 50,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 50, 50,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 50, 50,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 50, 50,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 50, 50,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 50, 50,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 50, 50,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 50, 50,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 50, 50,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 50, 50,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 50, 50,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 50, 50,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 50, 50,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 50, 50,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 50, 50,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 50, 50,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 50, 50,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 50, 50,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 50, 50,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 50, 50,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 50, 50,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 50, 50,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 50, 50,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 50, 50,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 25, 25,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 25, 25,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 25, 25,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 25, 25,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 25, 25,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 25, 25,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 25, 25,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 25, 25,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 25, 25,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 25, 25,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 25, 25,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 25, 25,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 25, 25,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 25, 25,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 25, 25,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 25, 25,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 25, 25,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 25, 25,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 25, 25,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 25, 25,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 25, 25,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 25, 25,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 25, 25,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 25, 25,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 25, 25,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 25, 25,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 25, 25,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 25, 25,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 25, 25,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 25, 25,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 25, 25,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 25, 25,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 25, 25,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 25, 25,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 25, 25,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 25, 25,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 25, 25,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 25, 25,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 25, 25,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 25, 25,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 25, 25,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 25, 25,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 13, 13,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 13, 13,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 13, 13,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 13, 13,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 13, 13,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 13, 13,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 13, 13,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 13, 13,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 13, 13,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 13, 13,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 13, 13,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 13, 13,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 13, 13,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 13, 13,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 13, 13,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 13, 13,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 13, 13,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 13, 13,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 13, 13,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 13, 13,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 13, 13,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 13, 13,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 13, 13,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 13, 13,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 13, 13,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 13, 13,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 13, 13,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 13, 13,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 13, 13,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 13, 13,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 13, 13,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 13, 13,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 13, 13,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 13, 13,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 13, 13,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 13, 13,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 13, 13,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 13, 13,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 13, 13,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 13, 13,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 13, 13,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 13, 13,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 13, 13,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 13, 13,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 13, 13,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 13, 13,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 13, 13,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 13, 13,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 13, 13,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 13, 13,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 13, 13,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 13, 13,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 13, 13,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 13, 13,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 13, 13,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 13, 13,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 13, 13,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 13, 13,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 13, 13,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 13, 13,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 13, 13,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 13, 13,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 7, 7,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 100352)    │          0 │ conv5_block3_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │  6,422,592 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64)        │        256 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         65 │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,010,625 (114.48 MB)
#  Trainable params: 6,422,785 (24.50 MB)
#  Non-trainable params: 23,587,840 (89.98 MB)

# %% [markdown]
# ## Import Dataset and Preprocessing

# %%
# Path to the folder containing the original images (no subfolders)
data_dir = r'../data/bmw_train'
image_exts = ('.jpeg', '.jpg', '.bmp', '.png')
pixel_per_micrometer = 1/0.728265817023213 # for our training data from bmw
F_value = 1.36/pixel_per_micrometer        # F_value from paper

# List all image filenames
files = [f for f in os.listdir(data_dir) if f.lower().endswith(image_exts)] 

tiles = []
labels = []
tile_size = 200

for idx, file in enumerate(files, 1):
    img_path = os.path.join(data_dir, file)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"⚠️ Could not load {file}, skipping.")
        continue

    # --- Extract label from filename exactly as in the original script ---
    try:
        filename_parts = file.split('_')
        if len(filename_parts) < 2:
            print(f"⚠️ Unexpected filename format: {file}")
            continue
        sdas_value_str = filename_parts[1]   # e.g., '33' from 'AC_33_B2.jpg'
        SDAS = float(sdas_value_str)         # Convert string to float
        s_value = round(SDAS / F_value, 2)  # Apply formula
    except Exception as e:
        print(f"⚠️ Error parsing label from '{file}': {e}")
        continue
        
    norm_label = s_value / 100.0  # Normalize to 0–1 range

    h, w = img.shape

    # Split image into 200×200 tiles
    for y in range(0, h, tile_size):
        for x in range(0, w, tile_size):
            tile = img[y:y+tile_size, x:x+tile_size]
            if tile.shape != (tile_size, tile_size):
                continue  # Skip incomplete tiles at the edges

            # Normalize pixel values and add channel dimension
            tile = tile.astype(np.float16) / 255.0
            tile = tile[..., np.newaxis]  # Shape: (200, 200, 1)

            tiles.append(tile)
            labels.append(norm_label)

            # Apply 90°, 180°, and 270° rotations and store them as additional samples
            # for k in [1, 2, 3]:  # 1 = 90°, 2 = 180°, 3 = 270°
            #     rotated = np.rot90(tile, k)  # Rotate k times 90° counter-clockwise
            #     tiles.append(rotated)
            #     labels.append(norm_label)

    if idx % 50 == 0:
        print(f"⏳ Processed {idx}/{len(files)} images...")

# Convert lists to NumPy arrays
input_data = np.array(tiles, dtype=np.float16)
labels     = np.array(labels, dtype=np.float16)

print(f"✅ Done: {input_data.shape[0]} tiles created, input shape {input_data.shape[1:]}")
# Out:
# ⏳ Processed 50/130 images...
# ⏳ Processed 100/130 images...
# ✅ Done: 12870 tiles created, input shape (200, 200, 1)
# Processing file 15771/30685
# Processing file 15772/30685
# Processing file 15773/30685
# Processing file 15774/30685
# Processing file 15775/30685
# Processing file 15776/30685
# Processing file 15777/30685
# Processing file 15778/30685
# Processing file 15779/30685
# Processing file 15780/30685
# Processing file 15781/30685
# Processing file 15782/30685
# Processing file 15783/30685
# Processing file 15784/30685
# Processing file 15785/30685
# Processing file 15786/30685
# Processing file 15787/30685
# Processing file 15788/30685
# Processing file 15789/30685
# Processing file 15790/30685
# Processing file 15791/30685
# Processing file 15792/30685
# Processing file 15793/30685
# Processing file 15794/30685
# Processing file 15795/30685
# Processing file 15796/30685
# Processing file 15797/30685
# Processing file 15798/30685
# Processing file 15799/30685
# Processing file 15800/30685
# Processing file 15801/30685
# Processing file 15802/30685
# Processing file 15803/30685
# Processing file 15804/30685
# Processing file 15805/30685
# Processing file 15806/30685
# Processing file 15807/30685
# Processing file 15808/30685
# Processing file 15809/30685
# Processing file 15810/30685
# Processing file 15811/30685
# Processing file 15812/30685
# Processing file 15813/30685
# Processing file 15814/30685
# Processing file 15815/30685
# Processing file 15816/30685
# Processing file 15817/30685
# Processing file 15818/30685
# Processing file 15819/30685
# Processing file 15820/30685
# Processing file 15821/30685
# Processing file 15822/30685
# Processing file 15823/30685
# Processing file 15824/30685
# Processing file 15825/30685
# Processing file 15826/30685
# Processing file 15827/30685
# Processing file 15828/30685
# Processing file 15829/30685
# Processing file 15830/30685
# Processing file 15831/30685
# Processing file 15832/30685
# Processing file 15833/30685
# Processing file 15834/30685
# Processing file 15835/30685
# Processing file 15836/30685
# Processing file 15837/30685
# Processing file 15838/30685
# Processing file 15839/30685
# Processing file 15840/30685
# Processing file 15841/30685
# Processing file 15842/30685
# Processing file 15843/30685
# Processing file 15844/30685
# Processing file 15845/30685
# Processing file 15846/30685
# Processing file 15847/30685
# Processing file 15848/30685
# Processing file 15849/30685
# Processing file 15850/30685
# Processing file 15851/30685
# Processing file 15852/30685
# Processing file 15853/30685
# Processing file 15854/30685
# Processing file 15855/30685
# Processing file 15856/30685
# Processing file 15857/30685
# Processing file 15858/30685
# Processing file 15859/30685
# Processing file 15860/30685
# Processing file 15861/30685
# Processing file 15862/30685
# Processing file 15863/30685
# Processing file 15864/30685
# Processing file 15865/30685
# Processing file 15866/30685
# Processing file 15867/30685
# Processing file 15868/30685
# Processing file 15869/30685
# Processing file 15870/30685
# Processing file 15871/30685
# Processing file 15872/30685
# Processing file 15873/30685
# Processing file 15874/30685
# Processing file 15875/30685
# Processing file 15876/30685
# Processing file 15877/30685
# Processing file 15878/30685
# Processing file 15879/30685
# Processing file 15880/30685
# Processing file 15881/30685
# Processing file 15882/30685
# Processing file 15883/30685
# Processing file 15884/30685
# Processing file 15885/30685
# Processing file 15886/30685
# Processing file 15887/30685
# Processing file 15888/30685
# Processing file 15889/30685
# Processing file 15890/30685
# Processing file 15891/30685
# Processing file 15892/30685
# Processing file 15893/30685
# Processing file 15894/30685
# Processing file 15895/30685
# Processing file 15896/30685
# Processing file 15897/30685
# Processing file 15898/30685
# Processing file 15899/30685
# Processing file 15900/30685
# Processing file 15901/30685
# Processing file 15902/30685
# Processing file 15903/30685
# Processing file 15904/30685
# Processing file 15905/30685
# Processing file 15906/30685
# Processing file 15907/30685
# Processing file 15908/30685
# Processing file 15909/30685
# Processing file 15910/30685
# Processing file 15911/30685
# Processing file 15912/30685
# Processing file 15913/30685
# Processing file 15914/30685
# Processing file 15915/30685
# Processing file 15916/30685
# Processing file 15917/30685
# Processing file 15918/30685
# Processing file 15919/30685
# Processing file 15920/30685
# Processing file 15921/30685
# Processing file 15922/30685
# Processing file 15923/30685
# Processing file 15924/30685
# Processing file 15925/30685
# Processing file 15926/30685
# Processing file 15927/30685
# Processing file 15928/30685
# Processing file 15929/30685
# Processing file 15930/30685
# Processing file 15931/30685
# Processing file 15932/30685
# Processing file 15933/30685
# Processing file 15934/30685
# Processing file 15935/30685
# Processing file 15936/30685
# Processing file 15937/30685
# Processing file 15938/30685
# Processing file 15939/30685
# Processing file 15940/30685
# Processing file 15941/30685
# Processing file 15942/30685
# Processing file 15943/30685
# Processing file 15944/30685
# Processing file 15945/30685
# Processing file 15946/30685
# Processing file 15947/30685
# Processing file 15948/30685
# Processing file 15949/30685
# Processing file 15950/30685
# Processing file 15951/30685
# Processing file 15952/30685
# Processing file 15953/30685
# Processing file 15954/30685
# Processing file 15955/30685
# Processing file 15956/30685
# Processing file 15957/30685
# Processing file 15958/30685
# Processing file 15959/30685
# Processing file 15960/30685
# Processing file 15961/30685
# Processing file 15962/30685
# Processing file 15963/30685
# Processing file 15964/30685
# Processing file 15965/30685
# Processing file 15966/30685
# Processing file 15967/30685
# Processing file 15968/30685
# Processing file 15969/30685
# Processing file 15970/30685
# Processing file 15971/30685
# Processing file 15972/30685
# Processing file 15973/30685
# Processing file 15974/30685
# Processing file 15975/30685
# Processing file 15976/30685
# Processing file 15977/30685
# Processing file 15978/30685
# Processing file 15979/30685
# Processing file 15980/30685
# Processing file 15981/30685
# Processing file 15982/30685
# Processing file 15983/30685
# Processing file 15984/30685
# Processing file 15985/30685
# Processing file 15986/30685
# Processing file 15987/30685
# Processing file 15988/30685
# Processing file 15989/30685
# Processing file 15990/30685
# Processing file 15991/30685
# Processing file 15992/30685
# Processing file 15993/30685
# Processing file 15994/30685
# Processing file 15995/30685
# Processing file 15996/30685
# Processing file 15997/30685
# Processing file 15998/30685
# Processing file 15999/30685
# Processing file 16000/30685
# Processing file 16001/30685
# Processing file 16002/30685
# Processing file 16003/30685
# Processing file 16004/30685
# Processing file 16005/30685
# Processing file 16006/30685
# Processing file 16007/30685
# Processing file 16008/30685
# Processing file 16009/30685
# Processing file 16010/30685
# Processing file 16011/30685
# Processing file 16012/30685
# Processing file 16013/30685
# Processing file 16014/30685
# Processing file 16015/30685
# Processing file 16016/30685
# Processing file 16017/30685
# Processing file 16018/30685
# Processing file 16019/30685
# Processing file 16020/30685
# Processing file 16021/30685
# Processing file 16022/30685
# Processing file 16023/30685
# Processing file 16024/30685
# Processing file 16025/30685
# Processing file 16026/30685
# Processing file 16027/30685
# Processing file 16028/30685
# Processing file 16029/30685
# Processing file 16030/30685
# Processing file 16031/30685
# Processing file 16032/30685
# Processing file 16033/30685
# Processing file 16034/30685
# Processing file 16035/30685
# Processing file 16036/30685
# Processing file 16037/30685
# Processing file 16038/30685
# Processing file 16039/30685
# Processing file 16040/30685
# Processing file 16041/30685
# Processing file 16042/30685
# Processing file 16043/30685
# Processing file 16044/30685
# Processing file 16045/30685
# Processing file 16046/30685
# Processing file 16047/30685
# Processing file 16048/30685
# Processing file 16049/30685
# Processing file 16050/30685
# Processing file 16051/30685
# Processing file 16052/30685
# Processing file 16053/30685
# Processing file 16054/30685
# Processing file 16055/30685
# Processing file 16056/30685
# Processing file 16057/30685
# Processing file 16058/30685
# Processing file 16059/30685
# Processing file 16060/30685
# Processing file 16061/30685
# Processing file 16062/30685
# Processing file 16063/30685
# Processing file 16064/30685
# Processing file 16065/30685
# Processing file 16066/30685
# Processing file 16067/30685
# Processing file 16068/30685
# Processing file 16069/30685
# Processing file 16070/30685
# Processing file 16071/30685
# Processing file 16072/30685
# Processing file 16073/30685
# Processing file 16074/30685
# Processing file 16075/30685
# Processing file 16076/30685
# Processing file 16077/30685
# Processing file 16078/30685
# Processing file 16079/30685
# Processing file 16080/30685
# Processing file 16081/30685
# Processing file 16082/30685
# Processing file 16083/30685
# Processing file 16084/30685
# Processing file 16085/30685
# Processing file 16086/30685
# Processing file 16087/30685
# Processing file 16088/30685
# Processing file 16089/30685
# Processing file 16090/30685
# Processing file 16091/30685
# Processing file 16092/30685
# Processing file 16093/30685
# Processing file 16094/30685
# Processing file 16095/30685
# Processing file 16096/30685
# Processing file 16097/30685
# Processing file 16098/30685
# Processing file 16099/30685
# Processing file 16100/30685
# Processing file 16101/30685
# Processing file 16102/30685
# Processing file 16103/30685
# Processing file 16104/30685
# Processing file 16105/30685
# Processing file 16106/30685
# Processing file 16107/30685
# Processing file 16108/30685
# Processing file 16109/30685
# Processing file 16110/30685
# Processing file 16111/30685
# Processing file 16112/30685
# Processing file 16113/30685
# Processing file 16114/30685
# Processing file 16115/30685
# Processing file 16116/30685
# Processing file 16117/30685
# Processing file 16118/30685
# Processing file 16119/30685
# Processing file 16120/30685
# Processing file 16121/30685
# Processing file 16122/30685
# Processing file 16123/30685
# Processing file 16124/30685
# Processing file 16125/30685
# Processing file 16126/30685
# Processing file 16127/30685
# Processing file 16128/30685
# Processing file 16129/30685
# Processing file 16130/30685
# Processing file 16131/30685
# Processing file 16132/30685
# Processing file 16133/30685
# Processing file 16134/30685
# Processing file 16135/30685
# Processing file 16136/30685
# Processing file 16137/30685
# Processing file 16138/30685
# Processing file 16139/30685
# Processing file 16140/30685
# Processing file 16141/30685
# Processing file 16142/30685
# Processing file 16143/30685
# Processing file 16144/30685
# Processing file 16145/30685
# Processing file 16146/30685
# Processing file 16147/30685
# Processing file 16148/30685
# Processing file 16149/30685
# Processing file 16150/30685
# Processing file 16151/30685
# Processing file 16152/30685
# Processing file 16153/30685
# Processing file 16154/30685
# Processing file 16155/30685
# Processing file 16156/30685
# Processing file 16157/30685
# Processing file 16158/30685
# Processing file 16159/30685
# Processing file 16160/30685
# Processing file 16161/30685
# Processing file 16162/30685
# Processing file 16163/30685
# Processing file 16164/30685
# Processing file 16165/30685
# Processing file 16166/30685
# Processing file 16167/30685
# Processing file 16168/30685
# Processing file 16169/30685
# Processing file 16170/30685
# Processing file 16171/30685
# Processing file 16172/30685
# Processing file 16173/30685
# Processing file 16174/30685
# Processing file 16175/30685
# Processing file 16176/30685
# Processing file 16177/30685
# Processing file 16178/30685
# Processing file 16179/30685
# Processing file 16180/30685
# Processing file 16181/30685
# Processing file 16182/30685
# Processing file 16183/30685
# Processing file 16184/30685
# Processing file 16185/30685
# Processing file 16186/30685
# Processing file 16187/30685
# Processing file 16188/30685
# Processing file 16189/30685
# Processing file 16190/30685
# Processing file 16191/30685
# Processing file 16192/30685
# Processing file 16193/30685
# Processing file 16194/30685
# Processing file 16195/30685
# Processing file 16196/30685
# Processing file 16197/30685
# Processing file 16198/30685
# Processing file 16199/30685
# Processing file 16200/30685
# Processing file 16201/30685
# Processing file 16202/30685
# Processing file 16203/30685
# Processing file 16204/30685
# Processing file 16205/30685
# Processing file 16206/30685
# Processing file 16207/30685
# Processing file 16208/30685
# Processing file 16209/30685
# Processing file 16210/30685
# Processing file 16211/30685
# Processing file 16212/30685
# Processing file 16213/30685
# Processing file 16214/30685
# Processing file 16215/30685
# Processing file 16216/30685
# Processing file 16217/30685
# Processing file 16218/30685
# Processing file 16219/30685
# Processing file 16220/30685
# Processing file 16221/30685
# Processing file 16222/30685
# Processing file 16223/30685
# Processing file 16224/30685
# Processing file 16225/30685
# Processing file 16226/30685
# Processing file 16227/30685
# Processing file 16228/30685
# Processing file 16229/30685
# Processing file 16230/30685
# Processing file 16231/30685
# Processing file 16232/30685
# Processing file 16233/30685
# Processing file 16234/30685
# Processing file 16235/30685
# Processing file 16236/30685
# Processing file 16237/30685
# Processing file 16238/30685
# Processing file 16239/30685
# Processing file 16240/30685
# Processing file 16241/30685
# Processing file 16242/30685
# Processing file 16243/30685
# Processing file 16244/30685
# Processing file 16245/30685
# Processing file 16246/30685
# Processing file 16247/30685
# Processing file 16248/30685
# Processing file 16249/30685
# Processing file 16250/30685
# Processing file 16251/30685
# Processing file 16252/30685
# Processing file 16253/30685
# Processing file 16254/30685
# Processing file 16255/30685
# Processing file 16256/30685
# Processing file 16257/30685
# Processing file 16258/30685
# Processing file 16259/30685
# Processing file 16260/30685
# Processing file 16261/30685
# Processing file 16262/30685
# Processing file 16263/30685
# Processing file 16264/30685
# Processing file 16265/30685
# Processing file 16266/30685
# Processing file 16267/30685
# Processing file 16268/30685
# Processing file 16269/30685
# Processing file 16270/30685
# Processing file 16271/30685
# Processing file 16272/30685
# Processing file 16273/30685
# Processing file 16274/30685
# Processing file 16275/30685
# Processing file 16276/30685
# Processing file 16277/30685
# Processing file 16278/30685
# Processing file 16279/30685
# Processing file 16280/30685
# Processing file 16281/30685
# Processing file 16282/30685
# Processing file 16283/30685
# Processing file 16284/30685
# Processing file 16285/30685
# Processing file 16286/30685
# Processing file 16287/30685
# Processing file 16288/30685
# Processing file 16289/30685
# Processing file 16290/30685
# Processing file 16291/30685
# Processing file 16292/30685
# Processing file 16293/30685
# Processing file 16294/30685
# Processing file 16295/30685
# Processing file 16296/30685
# Processing file 16297/30685
# Processing file 16298/30685
# Processing file 16299/30685
# Processing file 16300/30685
# Processing file 16301/30685
# Processing file 16302/30685
# Processing file 16303/30685
# Processing file 16304/30685
# Processing file 16305/30685
# Processing file 16306/30685
# Processing file 16307/30685
# Processing file 16308/30685
# Processing file 16309/30685
# Processing file 16310/30685
# Processing file 16311/30685
# Processing file 16312/30685
# Processing file 16313/30685
# Processing file 16314/30685
# Processing file 16315/30685
# Processing file 16316/30685
# Processing file 16317/30685
# Processing file 16318/30685
# Processing file 16319/30685
# Processing file 16320/30685
# Processing file 16321/30685
# Processing file 16322/30685
# Processing file 16323/30685
# Processing file 16324/30685
# Processing file 16325/30685
# Processing file 16326/30685
# Processing file 16327/30685
# Processing file 16328/30685
# Processing file 16329/30685
# Processing file 16330/30685
# Processing file 16331/30685
# Processing file 16332/30685
# Processing file 16333/30685
# Processing file 16334/30685
# Processing file 16335/30685
# Processing file 16336/30685
# Processing file 16337/30685
# Processing file 16338/30685
# Processing file 16339/30685
# Processing file 16340/30685
# Processing file 16341/30685
# Processing file 16342/30685
# Processing file 16343/30685
# Processing file 16344/30685
# Processing file 16345/30685
# Processing file 16346/30685
# Processing file 16347/30685
# Processing file 16348/30685
# Processing file 16349/30685
# Processing file 16350/30685
# Processing file 16351/30685
# Processing file 16352/30685
# Processing file 16353/30685
# Processing file 16354/30685
# Processing file 16355/30685
# Processing file 16356/30685
# Processing file 16357/30685
# Processing file 16358/30685
# Processing file 16359/30685
# Processing file 16360/30685
# Processing file 16361/30685
# Processing file 16362/30685
# Processing file 16363/30685
# Processing file 16364/30685
# Processing file 16365/30685
# Processing file 16366/30685
# Processing file 16367/30685
# Processing file 16368/30685
# Processing file 16369/30685
# Processing file 16370/30685
# Processing file 16371/30685
# Processing file 16372/30685
# Processing file 16373/30685
# Processing file 16374/30685
# Processing file 16375/30685
# Processing file 16376/30685
# Processing file 16377/30685
# Processing file 16378/30685
# Processing file 16379/30685
# Processing file 16380/30685
# Processing file 16381/30685
# Processing file 16382/30685
# Processing file 16383/30685
# Processing file 16384/30685
# Processing file 16385/30685
# Processing file 16386/30685
# Processing file 16387/30685
# Processing file 16388/30685
# Processing file 16389/30685
# Processing file 16390/30685
# Processing file 16391/30685
# Processing file 16392/30685
# Processing file 16393/30685
# Processing file 16394/30685
# Processing file 16395/30685
# Processing file 16396/30685
# Processing file 16397/30685
# Processing file 16398/30685
# Processing file 16399/30685
# Processing file 16400/30685
# Processing file 16401/30685
# Processing file 16402/30685
# Processing file 16403/30685
# Processing file 16404/30685
# Processing file 16405/30685
# Processing file 16406/30685
# Processing file 16407/30685
# Processing file 16408/30685
# Processing file 16409/30685
# Processing file 16410/30685
# Processing file 16411/30685
# Processing file 16412/30685
# Processing file 16413/30685
# Processing file 16414/30685
# Processing file 16415/30685
# Processing file 16416/30685
# Processing file 16417/30685
# Processing file 16418/30685
# Processing file 16419/30685
# Processing file 16420/30685
# Processing file 16421/30685
# Processing file 16422/30685
# Processing file 16423/30685
# Processing file 16424/30685
# Processing file 16425/30685
# Processing file 16426/30685
# Processing file 16427/30685
# Processing file 16428/30685
# Processing file 16429/30685
# Processing file 16430/30685
# Processing file 16431/30685
# Processing file 16432/30685
# Processing file 16433/30685
# Processing file 16434/30685
# Processing file 16435/30685
# Processing file 16436/30685
# Processing file 16437/30685
# Processing file 16438/30685
# Processing file 16439/30685
# Processing file 16440/30685
# Processing file 16441/30685
# Processing file 16442/30685
# Processing file 16443/30685
# Processing file 16444/30685
# Processing file 16445/30685
# Processing file 16446/30685
# Processing file 16447/30685
# Processing file 16448/30685
# Processing file 16449/30685
# Processing file 16450/30685
# Processing file 16451/30685
# Processing file 16452/30685
# Processing file 16453/30685
# Processing file 16454/30685
# Processing file 16455/30685
# Processing file 16456/30685
# Processing file 16457/30685
# Processing file 16458/30685
# Processing file 16459/30685
# Processing file 16460/30685
# Processing file 16461/30685
# Processing file 16462/30685
# Processing file 16463/30685
# Processing file 16464/30685
# Processing file 16465/30685
# Processing file 16466/30685
# Processing file 16467/30685
# Processing file 16468/30685
# Processing file 16469/30685
# Processing file 16470/30685
# Processing file 16471/30685
# Processing file 16472/30685
# Processing file 16473/30685
# Processing file 16474/30685
# Processing file 16475/30685
# Processing file 16476/30685
# Processing file 16477/30685
# Processing file 16478/30685
# Processing file 16479/30685
# Processing file 16480/30685
# Processing file 16481/30685
# Processing file 16482/30685
# Processing file 16483/30685
# Processing file 16484/30685
# Processing file 16485/30685
# Processing file 16486/30685
# Processing file 16487/30685
# Processing file 16488/30685
# Processing file 16489/30685
# Processing file 16490/30685
# Processing file 16491/30685
# Processing file 16492/30685
# Processing file 16493/30685
# Processing file 16494/30685
# Processing file 16495/30685
# Processing file 16496/30685
# Processing file 16497/30685
# Processing file 16498/30685
# Processing file 16499/30685
# Processing file 16500/30685
# Processing file 16501/30685
# Processing file 16502/30685
# Processing file 16503/30685
# Processing file 16504/30685
# Processing file 16505/30685
# Processing file 16506/30685
# Processing file 16507/30685
# Processing file 16508/30685
# Processing file 16509/30685
# Processing file 16510/30685
# Processing file 16511/30685
# Processing file 16512/30685
# Processing file 16513/30685
# Processing file 16514/30685
# Processing file 16515/30685
# Processing file 16516/30685
# Processing file 16517/30685
# Processing file 16518/30685
# Processing file 16519/30685
# Processing file 16520/30685
# Processing file 16521/30685
# Processing file 16522/30685
# Processing file 16523/30685
# Processing file 16524/30685
# Processing file 16525/30685
# Processing file 16526/30685
# Processing file 16527/30685
# Processing file 16528/30685
# Processing file 16529/30685
# Processing file 16530/30685
# Processing file 16531/30685
# Processing file 16532/30685
# Processing file 16533/30685
# Processing file 16534/30685
# Processing file 16535/30685
# Processing file 16536/30685
# Processing file 16537/30685
# Processing file 16538/30685
# Processing file 16539/30685
# Processing file 16540/30685
# Processing file 16541/30685
# Processing file 16542/30685
# Processing file 16543/30685
# Processing file 16544/30685
# Processing file 16545/30685
# Processing file 16546/30685
# Processing file 16547/30685
# Processing file 16548/30685
# Processing file 16549/30685
# Processing file 16550/30685
# Processing file 16551/30685
# Processing file 16552/30685
# Processing file 16553/30685
# Processing file 16554/30685
# Processing file 16555/30685
# Processing file 16556/30685
# Processing file 16557/30685
# Processing file 16558/30685
# Processing file 16559/30685
# Processing file 16560/30685
# Processing file 16561/30685
# Processing file 16562/30685
# Processing file 16563/30685
# Processing file 16564/30685
# Processing file 16565/30685
# Processing file 16566/30685
# Processing file 16567/30685
# Processing file 16568/30685
# Processing file 16569/30685
# Processing file 16570/30685
# Processing file 16571/30685
# Processing file 16572/30685
# Processing file 16573/30685
# Processing file 16574/30685
# Processing file 16575/30685
# Processing file 16576/30685
# Processing file 16577/30685
# Processing file 16578/30685
# Processing file 16579/30685
# Processing file 16580/30685
# Processing file 16581/30685
# Processing file 16582/30685
# Processing file 16583/30685
# Processing file 16584/30685
# Processing file 16585/30685
# Processing file 16586/30685
# Processing file 16587/30685
# Processing file 16588/30685
# Processing file 16589/30685
# Processing file 16590/30685
# Processing file 16591/30685
# Processing file 16592/30685
# Processing file 16593/30685
# Processing file 16594/30685
# Processing file 16595/30685
# Processing file 16596/30685
# Processing file 16597/30685
# Processing file 16598/30685
# Processing file 16599/30685
# Processing file 16600/30685
# Processing file 16601/30685
# Processing file 16602/30685
# Processing file 16603/30685
# Processing file 16604/30685
# Processing file 16605/30685
# Processing file 16606/30685
# Processing file 16607/30685
# Processing file 16608/30685
# Processing file 16609/30685
# Processing file 16610/30685
# Processing file 16611/30685
# Processing file 16612/30685
# Processing file 16613/30685
# Processing file 16614/30685
# Processing file 16615/30685
# Processing file 16616/30685
# Processing file 16617/30685
# Processing file 16618/30685
# Processing file 16619/30685
# Processing file 16620/30685
# Processing file 16621/30685
# Processing file 16622/30685
# Processing file 16623/30685
# Processing file 16624/30685
# Processing file 16625/30685
# Processing file 16626/30685
# Processing file 16627/30685
# Processing file 16628/30685
# Processing file 16629/30685
# Processing file 16630/30685
# Processing file 16631/30685
# Processing file 16632/30685
# Processing file 16633/30685
# Processing file 16634/30685
# Processing file 16635/30685
# Processing file 16636/30685
# Processing file 16637/30685
# Processing file 16638/30685
# Processing file 16639/30685
# Processing file 16640/30685
# Processing file 16641/30685
# Processing file 16642/30685
# Processing file 16643/30685
# Processing file 16644/30685
# Processing file 16645/30685
# Processing file 16646/30685
# Processing file 16647/30685
# Processing file 16648/30685
# Processing file 16649/30685
# Processing file 16650/30685
# Processing file 16651/30685
# Processing file 16652/30685
# Processing file 16653/30685
# Processing file 16654/30685
# Processing file 16655/30685
# Processing file 16656/30685
# Processing file 16657/30685
# Processing file 16658/30685
# Processing file 16659/30685
# Processing file 16660/30685
# Processing file 16661/30685
# Processing file 16662/30685
# Processing file 16663/30685
# Processing file 16664/30685
# Processing file 16665/30685
# Processing file 16666/30685
# Processing file 16667/30685
# Processing file 16668/30685
# Processing file 16669/30685
# Processing file 16670/30685
# Processing file 16671/30685
# Processing file 16672/30685
# Processing file 16673/30685
# Processing file 16674/30685
# Processing file 16675/30685
# Processing file 16676/30685
# Processing file 16677/30685
# Processing file 16678/30685
# Processing file 16679/30685
# Processing file 16680/30685
# Processing file 16681/30685
# Processing file 16682/30685
# Processing file 16683/30685
# Processing file 16684/30685
# Processing file 16685/30685
# Processing file 16686/30685
# Processing file 16687/30685
# Processing file 16688/30685
# Processing file 16689/30685
# Processing file 16690/30685
# Processing file 16691/30685
# Processing file 16692/30685
# Processing file 16693/30685
# Processing file 16694/30685
# Processing file 16695/30685
# Processing file 16696/30685
# Processing file 16697/30685
# Processing file 16698/30685
# Processing file 16699/30685
# Processing file 16700/30685
# Processing file 16701/30685
# Processing file 16702/30685
# Processing file 16703/30685
# Processing file 16704/30685
# Processing file 16705/30685
# Processing file 16706/30685
# Processing file 16707/30685
# Processing file 16708/30685
# Processing file 16709/30685
# Processing file 16710/30685
# Processing file 16711/30685
# Processing file 16712/30685
# Processing file 16713/30685
# Processing file 16714/30685
# Processing file 16715/30685
# Processing file 16716/30685
# Processing file 16717/30685
# Processing file 16718/30685
# Processing file 16719/30685
# Processing file 16720/30685
# Processing file 16721/30685
# Processing file 16722/30685
# Processing file 16723/30685
# Processing file 16724/30685
# Processing file 16725/30685
# Processing file 16726/30685
# Processing file 16727/30685
# Processing file 16728/30685
# Processing file 16729/30685
# Processing file 16730/30685
# Processing file 16731/30685
# Processing file 16732/30685
# Processing file 16733/30685
# Processing file 16734/30685
# Processing file 16735/30685
# Processing file 16736/30685
# Processing file 16737/30685
# Processing file 16738/30685
# Processing file 16739/30685
# Processing file 16740/30685
# Processing file 16741/30685
# Processing file 16742/30685
# Processing file 16743/30685
# Processing file 16744/30685
# Processing file 16745/30685
# Processing file 16746/30685
# Processing file 16747/30685
# Processing file 16748/30685
# Processing file 16749/30685
# Processing file 16750/30685
# Processing file 16751/30685
# Processing file 16752/30685
# Processing file 16753/30685
# Processing file 16754/30685
# Processing file 16755/30685
# Processing file 16756/30685
# Processing file 16757/30685
# Processing file 16758/30685
# Processing file 16759/30685
# Processing file 16760/30685
# Processing file 16761/30685
# Processing file 16762/30685
# Processing file 16763/30685
# Processing file 16764/30685
# Processing file 16765/30685
# Processing file 16766/30685
# Processing file 16767/30685
# Processing file 16768/30685
# Processing file 16769/30685
# Processing file 16770/30685
# Processing file 16771/30685
# Processing file 16772/30685
# Processing file 16773/30685
# Processing file 16774/30685
# Processing file 16775/30685
# Processing file 16776/30685
# Processing file 16777/30685
# Processing file 16778/30685
# Processing file 16779/30685
# Processing file 16780/30685
# Processing file 16781/30685
# Processing file 16782/30685
# Processing file 16783/30685
# Processing file 16784/30685
# Processing file 16785/30685
# Processing file 16786/30685
# Processing file 16787/30685
# Processing file 16788/30685
# Processing file 16789/30685
# Processing file 16790/30685
# Processing file 16791/30685
# Processing file 16792/30685
# Processing file 16793/30685
# Processing file 16794/30685
# Processing file 16795/30685
# Processing file 16796/30685
# Processing file 16797/30685
# Processing file 16798/30685
# Processing file 16799/30685
# Processing file 16800/30685
# Processing file 16801/30685
# Processing file 16802/30685
# Processing file 16803/30685
# Processing file 16804/30685
# Processing file 16805/30685
# Processing file 16806/30685
# Processing file 16807/30685
# Processing file 16808/30685
# Processing file 16809/30685
# Processing file 16810/30685
# Processing file 16811/30685
# Processing file 16812/30685
# Processing file 16813/30685
# Processing file 16814/30685
# Processing file 16815/30685
# Processing file 16816/30685
# Processing file 16817/30685
# Processing file 16818/30685
# Processing file 16819/30685
# Processing file 16820/30685
# Processing file 16821/30685
# Processing file 16822/30685
# Processing file 16823/30685
# Processing file 16824/30685
# Processing file 16825/30685
# Processing file 16826/30685
# Processing file 16827/30685
# Processing file 16828/30685
# Processing file 16829/30685
# Processing file 16830/30685
# Processing file 16831/30685
# Processing file 16832/30685
# Processing file 16833/30685
# Processing file 16834/30685
# Processing file 16835/30685
# Processing file 16836/30685
# Processing file 16837/30685
# Processing file 16838/30685
# Processing file 16839/30685
# Processing file 16840/30685
# Processing file 16841/30685
# Processing file 16842/30685
# Processing file 16843/30685
# Processing file 16844/30685
# Processing file 16845/30685
# Processing file 16846/30685
# Processing file 16847/30685
# Processing file 16848/30685
# Processing file 16849/30685
# Processing file 16850/30685
# Processing file 16851/30685
# Processing file 16852/30685
# Processing file 16853/30685
# Processing file 16854/30685
# Processing file 16855/30685
# Processing file 16856/30685
# Processing file 16857/30685
# Processing file 16858/30685
# Processing file 16859/30685
# Processing file 16860/30685
# Processing file 16861/30685
# Processing file 16862/30685
# Processing file 16863/30685
# Processing file 16864/30685
# Processing file 16865/30685
# Processing file 16866/30685
# Processing file 16867/30685
# Processing file 16868/30685
# Processing file 16869/30685
# Processing file 16870/30685
# Processing file 16871/30685
# Processing file 16872/30685
# Processing file 16873/30685
# Processing file 16874/30685
# Processing file 16875/30685
# Processing file 16876/30685
# Processing file 16877/30685
# Processing file 16878/30685
# Processing file 16879/30685
# Processing file 16880/30685
# Processing file 16881/30685
# Processing file 16882/30685
# Processing file 16883/30685
# Processing file 16884/30685
# Processing file 16885/30685
# Processing file 16886/30685
# Processing file 16887/30685
# Processing file 16888/30685
# Processing file 16889/30685
# Processing file 16890/30685
# Processing file 16891/30685
# Processing file 16892/30685
# Processing file 16893/30685
# Processing file 16894/30685
# Processing file 16895/30685
# Processing file 16896/30685
# Processing file 16897/30685
# Processing file 16898/30685
# Processing file 16899/30685
# Processing file 16900/30685
# Processing file 16901/30685
# Processing file 16902/30685
# Processing file 16903/30685
# Processing file 16904/30685
# Processing file 16905/30685
# Processing file 16906/30685
# Processing file 16907/30685
# Processing file 16908/30685
# Processing file 16909/30685
# Processing file 16910/30685
# Processing file 16911/30685
# Processing file 16912/30685
# Processing file 16913/30685
# Processing file 16914/30685
# Processing file 16915/30685
# Processing file 16916/30685
# Processing file 16917/30685
# Processing file 16918/30685
# Processing file 16919/30685
# Processing file 16920/30685
# Processing file 16921/30685
# Processing file 16922/30685
# Processing file 16923/30685
# Processing file 16924/30685
# Processing file 16925/30685
# Processing file 16926/30685
# Processing file 16927/30685
# Processing file 16928/30685
# Processing file 16929/30685
# Processing file 16930/30685
# Processing file 16931/30685
# Processing file 16932/30685
# Processing file 16933/30685
# Processing file 16934/30685
# Processing file 16935/30685
# Processing file 16936/30685
# Processing file 16937/30685
# Processing file 16938/30685
# Processing file 16939/30685
# Processing file 16940/30685
# Processing file 16941/30685
# Processing file 16942/30685
# Processing file 16943/30685
# Processing file 16944/30685
# Processing file 16945/30685
# Processing file 16946/30685
# Processing file 16947/30685
# Processing file 16948/30685
# Processing file 16949/30685
# Processing file 16950/30685
# Processing file 16951/30685
# Processing file 16952/30685
# Processing file 16953/30685
# Processing file 16954/30685
# Processing file 16955/30685
# Processing file 16956/30685
# Processing file 16957/30685
# Processing file 16958/30685
# Processing file 16959/30685
# Processing file 16960/30685
# Processing file 16961/30685
# Processing file 16962/30685
# Processing file 16963/30685
# Processing file 16964/30685
# Processing file 16965/30685
# Processing file 16966/30685
# Processing file 16967/30685
# Processing file 16968/30685
# Processing file 16969/30685
# Processing file 16970/30685
# Processing file 16971/30685
# Processing file 16972/30685
# Processing file 16973/30685
# Processing file 16974/30685
# Processing file 16975/30685
# Processing file 16976/30685
# Processing file 16977/30685
# Processing file 16978/30685
# Processing file 16979/30685
# Processing file 16980/30685
# Processing file 16981/30685
# Processing file 16982/30685
# Processing file 16983/30685
# Processing file 16984/30685
# Processing file 16985/30685
# Processing file 16986/30685
# Processing file 16987/30685
# Processing file 16988/30685
# Processing file 16989/30685
# Processing file 16990/30685
# Processing file 16991/30685
# Processing file 16992/30685
# Processing file 16993/30685
# Processing file 16994/30685
# Processing file 16995/30685
# Processing file 16996/30685
# Processing file 16997/30685
# Processing file 16998/30685
# Processing file 16999/30685
# Processing file 17000/30685
# Processing file 17001/30685
# Processing file 17002/30685
# Processing file 17003/30685
# Processing file 17004/30685
# Processing file 17005/30685
# Processing file 17006/30685
# Processing file 17007/30685
# Processing file 17008/30685
# Processing file 17009/30685
# Processing file 17010/30685
# Processing file 17011/30685
# Processing file 17012/30685
# Processing file 17013/30685
# Processing file 17014/30685
# Processing file 17015/30685
# Processing file 17016/30685
# Processing file 17017/30685
# Processing file 17018/30685
# Processing file 17019/30685
# Processing file 17020/30685
# Processing file 17021/30685
# Processing file 17022/30685
# Processing file 17023/30685
# Processing file 17024/30685
# Processing file 17025/30685
# Processing file 17026/30685
# Processing file 17027/30685
# Processing file 17028/30685
# Processing file 17029/30685
# Processing file 17030/30685
# Processing file 17031/30685
# Processing file 17032/30685
# Processing file 17033/30685
# Processing file 17034/30685
# Processing file 17035/30685
# Processing file 17036/30685
# Processing file 17037/30685
# Processing file 17038/30685
# Processing file 17039/30685
# Processing file 17040/30685
# Processing file 17041/30685
# Processing file 17042/30685
# Processing file 17043/30685
# Processing file 17044/30685
# Processing file 17045/30685
# Processing file 17046/30685
# Processing file 17047/30685
# Processing file 17048/30685
# Processing file 17049/30685
# Processing file 17050/30685
# Processing file 17051/30685
# Processing file 17052/30685
# Processing file 17053/30685
# Processing file 17054/30685
# Processing file 17055/30685
# Processing file 17056/30685
# Processing file 17057/30685
# Processing file 17058/30685
# Processing file 17059/30685
# Processing file 17060/30685
# Processing file 17061/30685
# Processing file 17062/30685
# Processing file 17063/30685
# Processing file 17064/30685
# Processing file 17065/30685
# Processing file 17066/30685
# Processing file 17067/30685
# Processing file 17068/30685
# Processing file 17069/30685
# Processing file 17070/30685
# Processing file 17071/30685
# Processing file 17072/30685
# Processing file 17073/30685
# Processing file 17074/30685
# Processing file 17075/30685
# Processing file 17076/30685
# Processing file 17077/30685
# Processing file 17078/30685
# Processing file 17079/30685
# Processing file 17080/30685
# Processing file 17081/30685
# Processing file 17082/30685
# Processing file 17083/30685
# Processing file 17084/30685
# Processing file 17085/30685
# Processing file 17086/30685
# Processing file 17087/30685
# Processing file 17088/30685
# Processing file 17089/30685
# Processing file 17090/30685
# Processing file 17091/30685
# Processing file 17092/30685
# Processing file 17093/30685
# Processing file 17094/30685
# Processing file 17095/30685
# Processing file 17096/30685
# Processing file 17097/30685
# Processing file 17098/30685
# Processing file 17099/30685
# Processing file 17100/30685
# Processing file 17101/30685
# Processing file 17102/30685
# Processing file 17103/30685
# Processing file 17104/30685
# Processing file 17105/30685
# Processing file 17106/30685
# Processing file 17107/30685
# Processing file 17108/30685
# Processing file 17109/30685
# Processing file 17110/30685
# Processing file 17111/30685
# Processing file 17112/30685
# Processing file 17113/30685
# Processing file 17114/30685
# Processing file 17115/30685
# Processing file 17116/30685
# Processing file 17117/30685
# Processing file 17118/30685
# Processing file 17119/30685
# Processing file 17120/30685
# Processing file 17121/30685
# Processing file 17122/30685
# Processing file 17123/30685
# Processing file 17124/30685
# Processing file 17125/30685
# Processing file 17126/30685
# Processing file 17127/30685
# Processing file 17128/30685
# Processing file 17129/30685
# Processing file 17130/30685
# Processing file 17131/30685
# Processing file 17132/30685
# Processing file 17133/30685
# Processing file 17134/30685
# Processing file 17135/30685
# Processing file 17136/30685
# Processing file 17137/30685
# Processing file 17138/30685
# Processing file 17139/30685
# Processing file 17140/30685
# Processing file 17141/30685
# Processing file 17142/30685
# Processing file 17143/30685
# Processing file 17144/30685
# Processing file 17145/30685
# Processing file 17146/30685
# Processing file 17147/30685
# Processing file 17148/30685
# Processing file 17149/30685
# Processing file 17150/30685
# Processing file 17151/30685
# Processing file 17152/30685
# Processing file 17153/30685
# Processing file 17154/30685
# Processing file 17155/30685
# Processing file 17156/30685
# Processing file 17157/30685
# Processing file 17158/30685
# Processing file 17159/30685
# Processing file 17160/30685
# Processing file 17161/30685
# Processing file 17162/30685
# Processing file 17163/30685
# Processing file 17164/30685
# Processing file 17165/30685
# Processing file 17166/30685
# Processing file 17167/30685
# Processing file 17168/30685
# Processing file 17169/30685
# Processing file 17170/30685
# Processing file 17171/30685
# Processing file 17172/30685
# Processing file 17173/30685
# Processing file 17174/30685
# Processing file 17175/30685
# Processing file 17176/30685
# Processing file 17177/30685
# Processing file 17178/30685
# Processing file 17179/30685
# Processing file 17180/30685
# Processing file 17181/30685
# Processing file 17182/30685
# Processing file 17183/30685
# Processing file 17184/30685
# Processing file 17185/30685
# Processing file 17186/30685
# Processing file 17187/30685
# Processing file 17188/30685
# Processing file 17189/30685
# Processing file 17190/30685
# Processing file 17191/30685
# Processing file 17192/30685
# Processing file 17193/30685
# Processing file 17194/30685
# Processing file 17195/30685
# Processing file 17196/30685
# Processing file 17197/30685
# Processing file 17198/30685
# Processing file 17199/30685
# Processing file 17200/30685
# Processing file 17201/30685
# Processing file 17202/30685
# Processing file 17203/30685
# Processing file 17204/30685
# Processing file 17205/30685
# Processing file 17206/30685
# Processing file 17207/30685
# Processing file 17208/30685
# Processing file 17209/30685
# Processing file 17210/30685
# Processing file 17211/30685
# Processing file 17212/30685
# Processing file 17213/30685
# Processing file 17214/30685
# Processing file 17215/30685
# Processing file 17216/30685
# Processing file 17217/30685
# Processing file 17218/30685
# Processing file 17219/30685
# Processing file 17220/30685
# Processing file 17221/30685
# Processing file 17222/30685
# Processing file 17223/30685
# Processing file 17224/30685
# Processing file 17225/30685
# Processing file 17226/30685
# Processing file 17227/30685
# Processing file 17228/30685
# Processing file 17229/30685
# Processing file 17230/30685
# Processing file 17231/30685
# Processing file 17232/30685
# Processing file 17233/30685
# Processing file 17234/30685
# Processing file 17235/30685
# Processing file 17236/30685
# Processing file 17237/30685
# Processing file 17238/30685
# Processing file 17239/30685
# Processing file 17240/30685
# Processing file 17241/30685
# Processing file 17242/30685
# Processing file 17243/30685
# Processing file 17244/30685
# Processing file 17245/30685
# Processing file 17246/30685
# Processing file 17247/30685
# Processing file 17248/30685
# Processing file 17249/30685
# Processing file 17250/30685
# Processing file 17251/30685
# Processing file 17252/30685
# Processing file 17253/30685
# Processing file 17254/30685
# Processing file 17255/30685
# Processing file 17256/30685
# Processing file 17257/30685
# Processing file 17258/30685
# Processing file 17259/30685
# Processing file 17260/30685
# Processing file 17261/30685
# Processing file 17262/30685
# Processing file 17263/30685
# Processing file 17264/30685
# Processing file 17265/30685
# Processing file 17266/30685
# Processing file 17267/30685
# Processing file 17268/30685
# Processing file 17269/30685
# Processing file 17270/30685
# Processing file 17271/30685
# Processing file 17272/30685
# Processing file 17273/30685
# Processing file 17274/30685
# Processing file 17275/30685
# Processing file 17276/30685
# Processing file 17277/30685
# Processing file 17278/30685
# Processing file 17279/30685
# Processing file 17280/30685
# Processing file 17281/30685
# Processing file 17282/30685
# Processing file 17283/30685
# Processing file 17284/30685
# Processing file 17285/30685
# Processing file 17286/30685
# Processing file 17287/30685
# Processing file 17288/30685
# Processing file 17289/30685
# Processing file 17290/30685
# Processing file 17291/30685
# Processing file 17292/30685
# Processing file 17293/30685
# Processing file 17294/30685
# Processing file 17295/30685
# Processing file 17296/30685
# Processing file 17297/30685
# Processing file 17298/30685
# Processing file 17299/30685
# Processing file 17300/30685
# Processing file 17301/30685
# Processing file 17302/30685
# Processing file 17303/30685
# Processing file 17304/30685
# Processing file 17305/30685
# Processing file 17306/30685
# Processing file 17307/30685
# Processing file 17308/30685
# Processing file 17309/30685
# Processing file 17310/30685
# Processing file 17311/30685
# Processing file 17312/30685
# Processing file 17313/30685
# Processing file 17314/30685
# Processing file 17315/30685
# Processing file 17316/30685
# Processing file 17317/30685
# Processing file 17318/30685
# Processing file 17319/30685
# Processing file 17320/30685
# Processing file 17321/30685
# Processing file 17322/30685
# Processing file 17323/30685
# Processing file 17324/30685
# Processing file 17325/30685
# Processing file 17326/30685
# Processing file 17327/30685
# Processing file 17328/30685
# Processing file 17329/30685
# Processing file 17330/30685
# Processing file 17331/30685
# Processing file 17332/30685
# Processing file 17333/30685
# Processing file 17334/30685
# Processing file 17335/30685
# Processing file 17336/30685
# Processing file 17337/30685
# Processing file 17338/30685
# Processing file 17339/30685
# Processing file 17340/30685
# Processing file 17341/30685
# Processing file 17342/30685
# Processing file 17343/30685
# Processing file 17344/30685
# Processing file 17345/30685
# Processing file 17346/30685
# Processing file 17347/30685
# Processing file 17348/30685
# Processing file 17349/30685
# Processing file 17350/30685
# Processing file 17351/30685
# Processing file 17352/30685
# Processing file 17353/30685
# Processing file 17354/30685
# Processing file 17355/30685
# Processing file 17356/30685
# Processing file 17357/30685
# Processing file 17358/30685
# Processing file 17359/30685
# Processing file 17360/30685
# Processing file 17361/30685
# Processing file 17362/30685
# Processing file 17363/30685
# Processing file 17364/30685
# Processing file 17365/30685
# Processing file 17366/30685
# Processing file 17367/30685
# Processing file 17368/30685
# Processing file 17369/30685
# Processing file 17370/30685
# Processing file 17371/30685
# Processing file 17372/30685
# Processing file 17373/30685
# Processing file 17374/30685
# Processing file 17375/30685
# Processing file 17376/30685
# Processing file 17377/30685
# Processing file 17378/30685
# Processing file 17379/30685
# Processing file 17380/30685
# Processing file 17381/30685
# Processing file 17382/30685
# Processing file 17383/30685
# Processing file 17384/30685
# Processing file 17385/30685
# Processing file 17386/30685
# Processing file 17387/30685
# Processing file 17388/30685
# Processing file 17389/30685
# Processing file 17390/30685
# Processing file 17391/30685
# Processing file 17392/30685
# Processing file 17393/30685
# Processing file 17394/30685
# Processing file 17395/30685
# Processing file 17396/30685
# Processing file 17397/30685
# Processing file 17398/30685
# Processing file 17399/30685
# Processing file 17400/30685
# Processing file 17401/30685
# Processing file 17402/30685
# Processing file 17403/30685
# Processing file 17404/30685
# Processing file 17405/30685
# Processing file 17406/30685
# Processing file 17407/30685
# Processing file 17408/30685
# Processing file 17409/30685
# Processing file 17410/30685
# Processing file 17411/30685
# Processing file 17412/30685
# Processing file 17413/30685
# Processing file 17414/30685
# Processing file 17415/30685
# Processing file 17416/30685
# Processing file 17417/30685
# Processing file 17418/30685
# Processing file 17419/30685
# Processing file 17420/30685
# Processing file 17421/30685
# Processing file 17422/30685
# Processing file 17423/30685
# Processing file 17424/30685
# Processing file 17425/30685
# Processing file 17426/30685
# Processing file 17427/30685
# Processing file 17428/30685
# Processing file 17429/30685
# Processing file 17430/30685
# Processing file 17431/30685
# Processing file 17432/30685
# Processing file 17433/30685
# Processing file 17434/30685
# Processing file 17435/30685
# Processing file 17436/30685
# Processing file 17437/30685
# Processing file 17438/30685
# Processing file 17439/30685
# Processing file 17440/30685
# Processing file 17441/30685
# Processing file 17442/30685
# Processing file 17443/30685
# Processing file 17444/30685
# Processing file 17445/30685
# Processing file 17446/30685
# Processing file 17447/30685
# Processing file 17448/30685
# Processing file 17449/30685
# Processing file 17450/30685
# Processing file 17451/30685
# Processing file 17452/30685
# Processing file 17453/30685
# Processing file 17454/30685
# Processing file 17455/30685
# Processing file 17456/30685
# Processing file 17457/30685
# Processing file 17458/30685
# Processing file 17459/30685
# Processing file 17460/30685
# Processing file 17461/30685
# Processing file 17462/30685
# Processing file 17463/30685
# Processing file 17464/30685
# Processing file 17465/30685
# Processing file 17466/30685
# Processing file 17467/30685
# Processing file 17468/30685
# Processing file 17469/30685
# Processing file 17470/30685
# Processing file 17471/30685
# Processing file 17472/30685
# Processing file 17473/30685
# Processing file 17474/30685
# Processing file 17475/30685
# Processing file 17476/30685
# Processing file 17477/30685
# Processing file 17478/30685
# Processing file 17479/30685
# Processing file 17480/30685
# ...
# Processing file 30115/30685
# Processing file 30116/30685
# Processing file 30117/30685
# Processing file 30118/30685
# Processing file 30119/30685
# Processing file 30120/30685
# Processing file 30121/30685
# Processing file 30122/30685
# Processing file 30123/30685
# Processing file 30124/30685
# Processing file 30125/30685
# Processing file 30126/30685
# Processing file 30127/30685
# Processing file 30128/30685
# Processing file 30129/30685
# Processing file 30130/30685
# Processing file 30131/30685
# Processing file 30132/30685
# Processing file 30133/30685
# Processing file 30134/30685
# Processing file 30135/30685
# Processing file 30136/30685
# Processing file 30137/30685
# Processing file 30138/30685
# Processing file 30139/30685
# Processing file 30140/30685
# Processing file 30141/30685
# Processing file 30142/30685
# Processing file 30143/30685
# Processing file 30144/30685
# Processing file 30145/30685
# Processing file 30146/30685
# Processing file 30147/30685
# Processing file 30148/30685
# Processing file 30149/30685
# Processing file 30150/30685
# Processing file 30151/30685
# Processing file 30152/30685
# Processing file 30153/30685
# Processing file 30154/30685
# Processing file 30155/30685
# Processing file 30156/30685
# Processing file 30157/30685
# Processing file 30158/30685
# Processing file 30159/30685
# Processing file 30160/30685
# Processing file 30161/30685
# Processing file 30162/30685
# Processing file 30163/30685
# Processing file 30164/30685
# Processing file 30165/30685
# Processing file 30166/30685
# Processing file 30167/30685
# Processing file 30168/30685
# Processing file 30169/30685
# Processing file 30170/30685
# Processing file 30171/30685
# Processing file 30172/30685
# Processing file 30173/30685
# Processing file 30174/30685
# Processing file 30175/30685
# Processing file 30176/30685
# Processing file 30177/30685
# Processing file 30178/30685
# Processing file 30179/30685
# Processing file 30180/30685
# Processing file 30181/30685
# Processing file 30182/30685
# Processing file 30183/30685
# Processing file 30184/30685
# Processing file 30185/30685
# Processing file 30186/30685
# Processing file 30187/30685
# Processing file 30188/30685
# Processing file 30189/30685
# Processing file 30190/30685
# Processing file 30191/30685
# Processing file 30192/30685
# Processing file 30193/30685
# Processing file 30194/30685
# Processing file 30195/30685
# Processing file 30196/30685
# Processing file 30197/30685
# Processing file 30198/30685
# Processing file 30199/30685
# Processing file 30200/30685
# Processing file 30201/30685
# Processing file 30202/30685
# Processing file 30203/30685
# Processing file 30204/30685
# Processing file 30205/30685
# Processing file 30206/30685
# Processing file 30207/30685
# Processing file 30208/30685
# Processing file 30209/30685
# Processing file 30210/30685
# Processing file 30211/30685
# Processing file 30212/30685
# Processing file 30213/30685
# Processing file 30214/30685
# Processing file 30215/30685
# Processing file 30216/30685
# Processing file 30217/30685
# Processing file 30218/30685
# Processing file 30219/30685
# Processing file 30220/30685
# Processing file 30221/30685
# Processing file 30222/30685
# Processing file 30223/30685
# Processing file 30224/30685
# Processing file 30225/30685
# Processing file 30226/30685
# Processing file 30227/30685
# Processing file 30228/30685
# Processing file 30229/30685
# Processing file 30230/30685
# Processing file 30231/30685
# Processing file 30232/30685
# Processing file 30233/30685
# Processing file 30234/30685
# Processing file 30235/30685
# Processing file 30236/30685
# Processing file 30237/30685
# Processing file 30238/30685
# Processing file 30239/30685
# Processing file 30240/30685
# Processing file 30241/30685
# Processing file 30242/30685
# Processing file 30243/30685
# Processing file 30244/30685
# Processing file 30245/30685
# Processing file 30246/30685
# Processing file 30247/30685
# Processing file 30248/30685
# Processing file 30249/30685
# Processing file 30250/30685
# Processing file 30251/30685
# Processing file 30252/30685
# Processing file 30253/30685
# Processing file 30254/30685
# Processing file 30255/30685
# Processing file 30256/30685
# Processing file 30257/30685
# Processing file 30258/30685
# Processing file 30259/30685
# Processing file 30260/30685
# Processing file 30261/30685
# Processing file 30262/30685
# Processing file 30263/30685
# Processing file 30264/30685
# Processing file 30265/30685
# Processing file 30266/30685
# Processing file 30267/30685
# Processing file 30268/30685
# Processing file 30269/30685
# Processing file 30270/30685
# Processing file 30271/30685
# Processing file 30272/30685
# Processing file 30273/30685
# Processing file 30274/30685
# Processing file 30275/30685
# Processing file 30276/30685
# Processing file 30277/30685
# Processing file 30278/30685
# Processing file 30279/30685
# Processing file 30280/30685
# Processing file 30281/30685
# Processing file 30282/30685
# Processing file 30283/30685
# Processing file 30284/30685
# Processing file 30285/30685
# Processing file 30286/30685
# Processing file 30287/30685
# Processing file 30288/30685
# Processing file 30289/30685
# Processing file 30290/30685
# Processing file 30291/30685
# Processing file 30292/30685
# Processing file 30293/30685
# Processing file 30294/30685
# Processing file 30295/30685
# Processing file 30296/30685
# Processing file 30297/30685
# Processing file 30298/30685
# Processing file 30299/30685
# Processing file 30300/30685
# Processing file 30301/30685
# Processing file 30302/30685
# Processing file 30303/30685
# Processing file 30304/30685
# Processing file 30305/30685
# Processing file 30306/30685
# Processing file 30307/30685
# Processing file 30308/30685
# Processing file 30309/30685
# Processing file 30310/30685
# Processing file 30311/30685
# Processing file 30312/30685
# Processing file 30313/30685
# Processing file 30314/30685
# Processing file 30315/30685
# Processing file 30316/30685
# Processing file 30317/30685
# Processing file 30318/30685
# Processing file 30319/30685
# Processing file 30320/30685
# Processing file 30321/30685
# Processing file 30322/30685
# Processing file 30323/30685
# Processing file 30324/30685
# Processing file 30325/30685
# Processing file 30326/30685
# Processing file 30327/30685
# Processing file 30328/30685
# Processing file 30329/30685
# Processing file 30330/30685
# Processing file 30331/30685
# Processing file 30332/30685
# Processing file 30333/30685
# Processing file 30334/30685
# Processing file 30335/30685
# Processing file 30336/30685
# Processing file 30337/30685
# Processing file 30338/30685
# Processing file 30339/30685
# Processing file 30340/30685
# Processing file 30341/30685
# Processing file 30342/30685
# Processing file 30343/30685
# Processing file 30344/30685
# Processing file 30345/30685
# Processing file 30346/30685
# Processing file 30347/30685
# Processing file 30348/30685
# Processing file 30349/30685
# Processing file 30350/30685
# Processing file 30351/30685
# Processing file 30352/30685
# Processing file 30353/30685
# Processing file 30354/30685
# Processing file 30355/30685
# Processing file 30356/30685
# Processing file 30357/30685
# Processing file 30358/30685
# Processing file 30359/30685
# Processing file 30360/30685
# Processing file 30361/30685
# Processing file 30362/30685
# Processing file 30363/30685
# Processing file 30364/30685
# Processing file 30365/30685
# Processing file 30366/30685
# Processing file 30367/30685
# Processing file 30368/30685
# Processing file 30369/30685
# Processing file 30370/30685
# Processing file 30371/30685
# Processing file 30372/30685
# Processing file 30373/30685
# Processing file 30374/30685
# Processing file 30375/30685
# Processing file 30376/30685
# Processing file 30377/30685
# Processing file 30378/30685
# Processing file 30379/30685
# Processing file 30380/30685
# Processing file 30381/30685
# Processing file 30382/30685
# Processing file 30383/30685
# Processing file 30384/30685
# Processing file 30385/30685
# Processing file 30386/30685
# Processing file 30387/30685
# Processing file 30388/30685
# Processing file 30389/30685
# Processing file 30390/30685
# Processing file 30391/30685
# Processing file 30392/30685
# Processing file 30393/30685
# Processing file 30394/30685
# Processing file 30395/30685
# Processing file 30396/30685
# Processing file 30397/30685
# Processing file 30398/30685
# Processing file 30399/30685
# Processing file 30400/30685
# Processing file 30401/30685
# Processing file 30402/30685
# Processing file 30403/30685
# Processing file 30404/30685
# Processing file 30405/30685
# Processing file 30406/30685
# Processing file 30407/30685
# Processing file 30408/30685
# Processing file 30409/30685
# Processing file 30410/30685
# Processing file 30411/30685
# Processing file 30412/30685
# Processing file 30413/30685
# Processing file 30414/30685
# Processing file 30415/30685
# Processing file 30416/30685
# Processing file 30417/30685
# Processing file 30418/30685
# Processing file 30419/30685
# Processing file 30420/30685
# Processing file 30421/30685
# Processing file 30422/30685
# Processing file 30423/30685
# Processing file 30424/30685
# Processing file 30425/30685
# Processing file 30426/30685
# Processing file 30427/30685
# Processing file 30428/30685
# Processing file 30429/30685
# Processing file 30430/30685
# Processing file 30431/30685
# Processing file 30432/30685
# Processing file 30433/30685
# Processing file 30434/30685
# Processing file 30435/30685
# Processing file 30436/30685
# Processing file 30437/30685
# Processing file 30438/30685
# Processing file 30439/30685
# Processing file 30440/30685
# Processing file 30441/30685
# Processing file 30442/30685
# Processing file 30443/30685
# Processing file 30444/30685
# Processing file 30445/30685
# Processing file 30446/30685
# Processing file 30447/30685
# Processing file 30448/30685
# Processing file 30449/30685
# Processing file 30450/30685
# Processing file 30451/30685
# Processing file 30452/30685
# Processing file 30453/30685
# Processing file 30454/30685
# Processing file 30455/30685
# Processing file 30456/30685
# Processing file 30457/30685
# Processing file 30458/30685
# Processing file 30459/30685
# Processing file 30460/30685
# Processing file 30461/30685
# Processing file 30462/30685
# Processing file 30463/30685
# Processing file 30464/30685
# Processing file 30465/30685
# Processing file 30466/30685
# Processing file 30467/30685
# Processing file 30468/30685
# Processing file 30469/30685
# Processing file 30470/30685
# Processing file 30471/30685
# Processing file 30472/30685
# Processing file 30473/30685
# Processing file 30474/30685
# Processing file 30475/30685
# Processing file 30476/30685
# Processing file 30477/30685
# Processing file 30478/30685
# Processing file 30479/30685
# Processing file 30480/30685
# Processing file 30481/30685
# Processing file 30482/30685
# Processing file 30483/30685
# Processing file 30484/30685
# Processing file 30485/30685
# Processing file 30486/30685
# Processing file 30487/30685
# Processing file 30488/30685
# Processing file 30489/30685
# Processing file 30490/30685
# Processing file 30491/30685
# Processing file 30492/30685
# Processing file 30493/30685
# Processing file 30494/30685
# Processing file 30495/30685
# Processing file 30496/30685
# Processing file 30497/30685
# Processing file 30498/30685
# Processing file 30499/30685
# Processing file 30500/30685
# Processing file 30501/30685
# Processing file 30502/30685
# Processing file 30503/30685
# Processing file 30504/30685
# Processing file 30505/30685
# Processing file 30506/30685
# Processing file 30507/30685
# Processing file 30508/30685
# Processing file 30509/30685
# Processing file 30510/30685
# Processing file 30511/30685
# Processing file 30512/30685
# Processing file 30513/30685
# Processing file 30514/30685
# Processing file 30515/30685
# Processing file 30516/30685
# Processing file 30517/30685
# Processing file 30518/30685
# Processing file 30519/30685
# Processing file 30520/30685
# Processing file 30521/30685
# Processing file 30522/30685
# Processing file 30523/30685
# Processing file 30524/30685
# Processing file 30525/30685
# Processing file 30526/30685
# Processing file 30527/30685
# Processing file 30528/30685
# Processing file 30529/30685
# Processing file 30530/30685
# Processing file 30531/30685
# Processing file 30532/30685
# Processing file 30533/30685
# Processing file 30534/30685
# Processing file 30535/30685
# Processing file 30536/30685
# Processing file 30537/30685
# Processing file 30538/30685
# Processing file 30539/30685
# Processing file 30540/30685
# Processing file 30541/30685
# Processing file 30542/30685
# Processing file 30543/30685
# Processing file 30544/30685
# Processing file 30545/30685
# Processing file 30546/30685
# Processing file 30547/30685
# Processing file 30548/30685
# Processing file 30549/30685
# Processing file 30550/30685
# Processing file 30551/30685
# Processing file 30552/30685
# Processing file 30553/30685
# Processing file 30554/30685
# Processing file 30555/30685
# Processing file 30556/30685
# Processing file 30557/30685
# Processing file 30558/30685
# Processing file 30559/30685
# Processing file 30560/30685
# Processing file 30561/30685
# Processing file 30562/30685
# Processing file 30563/30685
# Processing file 30564/30685
# Processing file 30565/30685
# Processing file 30566/30685
# Processing file 30567/30685
# Processing file 30568/30685
# Processing file 30569/30685
# Processing file 30570/30685
# Processing file 30571/30685
# Processing file 30572/30685
# Processing file 30573/30685
# Processing file 30574/30685
# Processing file 30575/30685
# Processing file 30576/30685
# Processing file 30577/30685
# Processing file 30578/30685
# Processing file 30579/30685
# Processing file 30580/30685
# Processing file 30581/30685
# Processing file 30582/30685
# Processing file 30583/30685
# Processing file 30584/30685
# Processing file 30585/30685
# Processing file 30586/30685
# Processing file 30587/30685
# Processing file 30588/30685
# Processing file 30589/30685
# Processing file 30590/30685
# Processing file 30591/30685
# Processing file 30592/30685
# Processing file 30593/30685
# Processing file 30594/30685
# Processing file 30595/30685
# Processing file 30596/30685
# Processing file 30597/30685
# Processing file 30598/30685
# Processing file 30599/30685
# Processing file 30600/30685
# Processing file 30601/30685
# Processing file 30602/30685
# Processing file 30603/30685
# Processing file 30604/30685
# Processing file 30605/30685
# Processing file 30606/30685
# Processing file 30607/30685
# Processing file 30608/30685
# Processing file 30609/30685
# Processing file 30610/30685
# Processing file 30611/30685
# Processing file 30612/30685
# Processing file 30613/30685
# Processing file 30614/30685
# Processing file 30615/30685
# Processing file 30616/30685
# Processing file 30617/30685
# Processing file 30618/30685
# Processing file 30619/30685
# Processing file 30620/30685
# Processing file 30621/30685
# Processing file 30622/30685
# Processing file 30623/30685
# Processing file 30624/30685
# Processing file 30625/30685
# Processing file 30626/30685
# Processing file 30627/30685
# Processing file 30628/30685
# Processing file 30629/30685
# Processing file 30630/30685
# Processing file 30631/30685
# Processing file 30632/30685
# Processing file 30633/30685
# Processing file 30634/30685
# Processing file 30635/30685
# Processing file 30636/30685
# Processing file 30637/30685
# Processing file 30638/30685
# Processing file 30639/30685
# Processing file 30640/30685
# Processing file 30641/30685
# Processing file 30642/30685
# Processing file 30643/30685
# Processing file 30644/30685
# Processing file 30645/30685
# Processing file 30646/30685
# Processing file 30647/30685
# Processing file 30648/30685
# Processing file 30649/30685
# Processing file 30650/30685
# Processing file 30651/30685
# Processing file 30652/30685
# Processing file 30653/30685
# Processing file 30654/30685
# Processing file 30655/30685
# Processing file 30656/30685
# Processing file 30657/30685
# Processing file 30658/30685
# Processing file 30659/30685
# Processing file 30660/30685
# Processing file 30661/30685
# Processing file 30662/30685
# Processing file 30663/30685
# Processing file 30664/30685
# Processing file 30665/30685
# Processing file 30666/30685
# Processing file 30667/30685
# Processing file 30668/30685
# Processing file 30669/30685
# Processing file 30670/30685
# Processing file 30671/30685
# Processing file 30672/30685
# Processing file 30673/30685
# Processing file 30674/30685
# Processing file 30675/30685
# Processing file 30676/30685
# Processing file 30677/30685
# Processing file 30678/30685
# Processing file 30679/30685
# Processing file 30680/30685
# Processing file 30681/30685
# Processing file 30682/30685
# Processing file 30683/30685
# Processing file 30684/30685
# Processing file 30685/30685

# %%
print(input_data.shape)  # (n, 200, 200, 1) 
print(labels.shape)      # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
type(input_data)
# Out:
# numpy.ndarray

# %%
type(labels)
# Out:
# numpy.ndarray

# %%
def check_duplicates_within_set(X, Y):
    unique_X, unique_indices = np.unique(X, axis=0, return_index=True)
    unique_Y = Y[unique_indices]

    print(f"{len(X)-len(unique_X)} duplicates found.")

    return unique_X, unique_Y

# %%
X, Y = check_duplicates_within_set(input_data, labels)
# Out:
# 0 duplicates found.

# %%
print(X.shape)  # (n, 200, 200, 1) 
print(Y.shape)  # (n,)
# Out:
# (12870, 200, 200, 1)
# (12870,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, stratify=Y, test_size=0.4, random_state=42) # stratify with labels (Y)

# %%
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5, random_state=42)

# %%
print(X_train.shape)  # (n, 200, 200, 1)
print(X_test.shape)   # (n, 200, 200, 1)
print(X_val.shape)    # (n, 200, 200, 1)
# Out:
# (7722, 200, 200, 1)
# (2574, 200, 200, 1)
# (2574, 200, 200, 1)

# %%
print(Y_train.shape)  # (n,) 
print(Y_test.shape)   # (n,) 
print(Y_val.shape)    # (n,)
# Out:
# (7722,)
# (2574,)
# (2574,)

# %% [markdown]
# *The training set, validation set and test set were split in the ratio 60 : 20 : 20.*

# %% [markdown]
# ## Augmentation

# %%
def custom_rotation(x):
    angle = np.random.choice([90, 180, 270])  # Randomly selects between 90, 180, and 270 degrees
    return np.rot90(x, k=angle // 90)  # k specifies the number of 90° rotations

# Define data augmentation (only for training data)
datagen = ImageDataGenerator(
    preprocessing_function=custom_rotation,  # Limit rotations to 90°, 180°, and 270°
    horizontal_flip=True,   # Flip images horizontally
)

# Fit the generator to the training data
datagen.fit(X_train)

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ### Check if x any y fit together

# %%
X_train[1].shape
# Out:
# (200, 200, 1)

# %%
type(X_train[1])
# Out:
# numpy.ndarray

# %%
# Convert to float32
image = X_train[1].squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()

# %%
Y_train[1]
# Out:
# 0.636

# %% [markdown]
# ### Check histogramm for image values

# %%
plt.hist(X_train[1].flatten(), bins=50, range=(0, 1))
plt.title('Verteilung der Pixelwerte')
plt.show()

# %%
print(f"Min: {np.min(X_train)}, Max: {np.max(X_train)}")
# Out:
# Min: 0.1412353515625, Max: 1.0

# %% [markdown]
# ### Check if null or inf values in train_y

# %%
assert not np.any(np.isnan(image)), "NaN-values found"
assert not np.any(np.isinf(image)), "infinite values found"
assert X_train[5].shape == (200, 200, 1), "image has unexpected form"

# %% [markdown]
# ### Check Data Distribution

# %%
# Plot histogram
plt.hist(Y_train, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Train")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_test, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Test")
plt.grid(True)

# Show the plot
plt.show()

# %%
# Plot histogram
plt.hist(Y_val, bins=100, edgecolor='black')  # 100 bins, black edges
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Val")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Training

# %%
logdir = r'..\logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    r'..\checkpoints\best_weights.weights.h5',
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    initial_value_threshold=None
)

# %% [markdown]
# *It was trained with the Keras library on an Intel® Core™ I7-4970 CPU running at 3.60 GHz using 8 parallel processing units. Training was completed in 5 h—for 30 epochs total. A batch size of 32 was used for the training.*
#
# I will instead use my GPU, since its simply way faster.

# %%
# Check if GPU's are available
gpus = tf.config.list_physical_devices('GPU')
print(f"{len(gpus)} GPUs erkannt:")
for gpu in gpus:
    print(gpu)
# Out:
# 1 GPUs erkannt:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# If a GPU is available, enable memory growth (prevents memory issues)
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled.")
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %% [markdown]
# *Verify loss @ init. Verify that your loss starts at the correct loss value*

# %%
# Calculate the initial loss before training
init_loss = model.evaluate(X_val, Y_val, verbose=1)
print(f"Initial Loss: {init_loss[0]}")  # Should be approximately 1/3
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746789553.090876  610861 service.cc:152] XLA service 0x7f899c003850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746789553.091027  610861 service.cc:160]   StreamExecutor device (0): NVIDIA A30 MIG 4g.24gb, Compute Capability 8.0
# 2025-05-09 11:19:13.204336: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-09 11:19:13.204977: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-09 11:19:13.208684: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1746789553.620549  610861 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  6/81 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - RootMeanSquaredError: 0.8662 - loss: 0.7504
# I0000 00:00:1746789555.708125  610861 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - RootMeanSquaredError: 0.8726 - loss: 0.7614
# 2025-05-09 11:19:17.621651: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-09 11:19:17.621773: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - RootMeanSquaredError: 0.8726 - loss: 0.7614
# Initial Loss: 0.7603969573974609

# %%
# CALLBACKS (optional)

# EarlyStopping callback, stops training when validation loss does not improve
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

# ModelCheckpoint callback, saves the best model based on validation loss
# checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)

def scheduler(epoch, lr): # Exponential Decay
    decay_rate = 0.90     # reduced 10% every decay_epochs...
    decay_epoch = 100     
    return lr * decay_rate**(epoch // decay_epoch)

lr_scheduler = LearningRateScheduler(scheduler)

# HYPERPARAMETER

batch_size = 32    # the original paper used a batch size of 32
epochs = 1000       # the original paper used 30 epochs 
shuffle = True

hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=batch_size),  # Use the generator here
    epochs=epochs,
    validation_data=(X_val, Y_val),
    shuffle=shuffle,
    verbose=0,  # muss 0 sein für tqdm
    callbacks=[TqdmCallback(verbose=1), early_stopping, lr_scheduler]
)
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# /opt/conda/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-05-09 11:19:23.925565: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-09 11:19:23.926510: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2025-05-09 11:19:29.791934: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-09 11:19:29.792030: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert

# %% [markdown]
# ## Plot Train, Test and Val Loss

# %% [markdown]
# *add significant digits to your eval. When plotting the test loss run the evaluation over the entire (large) test set. Do not just plot test losses over batches and then rely on smoothing them in Tensorboard. We are in pursuit of correctness and are very willing to give up time for staying sane.*

# %%
# Evaluation on the entire test set
test_loss = model.evaluate(X_test, Y_test, batch_size = 1, verbose=1)
# Out:
# 2025-05-09 11:42:50.305463: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_equal_1/Assert/Assert
# 2025-05-09 11:42:50.305743: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator functional_1/lambda_1/grayscale_to_rgb/assert_greater_equal/Assert/Assert
# 2574/2574 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - RootMeanSquaredError: 0.0886 - loss: 0.0079

# %%
print(hist.history.keys())
# Out:
# dict_keys(['RootMeanSquaredError', 'loss', 'val_RootMeanSquaredError', 'val_loss', 'learning_rate'])

# %%
print(hist.history)
# Out:
# {'RootMeanSquaredError': [0.5419102311134338, 0.476250559091568, 0.44791683554649353, 0.4342528283596039, 0.42047059535980225, 0.41124895215034485, 0.40494468808174133, 0.3997252285480499, 0.3925180733203888, 0.3885144293308258, 0.38503459095954895, 0.38063153624534607, 0.3768119215965271, 0.3734259009361267, 0.36886274814605713, 0.3665754795074463, 0.3626890182495117, 0.3588886857032776, 0.35705992579460144, 0.35366931557655334, 0.35004913806915283, 0.3478410243988037, 0.34405145049095154, 0.3426889181137085, 0.3390611410140991, 0.33576342463493347, 0.3343289792537689, 0.33157938718795776, 0.3288729786872864, 0.3255281150341034, 0.3236888349056244, 0.3209930658340454, 0.3183025121688843, 0.3160005509853363, 0.3134042024612427, 0.31149622797966003, 0.3087933361530304, 0.3062535524368286, 0.30432119965553284, 0.30141404271125793, 0.29912272095680237, 0.29675331711769104, 0.29383161664009094, 0.29214945435523987, 0.28966236114501953, 0.2870051860809326, 0.2848080098628998, 0.28237709403038025, 0.28020599484443665, 0.2778627872467041, 0.2753463387489319, 0.27289336919784546, 0.27049410343170166, 0.2682133913040161, 0.26616203784942627, 0.26363319158554077, 0.26178401708602905, 0.2593662440776825, 0.256666898727417, 0.25446707010269165, 0.25200697779655457, 0.2495080977678299, 0.24745310842990875, 0.24468733370304108, 0.2429334968328476, 0.24003037810325623, 0.2380881905555725, 0.23614592850208282, 0.2334551215171814, 0.23113510012626648, 0.22918064892292023, 0.22653773427009583, 0.22433991730213165, 0.2220991551876068, 0.21971505880355835, 0.21707898378372192, 0.21472327411174774, 0.21329596638679504, 0.21080255508422852, 0.208573117852211, 0.20635904371738434, 0.20355777442455292, 0.20130768418312073, 0.1988641321659088, 0.1968454122543335, 0.19434583187103271, 0.19234707951545715, 0.18997736275196075, 0.18770939111709595, 0.18560446798801422, 0.18314337730407715, 0.18115569651126862, 0.17906968295574188, 0.17669197916984558, 0.1744096726179123, 0.17220720648765564, 0.1700408160686493, 0.1677299439907074, 0.1649988740682602, 0.16288596391677856, 0.16136854887008667, 0.15968501567840576, 0.15778611600399017, 0.15634985268115997, 0.15518338978290558, 0.15370109677314758, 0.1530030369758606, 0.15115435421466827, 0.15054123103618622, 0.15004874765872955, 0.14920519292354584, 0.1484096348285675, 0.14804548025131226, 0.1473313421010971, 0.1469765454530716, 0.14613224565982819, 0.14638131856918335, 0.1454823613166809, 0.1451401710510254, 0.14516255259513855, 0.14480188488960266, 0.1451556235551834, 0.14466266334056854, 0.14384877681732178, 0.14440907537937164, 0.14451147615909576, 0.14373518526554108, 0.14393803477287292, 0.14354538917541504, 0.14303073287010193, 0.14371243119239807, 0.14312900602817535, 0.14358241856098175, 0.14342759549617767, 0.14340202510356903, 0.14282110333442688, 0.14315012097358704, 0.1431710124015808, 0.1430220603942871, 0.1432439237833023, 0.14338842034339905, 0.14268328249454498, 0.14303170144557953, 0.14261534810066223, 0.14305980503559113, 0.1428089290857315, 0.14233210682868958, 0.14300589263439178, 0.1427161991596222, 0.14301514625549316, 0.14226500689983368, 0.14364035427570343, 0.14259693026542664, 0.1423622965812683, 0.1424204558134079, 0.14264477789402008, 0.14201489090919495, 0.14284038543701172, 0.14317010343074799, 0.14248789846897125, 0.14236724376678467, 0.14268800616264343, 0.1427648961544037, 0.14238931238651276, 0.14257855713367462, 0.14264337718486786, 0.1424126774072647, 0.1426946073770523, 0.14293096959590912, 0.14339983463287354, 0.1423238068819046, 0.14240682125091553, 0.14269177615642548, 0.14289890229701996, 0.14251954853534698, 0.14270038902759552, 0.1425597071647644, 0.14296773076057434, 0.14296947419643402, 0.14280597865581512, 0.14260591566562653, 0.1425379514694214, 0.14299343526363373, 0.14291410148143768, 0.1423492282629013, 0.1426825076341629, 0.14278340339660645, 0.14330576360225677, 0.1427578330039978, 0.1423102468252182, 0.14322641491889954, 0.1423472911119461, 0.14218215644 ...

# %%
# Mean Squared Errors (Loss)
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='train_loss') # , marker='.' for akk exact points of graph
plt.plot(hist.history['val_loss'], color='orange', label='val_loss') # , marker='.' for akk exact points of graph
plt.axhline(y=test_loss[0], color='gray', linestyle='--', label='test_loss (final)')
plt.ylim(0, 1) # try commenting this...
fig.suptitle('Loss = Mean Squared Error', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
# # Root Mean Squared Errors (Metric) 
fig = plt.figure()
plt.plot(hist.history['RootMeanSquaredError'], color='teal', label='train_rmse', marker='.') # depends on tensorflow version if root_mean_squared_error or RootMeanSquaredError
plt.plot(hist.history['val_RootMeanSquaredError'], color='orange', label='val_rmse', marker='.')
plt.axhline(y=test_loss[1], color='gray', linestyle='--', label='test_rmse (final)')
plt.ylim(0, 1)
fig.suptitle('Root Mean Squared Error', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Evaluate Performance

# %% [markdown]
# The labels from the paper are in a range from 0.06 to 0.65.

# %% [markdown]
# ### Performance

# %%
mse = MeanSquaredError()
rmse = RootMeanSquaredError()
mape = MeanAbsolutePercentageError()
mae = MeanAbsoluteError()

# %%
batch_size = 1  # If your model was trained with batches (for a more accurate test, it's still better to use 1)

y_true = []
y_pred = []

# Calculate metrics over all test data in batches
for i in range(0, len(X_test), batch_size):
    X_batch = X_test[i:i+batch_size]  # Take a batch of test data
    y_batch = Y_test[i:i+batch_size]  # Corresponding labels
    yhat_batch = model.predict(X_batch, verbose=0)  # Model prediction for the batch
    
    # Store true values and predictions
    y_true.append(y_batch)
    y_pred.append(yhat_batch)

    # Update metrics
    mse.update_state(y_batch, yhat_batch)
    rmse.update_state(y_batch, yhat_batch)
    mae.update_state(y_batch, yhat_batch)
    mape.update_state(y_batch, yhat_batch)
    
y_true = np.concatenate(y_true, axis=0)
y_pred = np.concatenate(y_pred, axis=0)

# R²-Score
r2 = r2_score(y_true, y_pred)

# %%
print(f"Mean Squared Error (MSE): {mse.result().numpy():.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse.result().numpy():.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape.result().numpy():.2f}%")
print(f"Mean Absolute Error (MAPE): {mae.result().numpy():.2f}")
print(f"R²-Score: {r2}")
# Out:
# Mean Squared Error (MSE): 0.0078
# Root Mean Squared Error (RMSE): 0.0886
# Mean Absolute Percentage Error (MAPE): 19.28%
# Mean Absolute Error (MAPE): 0.07
# R²-Score: 0.3571418523788452

# %% [markdown]
# ## Predict SDAS for some specific test image

# %%
test_index = 1001
test_image = X_test[test_index]
test_label = Y_test[test_index]

print(test_image.shape)

# Convert Image to float32 numpy array
image = test_image.squeeze().astype(np.float32)

# Plot the image
plt.imshow(image, cmap='gray')
plt.show()
# Out:
# (200, 200, 1)

# %%
print(np.expand_dims(test_image, axis=0).shape)
# Out:
# (1, 200, 200, 1)

# %%
yhat = model.predict(np.expand_dims(test_image, axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
print("Ground Truth S_value: ", test_label*100)
print("Predicted S_value: ", round(yhat[0][0] * 100, 2))
# Out:
# Ground Truth S_value:  27.2705078125
# Predicted S_value:  27.7

# %% [markdown]
# ## Export Model

# %%
# model.save(os.path.join(r'..\models', '29.4.25_v2.keras'))

# %% [markdown]
# ## Make Predictions on real images

# %%
#test_dataset_version = "bmw_data" #210 images

test_dir = r'../data/bmw_test'

# %%
min_size = 200

results = []

# for all images in test_dir
for idx, img_name in enumerate(os.listdir(test_dir)):
    if img_name.endswith('.jpg') or img_name.endswith('.png'):
        
        img_path = os.path.join(test_dir, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        height, width = img.shape
        
        # Calculate the number of tiles
        rows = height // min_size
        cols = width // min_size
        
        # Split the image into tiles
        images = []
        for i in range(rows):
            for j in range(cols):
                y_start = i * min_size
                x_start = j * min_size
                y_end = min(y_start + min_size, height)
                x_end = min(x_start + min_size, width)
                image = img[y_start:y_end, x_start:x_end]
                images.append(image)
        
        # Collect model predictions
        predictions = []
        for image in images:
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction)
        
        # Calculate the prediction
        S_value_pred = np.median(predictions) * 100 # * 100, because we normalized the data when we imported it 
        
        SDAS_pred = S_value_pred * F_value  
        
        # Extract the actual SDAS value from the filename
        try:
            SDAS_true = float(img_name.split('_')[1])
            results.append((SDAS_true, SDAS_pred))
        except:
            print(f"Warning: Couldn't extract SDAS-value from '{img_name}'!")

        if idx % 5 == 0:
            print(f"⏳ Processed {idx}/{len(os.listdir(test_dir))} images...")
# Out:
# ⏳ Processed 0/81 images...
# ⏳ Processed 5/81 images...
# ⏳ Processed 10/81 images...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 33
#      31     image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
#      32     image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # add channel dimension
# ---> 33     prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
#      34     predictions.append(prediction)
#      36 # Calculate the prediction
#
# File /opt/conda/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
# Separate true and predicted values
y_true = [true for true, pred in results]
y_pred = [pred for true, pred in results]

# Calculate the metrics
SDAS_mse = mean_squared_error(y_true, y_pred)
SDAS_rmse = np.sqrt(SDAS_mse)
SDAS_mae = mean_absolute_error(y_true, y_pred)
SDAS_r2 = r2_score(y_true, y_pred)

# MAPE (with protection against division by zero)
y_true_array = np.array(y_true)
y_pred_array = np.array(y_pred)
SDAS_mape = np.mean(np.abs((y_true_array - y_pred_array) / y_true_array)) * 100

# Output the results
print(f"MSE: {SDAS_mse:.4f}")
print(f"RMSE: {SDAS_rmse:.4f}")
print(f"MAE: {SDAS_mae:.4f}")
print(f"MAPE: {SDAS_mape:.2f}%")
print(f"R²: {SDAS_r2:.4f}")

# %%
len(y_true_array)

# %%
#plotting predicted vs ground truth SDAS values for all images

plt.figure(figsize=(6, 6))  
plt.plot([0, 100], [0, 100], 'r--')  # Reference diagonal line
plt.scatter(y_true_array, y_pred_array)
plt.xlabel("Ground Truth SDAS")
plt.ylabel("Predicted SDAS")
plt.axis("equal")  # Ensure equal scaling on both axes
plt.title("Predicted vs. Ground Truth SDAS")
plt.show()

# %% [markdown]
# ## Showing Sclices Predictions for an given image

# %%
def process_image(test_dir, img_name, model):
    img_path = os.path.join(test_dir, img_name)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    height, width = img.shape
    
    # Calculate the number of tiles
    rows = height // min_size
    cols = width // min_size
    
    # Split the image into tiles
    images = []
    predictions = []
    for i in range(rows):
        for j in range(cols):
            y_start = i * min_size
            x_start = j * min_size
            y_end = min(y_start + min_size, height)
            x_end = min(x_start + min_size, width)
            image = img[y_start:y_end, x_start:x_end]
            images.append(image)
            
            # Normalize and resize the image for prediction
            image = image.astype(np.float16) / 255.0  # normalize to [0, 1]
            image_resized = tf.image.resize(image[..., np.newaxis], (200, 200))  # Add channel dimension            
            prediction = model.predict(np.expand_dims(image_resized, axis=0), verbose=0)[0][0]
            predictions.append(prediction * 100 * F_value)
    
    return img, predictions, rows, cols

def plot_heatmap_with_image(img, predictions, rows, cols, min_size):
    # Reshape predictions to match the number of tiles
    heatmap = np.array(predictions).reshape((rows, cols))
    
    # Create a figure
    plt.figure(figsize=(10, 10))
    
    # Display the original image
    plt.imshow(img, cmap='gray', extent=[0, img.shape[1], img.shape[0], 0])
    
    # Overlay the heatmap on top of the image
    plt.imshow(heatmap, cmap='jet', alpha=0.5, extent=[0, img.shape[1], img.shape[0], 0])
    
    # Add color bar (legend for the heatmap)
    cbar = plt.colorbar()
    cbar.set_label('SDAS Prediction')

    # Show the plot
    plt.title("Image with SDAS Heatmap Overlay")
    plt.show()

# %%
test_dir = r'../data/bmw_test'
img_name = 'AC_39_B9.jpg'  # Replace with the image you want to test

# Process the selected image
img, predictions, rows, cols = process_image(test_dir, img_name, model)

# %%
print(np.median(predictions))

# Plot the heatmap over the image
plot_heatmap_with_image(img, predictions, rows, cols, min_size)

# %% [markdown]
# ## ML-Flow

# %%
# !pip install --user mlflow
# !pip install mlflow

# %%
import mlflow
import mlflow.keras
from mlflow.tracking import MlflowClient

# %% [markdown]
# Tutorial: https://www.youtube.com/watch?v=6ngxBkx05Fs&ab_channel=codebasics
#
# What do we want to log for every run:
# - model (with summary)
# - hyperparameter
# - dataset version
# - metrics
# - notebook

# %% [markdown]
# Run "mlflow ui" in your CMD first!

# %%
# !mlflow --version

# %%
mlflow.set_experiment("SDAS_Prediciton")
mlflow.set_tracking_uri("file:../mlruns")

with mlflow.start_run(run_name = 'v1_CNN_paperArchitecture_bmw_unaugmented'): # change with every run 
    
    # Save hyperparameters
    
    mlflow.log_params({
        'learning_rate': learning_rate,
        'batch_size': batch_size,
        'epochs': epochs,
        'shuffle': shuffle,
        'optimizer': optimizer,
        # Save Data
        #'dataset_version': dataset_version,  
        #'test_dataset_version': test_dataset_version,
        'pixel_per_µm': pixel_per_µm
    }) 
    
    # Save metrics
    
    mlflow.log_metrics({
        'S_norm_Mean Squared Error': mse.result().numpy(),
        'S_norm_Root Mean Squared Error': rmse.result().numpy(), 
        'S_norm_Mean Absolute Percentage Error': mape.result().numpy(),
        'S_norm_Mean Absolute Error': mae.result().numpy(),
        'S_norm_R2-Score': r2,
        'SDAS_Mean Squared Error': SDAS_mse,
        'SDAS_Root_Mean Squared Error': SDAS_rmse,
        'SDAS_Mean Absolute Percentage Error': SDAS_mape, 
        'SDAS_Mean Absolute Error': SDAS_mae,
        'SDAS_R2-Score': SDAS_r2
    }) 
    
    # Save model
    
    if isinstance(model, tf.keras.Model):
        mlflow.keras.log_model(model, artifact_path="cnn_model")
    else:
        print("The model isn't from the type tf.keras.Model!") 
        
    # Save notebook
    
    mlflow.log_artifact("CNN_SDAS_Prediction_Pipeline.ipynb", artifact_path="notebooks") # Name of notebook has to be correct

# %% [markdown]
# ## Load model from ML-Flow

# %%
# Enter RunID and Path
run_id = input("Enter your RunID: ")  # Ersetze mit deiner RunID
model_path = "cnn_model"

# load model
loaded_model = mlflow.keras.load_model(f"runs:/{run_id}/{model_path}")

# print model architecture
loaded_model.summary()

# %%
y_pred = loaded_model.predict(X_test)
y_pred[:4]

# %%
# optional

client = MlflowClient()

# load hyperparameter and metrcis
run_data = client.get_run(run_id).data
print("Hyperparameter:", run_data.params)
print("Metriken:", run_data.metrics)

# download current notebook
client.download_artifacts(run_id, f"notebooks_from_mlflow/{run_id}.ipynb", "./")
